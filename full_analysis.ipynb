# %% [markdown]
# # Full Market Scanner
#
# Comprehensive scanner for all market categories with automated report generation.
#
# ### Coverage
# - **S&P 500**: ~500 stocks
# - **NASDAQ 100**: ~100 stocks
# - **Portfolio**: Custom watchlist from `stocks.txt`
#
# ### Output
# - **Excel**: Single-tab FULL HOLD + ADD signals (S&P 500 & NASDAQ 100), Multi-tab signals (Portfolio)
# - **PDF**: Detailed research reports with support/resistance levels
# - **Cleanup**: Automatically archives old scans (keeps most recent only)
#
# ### Runtime (with rate limit protection)
# - **First run today**: ~15-25 minutes (fetches fresh data with delays)
# - **Second run today**: ~2-3 minutes (uses 24hr cache)
# - S&P 500: ~6-8 minutes | NASDAQ 100: ~1-2 minutes | Portfolio: ~30 seconds

# %%
# ============================================================================
# CELL 2: Import all required libraries and scanner functions
# ============================================================================

# Import libraries
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from pathlib import Path
import importlib

# Import scanner functions
import full_scanner
importlib.reload(full_scanner)
from full_scanner import (get_sp500_tickers, get_nasdaq100_tickers, scan_stocks, 
                          filter_buy_signals, create_excel_output, create_pdf_report, 
                          create_portfolio_excel, cleanup_old_scans)

# Display settings
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

# %% [markdown]
# ---
# ## Step 1: Scan S&P 500
# Scanning ~500 stocks (6-8 minutes first run, instant if cached)

# %%
# ============================================================================
# CELL 4: S&P 500 Scanner - Fetches ~503 stocks and scans for signals
# ============================================================================

print("="*80)
print("SCAN 1 of 3: S&P 500")
print("="*80 + "\n")

start_time = datetime.now()
sp500_tickers = get_sp500_tickers()
print(f"Found {len(sp500_tickers)} S&P 500 stocks\n")

sp500_results = scan_stocks(sp500_tickers, category="S&P 500", daily_bars=60, weekly_bars=52, concurrency=2)
sp500_elapsed = (datetime.now() - start_time).total_seconds()

print(f"\n✓ S&P 500 scan completed in {sp500_elapsed:.1f} seconds")
# Out:
# ================================================================================
# SCAN 1 of 3: S&P 500
# ================================================================================
#
# ✓ Loaded 503 S&P 500 tickers
#
# Found 503 S&P 500 stocks
#
# 🔍 Scanning 503 S&P 500 stocks for 'FULL HOLD + ADD' signals...
# Parameters: 60 daily bars, 52 weekly bars, 2 threads
# ================================================================================
# ✓ [4/503] ABBV   -> FULL HOLD + ADD      $220.18
# ✓ [9/503] AFL    -> FULL HOLD + ADD      $112.19
# ✓ [14/503] ALB    -> FULL HOLD + ADD      $146.13
# ✓ [18/503] ALL    -> FULL HOLD + ADD      $205.57
# ✓ [20/503] GOOGL  -> FULL HOLD + ADD      $316.54
# ✓ [21/503] GOOG   -> FULL HOLD + ADD      $317.32
# ✓ [23/503] AMZN   -> FULL HOLD + ADD      $233.06
# ✓ [27/503] AXP    -> FULL HOLD + ADD      $379.80
# ✓ [28/503] AIG    -> FULL HOLD + ADD      $84.38
# ✓ [32/503] AME    -> FULL HOLD + ADD      $211.31
# ✓ [33/503] AMGN   -> FULL HOLD + ADD      $320.72
# ✓ [34/503] APH    -> FULL HOLD + ADD      $139.88
# ✓ [35/503] ADI    -> FULL HOLD + ADD      $277.29
# ✓ [38/503] APO    -> FULL HOLD + ADD      $149.76
# ✓ [39/503] AAPL   -> FULL HOLD + ADD      $267.26
# ✓ [40/503] AMAT   -> FULL HOLD + ADD      $284.32
# ✓ [41/503] APP    -> FULL HOLD + ADD      $632.91
# ✓ [43/503] ACGL   -> FULL HOLD + ADD      $94.44
# ✓ [45/503] ARES   -> FULL HOLD + ADD      $172.05
# ✓ [48/503] AIZ    -> FULL HOLD + ADD      $240.42
#   [50/503] Scanning...
# ✓ [59/503] BAC    -> FULL HOLD + ADD      $56.89
# ✓ [63/503] BRK-B  -> FULL HOLD + ADD      $498.52
# ✓ [69/503] BK     -> FULL HOLD + ADD      $121.04
# ✓ [71/503] BKNG   -> FULL HOLD + ADD      $5367.37
# ✓ [81/503] CHRW   -> FULL HOLD + ADD      $167.21
# ✓ [85/503] COF    -> FULL HOLD + ADD      $250.51
# ✓ [86/503] CAH    -> FULL HOLD + ADD      $205.45
# ✓ [87/503] CCL    -> FULL HOLD + ADD      $31.49
# ✓ [89/503] CVNA   -> FULL HOLD + ADD      $430.06
# ✓ [90/503] CAT    -> FULL HOLD + ADD      $616.10
# ✓ [91/503] CBOE   -> FULL HOLD + ADD      $252.11
# ✓ [92/503] CBRE   -> FULL HOLD + ADD      $164.40
# ✓ [94/503] COR    -> FULL HOLD + ADD      $340.92
# ✓ [99/503] SCHW   -> FULL HOLD + ADD      $103.74
#   [100/503] Scanning...
# ✓ [101/503] CVX    -> FULL HOLD + ADD      $163.85
# ✓ [103/503] CB     -> FULL HOLD + ADD      $315.19
# ✓ [106/503] CINF   -> FULL HOLD + ADD      $161.96
# ✓ [108/503] CSCO   -> FULL HOLD + ADD      $75.58
# ✓ [109/503] C      -> FULL HOLD + ADD      $123.30
# ✓ [110/503] CFG    -> FULL HOLD + ADD      $61.05
# ✓ [112/503] CME    -> FULL HOLD + ADD      $275.06
# ✓ [113/503] KO     -> FULL HOLD + ADD      $67.94
# ✓ [115/503] CTSH   -> FULL HOLD + ADD      $81.63
# ✓ [119/503] FIX    -> FULL HOLD + ADD      $1032.31
# ✓ [124/503] CEG    -> FULL HOLD + ADD      $354.94
# ✓ [127/503] GLW    -> FULL HOLD + ADD      $88.69
# ✓ [132/503] CTRA   -> FULL HOLD + ADD      $25.82
# ✓ [133/503] CRH    -> FULL HOLD + ADD      $128.31
# ✓ [136/503] CSX    -> FULL HOLD + ADD      $35.91
# ✓ [137/503] CMI    -> FULL HOLD + ADD      $531.70
# ✓ [138/503] CVS    -> FULL HOLD + ADD      $80.42
# ✓ [144/503] DAY    -> FULL HOLD + ADD      $69.34
# ✓ [147/503] DAL    -> FULL HOLD + ADD      $71.82
#   [150/503] Scanning...
# ✓ [152/503] DG     -> FULL HOLD + ADD      $138.93
# ✓ [153/503] DLTR   -> FULL HOLD + ADD      $128.57
# ✓ [157/503] DOV    -> FULL HOLD + ADD      $202.27
# ✓ [162/503] DD     -> FULL HOLD + ADD      $42.01
# ✓ [167/503] EW     -> FULL HOLD + ADD      $84.17
# ✓ [168/503] EA     -> FULL HOLD + ADD      $204.36
# ✓ [171/503] EMR    -> FULL HOLD + ADD      $142.85
# ✓ [186/503] EXE    -> FULL HOLD + ADD      $106.82
# ✓ [187/503] EXPE   -> FULL HOLD + ADD      $287.47
# ✓ [188/503] EXPD   -> FULL HOLD + ADD      $154.40
# ✓ [190/503] XOM    -> FULL HOLD + ADD      $125.36
# ✓ [194/503] FRT    -> FULL HOLD + ADD      $99.56
# ✓ [197/503] FDX    -> FULL HOLD + ADD      $297.46
# ✓ [198/503] FITB   -> FULL HOLD + ADD      $48.62
# ✓ [199/503] FSLR   -> FULL HOLD + ADD      $272.00
#   [200/503] Scanning...
# ✓ [202/503] F      -> FULL HOLD + ADD      $13.47
# ✓ [205/503] FOXA   -> FULL HOLD + ADD      $75.67
# ✓ [206/503] FOX    -> FULL HOLD + ADD      $67.76
# ✓ [207/503] BEN    -> FULL HOLD + ADD      $24.49
# ✓ [209/503] FCX    -> FULL HOLD + ADD      $54.41
# ✓ [211/503] GE     -> FULL HOLD + ADD      $324.32
# ✓ [213/503] GEV    -> FULL HOLD + ADD      $680.86
# ✓ [216/503] GD     -> FULL HOLD + ADD      $355.56
# ✓ [218/503] GM     -> FULL HOLD + ADD      $83.15
# ✓ [221/503] GILD   -> FULL HOLD + ADD      $118.30
# ✓ [223/503] GL     -> FULL HOLD + ADD      $140.63
# ✓ [224/503] GS     -> FULL HOLD + ADD      $948.44
# ✓ [226/503] HIG    -> FULL HOLD + ADD      $137.75
# ✓ [227/503] HAS    -> FULL HOLD + ADD      $85.58
# ✓ [228/503] HCA    -> FULL HOLD + ADD      $477.83
# ✓ [230/503] HSIC   -> FULL HOLD + ADD      $78.54
# ✓ [231/503] HSY    -> FULL HOLD + ADD      $179.99
# ✓ [232/503] HPE    -> FULL HOLD + ADD      $24.13
# ✓ [233/503] HLT    -> FULL HOLD + ADD      $285.77
# ✓ [238/503] HST    -> FULL HOLD + ADD      $18.12
# ✓ [239/503] HWM    -> FULL HOLD + ADD      $212.92
# ✓ [241/503] HUBB   -> FULL HOLD + ADD      $465.48
# ✓ [243/503] HBAN   -> FULL HOLD + ADD      $17.88
# ✓ [244/503] HII    -> FULL HOLD + ADD      $363.48
# ✓ [245/503] IBM    -> FULL HOLD + ADD      $294.97
# ✓ [247/503] IDXX   -> FULL HOLD + ADD      $682.23
# ✓ [249/503] INCY   -> FULL HOLD + ADD      $101.79
#   [250/503] Scanning...
# ✓ [252/503] INTC   -> FULL HOLD + ADD      $39.37
# ✓ [258/503] ISRG   -> FULL HOLD + ADD      $566.38
# ✓ [259/503] IVZ    -> FULL HOLD + ADD      $28.16
# ✓ [261/503] IQV    -> FULL HOLD + ADD      $234.59
# ✓ [263/503] JBHT   -> FULL HOLD + ADD      $202.02
# ✓ [264/503] JBL    -> FULL HOLD + ADD      $223.44
# ✓ [265/503] JKHY   -> FULL HOLD + ADD      $181.46
# ✓ [267/503] JNJ    -> FULL HOLD + ADD      $204.31
# ✓ [268/503] JCI    -> FULL HOLD + ADD      $121.53
# ✓ [269/503] JPM    -> FULL HOLD + ADD      $334.04
# ✓ [272/503] KEY    -> FULL HOLD + ADD      $21.37
# ✓ [273/503] KEYS   -> FULL HOLD + ADD      $208.82
# ✓ [276/503] KMI    -> FULL HOLD + ADD      $27.90
# ✓ [277/503] KKR    -> FULL HOLD + ADD      $134.57
# ✓ [278/503] KLAC   -> FULL HOLD + ADD      $1352.45
# ✓ [281/503] LHX    -> FULL HOLD + ADD      $311.38
# ✓ [283/503] LRCX   -> FULL HOLD + ADD      $194.76
# ✓ [285/503] LVS    -> FULL HOLD + ADD      $64.64
# ✓ [289/503] LLY    -> FULL HOLD + ADD      $1041.51
# ✓ [292/503] LMT    -> FULL HOLD + ADD      $511.57
# ✓ [293/503] L      -> FULL HOLD + ADD      $105.67
# ✓ [294/503] LOW    -> FULL HOLD + ADD      $244.75
# ✓ [297/503] MTB    -> FULL HOLD + ADD      $209.45
# ✓ [299/503] MAR    -> FULL HOLD + ADD      $311.03
#   [300/503] Scanning...
# ✓ [301/503] MLM    -> FULL HOLD + ADD      $642.00
# ✓ [303/503] MA     -> FULL HOLD + ADD      $568.57
# ✓ [306/503] MCD    -> FULL HOLD + ADD      $299.86
# ✓ [307/503] MCK    -> FULL HOLD + ADD      $824.92
# ✓ [308/503] MDT    -> FULL HOLD + ADD      $97.36
# ✓ [311/503] MET    -> FULL HOLD + ADD      $81.77
# ✓ [312/503] MTD    -> FULL HOLD + ADD      $1446.63
# ✓ [315/503] MU     -> FULL HOLD + ADD      $312.15
# ✓ [322/503] MPWR   -> FULL HOLD + ADD      $955.03
# ✓ [323/503] MNST   -> FULL HOLD + ADD      $75.67
# ✓ [324/503] MCO    -> FULL HOLD + ADD      $526.88
# ✓ [325/503] MS     -> FULL HOLD + ADD      $186.54
# ✓ [328/503] MSCI   -> FULL HOLD + ADD      $577.60
# ✓ [329/503] NDAQ   -> FULL HOLD + ADD      $98.45
# ✓ [332/503] NEM    -> FULL HOLD + ADD      $103.53
# ✓ [338/503] NDSN   -> FULL HOLD + ADD      $245.89
# ✓ [339/503] NSC    -> FULL HOLD + ADD      $287.92
# ✓ [340/503] NTRS   -> FULL HOLD + ADD      $144.00
# ✓ [341/503] NOC    -> FULL HOLD + ADD      $611.32
# ✓ [344/503] NUE    -> FULL HOLD + ADD      $168.13
# ✓ [345/503] NVDA   -> FULL HOLD + ADD      $188.12
# ✓ [347/503] NXPI   -> FULL HOLD + ADD      $223.88
#   [350/503] Scanning...
# ✓ [356/503] PCAR   -> FULL HOLD + ADD      $112.92
# ✓ [357/503] PKG    -> FULL HOLD + ADD      $211.13
# ✓ [358/503] PLTR   -> FULL HOLD + ADD      $174.04
# ✓ [361/503] PH     -> FULL HOLD + ADD      $906.89
# ✓ [372/503] PNC    -> FULL HOLD + ADD      $215.80
# ✓ [376/503] PFG    -> FULL HOLD + ADD      $90.51
# ✓ [379/503] PLD    -> FULL HOLD + ADD      $129.69
# ✓ [380/503] PRU    -> FULL HOLD + ADD      $117.36
# ✓ [385/503] PWR    -> FULL HOLD + ADD      $435.82
# ✓ [386/503] QCOM   -> FULL HOLD + ADD      $176.31
# ✓ [389/503] RL     -> FULL HOLD + ADD      $358.52
# ✓ [390/503] RJF    -> FULL HOLD + ADD      $167.33
# ✓ [391/503] RTX    -> FULL HOLD + ADD      $188.26
# ✓ [395/503] RF     -> FULL HOLD + ADD      $28.27
# ✓ [400/503] ROK    -> FULL HOLD + ADD      $404.73
# ✓ [401/503] ROL    -> FULL HOLD + ADD      $58.93
# ✓ [403/503] ROST   -> FULL HOLD + ADD      $186.68
# ✓ [405/503] SPGI   -> FULL HOLD + ADD      $532.90
# ✓ [407/503] SNDK   -> FULL HOLD + ADD      $274.08
# ✓ [410/503] STX    -> FULL HOLD + ADD      $289.83
# ✓ [414/503] SPG    -> FULL HOLD + ADD      $183.11
# ✓ [418/503] SNA    -> FULL HOLD + ADD      $354.20
# ✓ [419/503] SOLV   -> FULL HOLD + ADD      $80.80
# ✓ [421/503] LUV    -> FULL HOLD + ADD      $42.44
# ✓ [424/503] STT    -> FULL HOLD + ADD      $133.01
# ✓ [425/503] STLD   -> FULL HOLD + ADD      $171.83
# ✓ [426/503] STE    -> FULL HOLD + ADD      $256.75
# ✓ [429/503] SYF    -> FULL HOLD + ADD      $86.74
# ✓ [433/503] TROW   -> FULL HOLD + ADD      $106.49
# ✓ [434/503] TTWO   -> FULL HOLD + ADD      $257.31
# ✓ [435/503] TPR    -> FULL HOLD + ADD      $128.53
# ✓ [436/503] TRGP   -> FULL HOLD + ADD      $183.47
# ✓ [438/503] TEL    -> FULL HOLD + ADD      $231.40
# ✓ [440/503] TER    -> FULL HOLD + ADD      $219.50
# ✓ [441/503] TSLA   -> FULL HOLD + ADD      $451.67
# ✓ [444/503] TXT    -> FULL HOLD + ADD      $89.00
# ✓ [445/503] TMO    -> FULL HOLD + ADD      $611.20
# ✓ [446/503] TJX    -> FULL HOLD + ADD      $153.84
# ✓ [447/503] TKO    -> FULL HOLD + ADD      $203.65
#   [450/503] Scanning...
# ✓ [452/503] TRV    -> FULL HOLD + ADD      $287.76
# ✓ [453/503] TRMB   -> FULL HOLD + ADD      $79.27
# ✓ [454/503] TFC    -> FULL HOLD + ADD      $50.48
# ✓ [457/503] USB    -> FULL HOLD + ADD      $55.49
# ✓ [460/503] ULTA   -> FULL HOLD + ADD      $631.15
# ✓ [461/503] UNP    -> FULL HOLD + ADD      $231.97
# ✓ [462/503] UAL    -> FULL HOLD + ADD      $114.89
# ✓ [466/503] UHS    -> FULL HOLD + ADD      $222.87
# ✓ [468/503] VTR    -> FULL HOLD + ADD      $76.44
# ✓ [474/503] VTRS   -> FULL HOLD + ADD      $12.37
# ✓ [476/503] V      -> FULL HOLD + ADD      $353.80
# ✓ [481/503] WAB    -> FULL HOLD + ADD      $217.01
# ✓ [482/503] WMT    -> FULL HOLD + ADD      $112.71
# ✓ [484/503] WBD    -> FULL HOLD + ADD      $28.53
# ✓ [486/503] WAT    -> FULL HOLD + ADD      $394.97
# ✓ [488/503] WFC    -> FULL HOLD + ADD      $96.38
# ✓ [489/503] WELL   -> FULL HOLD + ADD      $184.73
# ✓ [491/503] WDC    -> FULL HOLD + ADD      $187.88
# ✓ [494/503] WMB    -> FULL HOLD + ADD      $61.16
# ✓ [495/503] WTW    -> FULL HOLD + ADD      $334.60
# ✓ [497/503] WYNN   -> FULL HOLD + ADD      $119.68
# ✓ [500/503] YUM    -> FULL HOLD + ADD      $150.29
# ================================================================================
#
# ✓ Scan complete: 501 analyzed, 202 FULL HOLD + ADD signals found
#
#
# ✓ S&P 500 scan completed in 678.7 seconds

# %% [markdown]
# ---
# ## Step 2: Scan NASDAQ 100
# Scanning ~100 stocks (1-2 minutes first run, instant if cached)

# %%
# ============================================================================
# CELL 6: NASDAQ 100 Scanner - Fetches ~101 stocks and scans for signals
# ============================================================================

print("\n" + "="*80)
print("SCAN 2 of 3: NASDAQ 100")
print("="*80 + "\n")

start_time = datetime.now()
nasdaq100_tickers = get_nasdaq100_tickers()
print(f"Found {len(nasdaq100_tickers)} NASDAQ 100 stocks\n")

nasdaq100_results = scan_stocks(nasdaq100_tickers, category="NASDAQ 100", daily_bars=60, weekly_bars=52, concurrency=2)
nasdaq100_elapsed = (datetime.now() - start_time).total_seconds()

print(f"\n✓ NASDAQ 100 scan completed in {nasdaq100_elapsed:.1f} seconds")
# Out:
# ================================================================================
# SCAN 2 of 3: NASDAQ 100
# ================================================================================
#
# ✓ Loaded 101 NASDAQ 100 tickers
#
# Found 101 NASDAQ 100 stocks
#
# 🔍 Scanning 101 NASDAQ 100 stocks for 'FULL HOLD + ADD' signals...
# Parameters: 60 daily bars, 52 weekly bars, 2 threads
# ================================================================================
# ✓ [4/101] GOOGL  -> FULL HOLD + ADD      $316.54
# ✓ [5/101] GOOG   -> FULL HOLD + ADD      $317.32
# ✓ [6/101] AMZN   -> FULL HOLD + ADD      $233.06
# ✓ [8/101] AMGN   -> FULL HOLD + ADD      $320.72
# ✓ [9/101] ADI    -> FULL HOLD + ADD      $277.29
# ✓ [10/101] AAPL   -> FULL HOLD + ADD      $267.26
# ✓ [11/101] AMAT   -> FULL HOLD + ADD      $284.32
# ✓ [12/101] APP    -> FULL HOLD + ADD      $632.91
# ✓ [15/101] ASML   -> FULL HOLD + ADD      $1228.19
# ✓ [16/101] AZN    -> FULL HOLD + ADD      $91.22
# ✓ [21/101] BKNG   -> FULL HOLD + ADD      $5367.37
# ✓ [26/101] CSCO   -> FULL HOLD + ADD      $75.58
# ✓ [27/101] CCEP   -> FULL HOLD + ADD      $87.56
# ✓ [28/101] CTSH   -> FULL HOLD + ADD      $81.63
# ✓ [30/101] CEG    -> FULL HOLD + ADD      $354.94
# ✓ [35/101] CSX    -> FULL HOLD + ADD      $35.91
# ✓ [40/101] EA     -> FULL HOLD + ADD      $204.36
# ✓ [46/101] GILD   -> FULL HOLD + ADD      $118.30
# ✓ [48/101] IDXX   -> FULL HOLD + ADD      $682.23
# ✓ [49/101] FER    -> FULL HOLD + ADD      $67.18
# ✓ [50/101] INTC   -> FULL HOLD + ADD      $39.37
# ✓ [52/101] ISRG   -> FULL HOLD + ADD      $566.38
# ✓ [54/101] KLAC   -> FULL HOLD + ADD      $1352.45
# ✓ [56/101] LRCX   -> FULL HOLD + ADD      $194.76
# ✓ [58/101] MAR    -> FULL HOLD + ADD      $311.03
# ✓ [59/101] INSM   -> FULL HOLD + ADD      $175.20
# ✓ [60/101] MRVL   -> FULL HOLD + ADD      $90.23
# ✓ [63/101] MU     -> FULL HOLD + ADD      $312.15
# ✓ [67/101] MPWR   -> FULL HOLD + ADD      $955.03
# ✓ [68/101] MNST   -> FULL HOLD + ADD      $75.67
# ✓ [70/101] NVDA   -> FULL HOLD + ADD      $188.12
# ✓ [71/101] NXPI   -> FULL HOLD + ADD      $223.88
# ✓ [74/101] PCAR   -> FULL HOLD + ADD      $112.92
# ✓ [75/101] PLTR   -> FULL HOLD + ADD      $174.04
# ✓ [81/101] QCOM   -> FULL HOLD + ADD      $176.31
# ✓ [84/101] ROST   -> FULL HOLD + ADD      $186.68
# ✓ [85/101] STX    -> FULL HOLD + ADD      $289.83
# ✓ [90/101] TTWO   -> FULL HOLD + ADD      $257.31
# ✓ [91/101] TSLA   -> FULL HOLD + ADD      $451.67
# ✓ [93/101] SHOP   -> FULL HOLD + ADD      $166.21
# ✓ [96/101] WBD    -> FULL HOLD + ADD      $28.53
# ✓ [97/101] WDC    -> FULL HOLD + ADD      $187.88
#   [100/101] Scanning...
# ================================================================================
#
# ✓ Scan complete: 101 analyzed, 42 FULL HOLD + ADD signals found
#
#
# ✓ NASDAQ 100 scan completed in 24.5 seconds

# %% [markdown]
# ---
# ## Step 3: Scan Portfolio
# Scanning custom watchlist from `stocks.txt` (~30 seconds, instant if cached)

# %%
# ============================================================================
# CELL 8: Portfolio Scanner - Loads stocks.txt and scans your watchlist
# Note: Skips lines starting with # (comments) or [ (basket headers)
# ============================================================================

print("\n" + "="*80)
print("SCAN 3 of 3: PORTFOLIO STOCKS")
print("="*80 + "\n")

# Load portfolio tickers
stocks_file = Path('stocks.txt')
if stocks_file.exists():
    with open(stocks_file) as f:
        portfolio_tickers = [line.strip() for line in f 
                            if line.strip() 
                            and not line.startswith('#')
                            and not line.startswith('[')]  # Skip basket lines
    print(f"✓ Loaded {len(portfolio_tickers)} portfolio tickers from stocks.txt\n")
else:
    portfolio_tickers = []
    print("⚠️  stocks.txt not found, skipping portfolio scan\n")

if portfolio_tickers:
    start_time = datetime.now()
    portfolio_results = scan_stocks(portfolio_tickers, category="Portfolio", daily_bars=60, weekly_bars=52, concurrency=2)
    portfolio_elapsed = (datetime.now() - start_time).total_seconds()
    print(f"\n✓ Portfolio scan completed in {portfolio_elapsed:.1f} seconds")
else:
    portfolio_results = pd.DataFrame()
    portfolio_elapsed = 0
# Out:
# ================================================================================
# SCAN 3 of 3: PORTFOLIO STOCKS
# ================================================================================
#
# ✓ Loaded 13 portfolio tickers from stocks.txt
#
# 🔍 Scanning 13 Portfolio stocks for 'FULL HOLD + ADD' signals...
# Parameters: 60 daily bars, 52 weekly bars, 2 threads
# ================================================================================
# ✓ [1/13] TSLA   -> FULL HOLD + ADD      $451.67
# ✓ [2/13] NVDA   -> FULL HOLD + ADD      $188.12
# ✓ [6/13] ASML   -> FULL HOLD + ADD      $1228.19
# ✓ [8/13] PLTR   -> FULL HOLD + ADD      $174.04
# ✓ [10/13] MRVL   -> FULL HOLD + ADD      $90.23
# ================================================================================
#
# ✓ Scan complete: 13 analyzed, 5 FULL HOLD + ADD signals found
#
#
# ✓ Portfolio scan completed in 5.0 seconds

# %% [markdown]
# ---
# ## Step 4: Generate All Reports
# Creating Excel files and PDF research documents for each category

# %%
# ============================================================================
# CELL 10: Report Generator - Creates 6 files (3 Excel + 3 PDF)
# - S&P 500: sp500_analysis_*.xlsx + PDF (1 tab: FULL HOLD + ADD only)
# - NASDAQ 100: nasdaq100_analysis_*.xlsx + PDF (1 tab: FULL HOLD + ADD only)
# - Portfolio: portfolio_scanner_*.xlsx + PDF (5 tabs: All signals)
# ============================================================================

print("\n" + "="*80)
print("GENERATING REPORTS")
print("="*80 + "\n")

results_dir = Path.cwd() / 'scanner_results'
results_dir.mkdir(exist_ok=True)
timestamp = datetime.now().strftime("%Y%m%d_%H%M")

# === S&P 500 Reports ===
if not sp500_results.empty:
    sp500_buy = filter_buy_signals(sp500_results, 'FULL HOLD + ADD')
    print(f"🎯 S&P 500: {len(sp500_buy)} FULL HOLD + ADD signals found")
    
    if not sp500_buy.empty:
        xlsx_path = results_dir / f'sp500_analysis_{timestamp}.xlsx'
        pdf_path = results_dir / f'scanner_report_sp500_{timestamp}.pdf'
        
        create_excel_output(sp500_buy, xlsx_path, category="S&P 500")
        create_pdf_report(sp500_buy, sp500_results, pdf_path, timestamp, category="S&P 500")
        print(f"  ✓ Excel: {xlsx_path.name}")
        print(f"  ✓ PDF: {pdf_path.name}\n")

# === NASDAQ 100 Reports ===
if not nasdaq100_results.empty:
    nasdaq100_buy = filter_buy_signals(nasdaq100_results, 'FULL HOLD + ADD')
    print(f"🎯 NASDAQ 100: {len(nasdaq100_buy)} FULL HOLD + ADD signals found")
    
    if not nasdaq100_buy.empty:
        xlsx_path = results_dir / f'nasdaq100_analysis_{timestamp}.xlsx'
        pdf_path = results_dir / f'scanner_report_nasdaq100_{timestamp}.pdf'
        
        create_excel_output(nasdaq100_buy, xlsx_path, category="NASDAQ 100")
        create_pdf_report(nasdaq100_buy, nasdaq100_results, pdf_path, timestamp, category="NASDAQ 100")
        print(f"  ✓ Excel: {xlsx_path.name}")
        print(f"  ✓ PDF: {pdf_path.name}\n")

# === Portfolio Reports ===
if not portfolio_results.empty:
    portfolio_buy = filter_buy_signals(portfolio_results, 'FULL HOLD + ADD')
    print(f"🎯 Portfolio: {len(portfolio_results)} stocks scanned (all included)")
    print(f"  - {len(portfolio_buy)} with FULL HOLD + ADD signal")
    
    xlsx_path = results_dir / f'portfolio_scanner_{timestamp}.xlsx'
    pdf_path = results_dir / f'scanner_report_portfolio_{timestamp}.pdf'
    
    create_portfolio_excel(portfolio_results, xlsx_path, category="Portfolio")
    create_pdf_report(portfolio_buy, portfolio_results, pdf_path, timestamp, category="Portfolio")
    print(f"  ✓ Excel: {xlsx_path.name}")
    print(f"  ✓ PDF: {pdf_path.name}\n")

# Cleanup old scans
print("📁 Managing scan history...")
cleanup_old_scans(results_dir, max_files=1)
# Out:
# ================================================================================
# GENERATING REPORTS
# ================================================================================
#
# 🎯 S&P 500: 202 FULL HOLD + ADD signals found
# ✓ Excel file created: c:\workspace\my_script_project\scanner_results\sp500_analysis_20260106_1456.xlsx
#   - FULL HOLD + ADD: 202 stocks
# ✓ PDF report created: c:\workspace\my_script_project\scanner_results\scanner_report_sp500_20260106_1456.pdf
#   - 202 FULL HOLD + ADD (detailed)
#   ✓ Excel: sp500_analysis_20260106_1456.xlsx
#   ✓ PDF: scanner_report_sp500_20260106_1456.pdf
#
# 🎯 NASDAQ 100: 42 FULL HOLD + ADD signals found
# ✓ Excel file created: c:\workspace\my_script_project\scanner_results\nasdaq100_analysis_20260106_1456.xlsx
#   - FULL HOLD + ADD: 42 stocks
# ✓ PDF report created: c:\workspace\my_script_project\scanner_results\scanner_report_nasdaq100_20260106_1456.pdf
#   - 42 FULL HOLD + ADD (detailed)
#   ✓ Excel: nasdaq100_analysis_20260106_1456.xlsx
#   ✓ PDF: scanner_report_nasdaq100_20260106_1456.pdf
#
# 🎯 Portfolio: 13 stocks scanned (all included)
#   - 5 with FULL HOLD + ADD signal
# ✓ Excel file created: c:\workspace\my_script_project\scanner_results\portfolio_scanner_20260106_1456.xlsx
#   - All: 13 stocks
#   - FULL HOLD + ADD: 5 stocks
#   - HOLD MOST → REDUCE: 4 stocks
#   - HOLD: 2 stocks
#   - CASH: 2 stocks
# ✓ PDF report created: c:\workspace\my_script_project\scanner_results\scanner_report_portfolio_20260106_1456.pdf
#   - 5 FULL HOLD + ADD (detailed)
#   - 4 HOLD MOST → REDUCE (summary)
#   - 2 HOLD (summary)
#   - 2 CASH (summary)
#   ✓ Excel: portfolio_scanner_20260106_1456.xlsx
#   ✓ PDF: scanner_report_portfolio_20260106_1456.pdf
#
# 📁 Managing scan history...
#   📦 Archived (sp500): sp500_analysis_20260106_1420.xlsx
#   📦 Archived (sp500): scanner_report_sp500_20260106_1420.pdf
#   📦 Archived (nasdaq100): nasdaq100_analysis_20260106_1420.xlsx
#   📦 Archived (nasdaq100): scanner_report_nasdaq100_20260106_1420.pdf
#   ✅ Archived 4 file(s), kept 1 most recent

# %% [markdown]
# ---
# ## Summary & Results
# Final scan statistics and file locations

# %%
# ============================================================================
# CELL 12: Summary Statistics - Shows total signals found and timing
# ============================================================================

print("\n" + "="*80)
print("SCAN COMPLETE - SUMMARY")
print("="*80)

total_time = sp500_elapsed + nasdaq100_elapsed + portfolio_elapsed
print(f"⏱️  Total time: {total_time:.1f}s\n")

print("📊 Results by Category:")
if not sp500_results.empty:
    sp500_buy = filter_buy_signals(sp500_results, 'FULL HOLD + ADD')
    print(f"  S&P 500:     {len(sp500_buy):3d} FULL HOLD + ADD signals ({sp500_elapsed:.1f}s)")
if not nasdaq100_results.empty:
    nasdaq100_buy = filter_buy_signals(nasdaq100_results, 'FULL HOLD + ADD')
    print(f"  NASDAQ 100:  {len(nasdaq100_buy):3d} FULL HOLD + ADD signals ({nasdaq100_elapsed:.1f}s)")
if not portfolio_results.empty:
    portfolio_buy = filter_buy_signals(portfolio_results, 'FULL HOLD + ADD')
    print(f"  Portfolio:    {len(portfolio_buy):3d} FULL HOLD + ADD signals ({portfolio_elapsed:.1f}s)")

print("\n✅ All reports generated in scanner_results/")
# Out:
# ================================================================================
# SCAN COMPLETE - SUMMARY
# ================================================================================
# ⏱️  Total time: 708.2s
#
# 📊 Results by Category:
#   S&P 500:     202 FULL HOLD + ADD signals (678.7s)
#   NASDAQ 100:   42 FULL HOLD + ADD signals (24.5s)
#   Portfolio:      5 FULL HOLD + ADD signals (5.0s)
#
# ✅ All reports generated in scanner_results/
