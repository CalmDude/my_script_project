# %% [markdown]
# ## Cell 1: Environment Setup

# %%
from pathlib import Path
from datetime import datetime
import pandas as pd
import importlib

# Import and reload scanner module (ensures latest code changes are used)
import sp500_scanner
importlib.reload(sp500_scanner)
from sp500_scanner import get_sp500_tickers, scan_sp500, filter_buy_signals, create_excel_output, create_pdf_report, cleanup_old_scans

print("✓ Imports complete")
print(f"Ready to scan S&P 500 as of {datetime.now().strftime('%Y-%m-%d %H:%M')}")
# Out:
# ✓ Imports complete
# Ready to scan S&P 500 as of 2026-01-05 21:01

# %% [markdown]
# ## Cell 2: Run Full S&P 500 Scan
#
# **This will take 5-10 minutes to complete.**
#
# Parameters:
# - `daily_bars=60` - 60 days of daily data
# - `weekly_bars=52` - 52 weeks of weekly data
# - `concurrency=15` - 15 parallel threads (adjust if needed)

# %%
# Run the scan
start_time = datetime.now()
print(f"🔍 Starting S&P 500 scan at {start_time.strftime('%H:%M:%S')}...\n")

results_df = scan_sp500(daily_bars=60, weekly_bars=52, concurrency=15)

elapsed = (datetime.now() - start_time).total_seconds()
print(f"\n✓ Scan completed in {elapsed:.1f} seconds")
# Out:
# 🔍 Starting S&P 500 scan at 21:02:02...
#
# Fetching S&P 500 ticker list...
# ✓ Loaded 503 S&P 500 tickers
#
# Found 503 S&P 500 stocks
#
# 🔍 Scanning 503 stocks for 'FULL HOLD + ADD' signals...
# Parameters: 60 daily bars, 52 weekly bars, 15 threads
# ================================================================================
# ✓ [3/503] ABBV   -> FULL HOLD + ADD      $219.41
# ✓ [6/503] AFL    -> FULL HOLD + ADD      $112.32
# ✓ [13/503] ALB    -> FULL HOLD + ADD      $146.48
# ✓ [17/503] GOOGL  -> FULL HOLD + ADD      $315.94
# ✓ [20/503] AMZN   -> FULL HOLD + ADD      $232.93
# ✓ [21/503] ALL    -> FULL HOLD + ADD      $205.65
# ✓ [22/503] GOOG   -> FULL HOLD + ADD      $316.53
# ✓ [29/503] AXP    -> FULL HOLD + ADD      $380.74
# ✓ [30/503] AIG    -> FULL HOLD + ADD      $85.15
# ✓ [32/503] AMGN   -> FULL HOLD + ADD      $319.64
# ✓ [33/503] AME    -> FULL HOLD + ADD      $211.93
# ✓ [34/503] APO    -> FULL HOLD + ADD      $151.21
# ✓ [37/503] APP    -> FULL HOLD + ADD      $633.03
# ✓ [38/503] APH    -> FULL HOLD + ADD      $139.68
# ✓ [39/503] ADI    -> FULL HOLD + ADD      $277.83
# ✓ [40/503] AAPL   -> FULL HOLD + ADD      $266.58
# ✓ [41/503] AMAT   -> FULL HOLD + ADD      $283.57
# ✓ [43/503] ACGL   -> FULL HOLD + ADD      $94.76
# ✓ [47/503] ARES   -> FULL HOLD + ADD      $173.12
# ✓ [48/503] AIZ    -> FULL HOLD + ADD      $240.87
#   [50/503] Scanning...
# ✓ [59/503] BAC    -> FULL HOLD + ADD      $57.02
# ✓ [63/503] BRK-B  -> FULL HOLD + ADD      $500.25
# ✓ [70/503] BK     -> FULL HOLD + ADD      $121.65
# ✓ [72/503] BKNG   -> FULL HOLD + ADD      $5396.70
# ✓ [82/503] CHRW   -> FULL HOLD + ADD      $166.92
# ✓ [85/503] CCL    -> FULL HOLD + ADD      $31.68
# ✓ [86/503] COF    -> FULL HOLD + ADD      $251.72
# ✓ [87/503] CAH    -> FULL HOLD + ADD      $205.68
# ✓ [89/503] CVNA   -> FULL HOLD + ADD      $430.07
# ✓ [90/503] CAT    -> FULL HOLD + ADD      $617.19
# ✓ [91/503] CBRE   -> FULL HOLD + ADD      $163.94
# ✓ [94/503] COR    -> FULL HOLD + ADD      $340.60
# ✓ [95/503] CBOE   -> FULL HOLD + ADD      $250.26
# ✓ [99/503] SCHW   -> FULL HOLD + ADD      $104.10
#   [100/503] Scanning...
# ✓ [102/503] CVX    -> FULL HOLD + ADD      $164.29
# ✓ [103/503] CB     -> FULL HOLD + ADD      $315.97
# ✓ [105/503] CINF   -> FULL HOLD + ADD      $162.47
# ✓ [107/503] CSCO   -> FULL HOLD + ADD      $75.78
# ✓ [108/503] C      -> FULL HOLD + ADD      $123.80
# ✓ [110/503] CFG    -> FULL HOLD + ADD      $61.27
# ✓ [113/503] CME    -> FULL HOLD + ADD      $274.56
# ✓ [115/503] CTSH   -> FULL HOLD + ADD      $81.86
# ✓ [116/503] KO     -> FULL HOLD + ADD      $68.12
# ✓ [118/503] FIX    -> FULL HOLD + ADD      $1026.48
# ✓ [121/503] CEG    -> FULL HOLD + ADD      $355.54
# ✓ [125/503] GLW    -> FULL HOLD + ADD      $87.57
# ✓ [130/503] CTRA   -> FULL HOLD + ADD      $25.69
# ✓ [134/503] CSX    -> FULL HOLD + ADD      $36.23
# ✓ [135/503] CRH    -> FULL HOLD + ADD      $128.44
# ✓ [136/503] CVS    -> FULL HOLD + ADD      $80.37
# ✓ [137/503] CMI    -> FULL HOLD + ADD      $530.32
# ✓ [143/503] DAY    -> FULL HOLD + ADD      $69.39
# ✓ [145/503] DAL    -> FULL HOLD + ADD      $72.46
#   [150/503] Scanning...
# ✓ [151/503] DLTR   -> FULL HOLD + ADD      $129.22
# ✓ [152/503] DG     -> FULL HOLD + ADD      $138.03
# ✓ [158/503] DOV    -> FULL HOLD + ADD      $202.96
# ✓ [163/503] DD     -> FULL HOLD + ADD      $42.00
# ✓ [166/503] EW     -> FULL HOLD + ADD      $84.25
# ✓ [168/503] EA     -> FULL HOLD + ADD      $204.37
# ✓ [172/503] EMR    -> FULL HOLD + ADD      $142.76
# ✓ [183/503] EXE    -> FULL HOLD + ADD      $105.97
# ✓ [186/503] EXPE   -> FULL HOLD + ADD      $287.29
# ✓ [187/503] EXPD   -> FULL HOLD + ADD      $154.57
# ✓ [190/503] XOM    -> FULL HOLD + ADD      $125.28
# ✓ [195/503] FRT    -> FULL HOLD + ADD      $99.99
# ✓ [196/503] FDX    -> FULL HOLD + ADD      $297.84
# ✓ [197/503] FSLR   -> FULL HOLD + ADD      $270.40
# ✓ [200/503] FITB   -> FULL HOLD + ADD      $48.77
# ✓ [201/503] F      -> FULL HOLD + ADD      $13.47
# ✓ [205/503] FOXA   -> FULL HOLD + ADD      $76.11
# ✓ [206/503] FOX    -> FULL HOLD + ADD      $68.00
# ✓ [208/503] BEN    -> FULL HOLD + ADD      $24.63
# ✓ [210/503] FCX    -> FULL HOLD + ADD      $54.00
# ✓ [211/503] GEV    -> FULL HOLD + ADD      $679.31
# ✓ [214/503] GE     -> FULL HOLD + ADD      $325.75
# ✓ [217/503] GD     -> FULL HOLD + ADD      $355.51
# ✓ [218/503] GM     -> FULL HOLD + ADD      $83.31
# ✓ [220/503] GILD   -> FULL HOLD + ADD      $118.10
# ✓ [223/503] GL     -> FULL HOLD + ADD      $140.49
# ✓ [224/503] GS     -> FULL HOLD + ADD      $954.92
# ✓ [225/503] HAS    -> FULL HOLD + ADD      $85.81
# ✓ [226/503] HSIC   -> FULL HOLD + ADD      $77.91
# ✓ [227/503] HCA    -> FULL HOLD + ADD      $474.89
# ✓ [228/503] HIG    -> FULL HOLD + ADD      $137.89
# ✓ [232/503] HPE    -> FULL HOLD + ADD      $23.98
# ✓ [233/503] HLT    -> FULL HOLD + ADD      $286.35
# ✓ [234/503] HSY    -> FULL HOLD + ADD      $181.04
# ✓ [237/503] HWM    -> FULL HOLD + ADD      $213.25
# ✓ [238/503] HST    -> FULL HOLD + ADD      $18.24
# ✓ [241/503] HUBB   -> FULL HOLD + ADD      $465.26
# ✓ [242/503] HBAN   -> FULL HOLD + ADD      $17.95
# ✓ [243/503] HII    -> FULL HOLD + ADD      $362.80
# ✓ [245/503] IBM    -> FULL HOLD + ADD      $295.86
# ✓ [247/503] IDXX   -> FULL HOLD + ADD      $682.22
# ✓ [250/503] INCY   -> FULL HOLD + ADD      $101.70
# ✓ [252/503] INTC   -> FULL HOLD + ADD      $39.29
# ✓ [257/503] ISRG   -> FULL HOLD + ADD      $566.38
# ✓ [260/503] IVZ    -> FULL HOLD + ADD      $28.23
# ✓ [262/503] JBHT   -> FULL HOLD + ADD      $202.77
# ✓ [263/503] JBL    -> FULL HOLD + ADD      $222.62
# ✓ [264/503] IQV    -> FULL HOLD + ADD      $233.68
# ✓ [265/503] JKHY   -> FULL HOLD + ADD      $181.54
# ✓ [267/503] JNJ    -> FULL HOLD + ADD      $203.47
# ✓ [269/503] JCI    -> FULL HOLD + ADD      $122.09
# ✓ [271/503] KEYS   -> FULL HOLD + ADD      $208.12
# ✓ [272/503] JPM    -> FULL HOLD + ADD      $336.09
# ✓ [273/503] KKR    -> FULL HOLD + ADD      $135.12
# ✓ [274/503] KMI    -> FULL HOLD + ADD      $27.82
# ✓ [276/503] KEY    -> FULL HOLD + ADD      $21.48
# ✓ [279/503] KLAC   -> FULL HOLD + ADD      $1349.38
# ✓ [282/503] LHX    -> FULL HOLD + ADD      $311.30
# ✓ [284/503] LRCX   -> FULL HOLD + ADD      $194.54
# ✓ [285/503] LVS    -> FULL HOLD + ADD      $64.94
# ✓ [288/503] LLY    -> FULL HOLD + ADD      $1041.23
# ✓ [292/503] LMT    -> FULL HOLD + ADD      $509.96
# ✓ [293/503] LOW    -> FULL HOLD + ADD      $245.35
# ✓ [294/503] L      -> FULL HOLD + ADD      $105.81
# ✓ [297/503] MTB    -> FULL HOLD + ADD      $209.74
# ✓ [299/503] MAR    -> FULL HOLD + ADD      $312.11
# ✓ [300/503] MLM    -> FULL HOLD + ADD      $642.44
# ✓ [303/503] MA     -> FULL HOLD + ADD      $572.29
# ✓ [306/503] MCD    -> FULL HOLD + ADD      $300.25
# ✓ [307/503] MCK    -> FULL HOLD + ADD      $822.00
# ✓ [309/503] MTD    -> FULL HOLD + ADD      $1441.04
# ✓ [311/503] MDT    -> FULL HOLD + ADD      $97.24
# ✓ [312/503] MET    -> FULL HOLD + ADD      $82.42
# ✓ [314/503] MU     -> FULL HOLD + ADD      $310.50
# ✓ [322/503] MNST   -> FULL HOLD + ADD      $75.27
# ✓ [323/503] MPWR   -> FULL HOLD + ADD      $949.72
# ✓ [324/503] MCO    -> FULL HOLD + ADD      $531.13
# ✓ [325/503] MS     -> FULL HOLD + ADD      $187.42
# ✓ [326/503] MSCI   -> FULL HOLD + ADD      $583.32
# ✓ [330/503] NDAQ   -> FULL HOLD + ADD      $98.60
# ✓ [332/503] NEM    -> FULL HOLD + ADD      $103.79
# ✓ [338/503] NDSN   -> FULL HOLD + ADD      $246.03
# ✓ [339/503] NSC    -> FULL HOLD + ADD      $289.50
# ✓ [341/503] NTRS   -> FULL HOLD + ADD      $144.12
# ✓ [344/503] NOC    -> FULL HOLD + ADD      $606.97
# ✓ [345/503] NUE    -> FULL HOLD + ADD      $167.97
# ✓ [346/503] NVDA   -> FULL HOLD + ADD      $186.55
# ✓ [350/503] NXPI   -> FULL HOLD + ADD      $224.17
# ✓ [356/503] PLTR   -> FULL HOLD + ADD      $174.53
# ✓ [357/503] PCAR   -> FULL HOLD + ADD      $112.77
# ✓ [359/503] PKG    -> FULL HOLD + ADD      $211.18
# ✓ [364/503] PH     -> FULL HOLD + ADD      $911.30
# ✓ [370/503] PNC    -> FULL HOLD + ADD      $216.94
# ✓ [377/503] PFG    -> FULL HOLD + ADD      $90.90
# ✓ [378/503] PLD    -> FULL HOLD + ADD      $130.33
# ✓ [380/503] PRU    -> FULL HOLD + ADD      $117.71
# ✓ [385/503] PWR    -> FULL HOLD + ADD      $436.90
# ✓ [387/503] RL     -> FULL HOLD + ADD      $360.94
# ✓ [389/503] QCOM   -> FULL HOLD + ADD      $175.73
# ✓ [390/503] RJF    -> FULL HOLD + ADD      $167.98
# ✓ [391/503] RTX    -> FULL HOLD + ADD      $188.07
# ✓ [392/503] RF     -> FULL HOLD + ADD      $28.34
# ✓ [400/503] ROK    -> FULL HOLD + ADD      $405.68
# ✓ [402/503] ROL    -> FULL HOLD + ADD      $59.27
# ✓ [403/503] ROST   -> FULL HOLD + ADD      $186.26
# ✓ [406/503] SNDK   -> FULL HOLD + ADD      $268.52
# ✓ [407/503] SPGI   -> FULL HOLD + ADD      $535.97
# ✓ [411/503] STX    -> FULL HOLD + ADD      $287.35
# ✓ [416/503] SPG    -> FULL HOLD + ADD      $184.94
# ✓ [417/503] SNA    -> FULL HOLD + ADD      $354.33
# ✓ [419/503] SOLV   -> FULL HOLD + ADD      $81.09
# ✓ [420/503] LUV    -> FULL HOLD + ADD      $42.53
# ✓ [424/503] STT    -> FULL HOLD + ADD      $134.14
# ✓ [425/503] STLD   -> FULL HOLD + ADD      $172.91
# ✓ [427/503] STE    -> FULL HOLD + ADD      $256.60
# ✓ [428/503] SYF    -> FULL HOLD + ADD      $87.19
# ✓ [431/503] TTWO   -> FULL HOLD + ADD      $257.88
# ✓ [433/503] TPR    -> FULL HOLD + ADD      $129.54
# ✓ [434/503] TROW   -> FULL HOLD + ADD      $106.63
# ✓ [435/503] TRGP   -> FULL HOLD + ADD      $183.74
# ✓ [438/503] TEL    -> FULL HOLD + ADD      $230.78
# ✓ [440/503] TSLA   -> FULL HOLD + ADD      $454.67
# ✓ [441/503] TER    -> FULL HOLD + ADD      $218.13
# ✓ [443/503] TJX    -> FULL HOLD + ADD      $153.60
# ✓ [444/503] TMO    -> FULL HOLD + ADD      $606.28
# ✓ [446/503] TXT    -> FULL HOLD + ADD      $89.31
# ✓ [449/503] TRV    -> FULL HOLD + ADD      $290.11
# ✓ [450/503] TKO    -> FULL HOLD + ADD      $203.25
# ✓ [454/503] TRMB   -> FULL HOLD + ADD      $79.39
# ✓ [456/503] USB    -> FULL HOLD + ADD      $55.67
# ✓ [458/503] ULTA   -> FULL HOLD + ADD      $633.25
# ✓ [459/503] TFC    -> FULL HOLD + ADD      $50.65
# ✓ [461/503] UNP    -> FULL HOLD + ADD      $233.25
# ✓ [463/503] UAL    -> FULL HOLD + ADD      $115.32
# ✓ [466/503] UHS    -> FULL HOLD + ADD      $221.91
# ✓ [469/503] VTR    -> FULL HOLD + ADD      $77.07
# ✓ [472/503] VTRS   -> FULL HOLD + ADD      $12.36
# ✓ [476/503] V      -> FULL HOLD + ADD      $355.77
# ✓ [478/503] WAB    -> FULL HOLD + ADD      $217.24
# ✓ [482/503] WBD    -> FULL HOLD + ADD      $28.66
# ✓ [484/503] WMT    -> FULL HOLD + ADD      $113.22
# ✓ [485/503] WAT    -> FULL HOLD + ADD      $394.99
# ✓ [487/503] WFC    -> FULL HOLD + ADD      $96.61
# ✓ [489/503] WELL   -> FULL HOLD + ADD      $185.92
# ✓ [490/503] WDC    -> FULL HOLD + ADD      $186.62
# ✓ [495/503] WTW    -> FULL HOLD + ADD      $334.87
# ✓ [496/503] WMB    -> FULL HOLD + ADD      $61.08
# ✓ [498/503] WYNN   -> FULL HOLD + ADD      $120.84
# ✓ [500/503] YUM    -> FULL HOLD + ADD      $149.90
# ================================================================================
#
# ✓ Scan complete: 502 analyzed, 202 FULL HOLD + ADD signals found
#
#
# ✓ Scan completed in 96.6 seconds

# %% [markdown]
# ## Cell 3: Filter and Display Results by Confluence

# %%
# Filter for FULL HOLD + ADD signals
buy_df = filter_buy_signals(results_df, 'FULL HOLD + ADD')

print(f"{'='*80}")
print(f"🎯 FULL HOLD + ADD SIGNALS: {len(buy_df)} stocks")
print(f"{'='*80}\n")

# Breakdown by confluence
print("📊 Breakdown by Confluence:")
confluence_counts = buy_df['confluence'].value_counts()
for conf, count in confluence_counts.items():
    print(f"  {conf:12s}: {count:3d} stocks")

# Save to workspace scanner_results folder
results_dir = Path.cwd() / 'scanner_results'
results_dir.mkdir(exist_ok=True)

timestamp = datetime.now().strftime("%Y%m%d_%H%M")
excel_path = results_dir / f'sp500_analysis_{timestamp}.xlsx'
pdf_path = results_dir / f'scanner_report_{timestamp}.pdf'

# Generate Excel
create_excel_output(buy_df, excel_path)
print(f"\n✓ Excel saved to: {excel_path}")

# Generate PDF
print(f"\n📄 Creating PDF research document...")
create_pdf_report(buy_df, results_df, pdf_path, timestamp)
print(f"✓ PDF saved to: {pdf_path}")

# Cleanup old scans (keep 7 most recent, archive rest)
print("\n📁 Managing scan history...")
cleanup_old_scans(results_dir, max_files=7)
# Out:
# ================================================================================
# 🎯 FULL HOLD + ADD SIGNALS: 202 stocks
# ================================================================================
#
# 📊 Breakdown by Confluence:
#   WEAK        : 138 stocks
#   EXTENDED    :  39 stocks
#   BALANCED    :  25 stocks
# ✓ Excel file created: c:\workspace\my_script_project\scanner_results\sp500_analysis_20260105_2103.xlsx
#   - All: 202 stocks
#   - Balanced: 25 stocks
#   - Extended: 39 stocks
#   - Weak: 138 stocks
#
# ✓ Excel saved to: c:\workspace\my_script_project\scanner_results\sp500_analysis_20260105_2103.xlsx
#
# 📄 Creating PDF research document...
# ✓ PDF report created: c:\workspace\my_script_project\scanner_results\scanner_report_20260105_2103.pdf
#   - 25 BALANCED stocks detailed
#   - 39 EXTENDED stocks in watch list
# ✓ PDF saved to: c:\workspace\my_script_project\scanner_results\scanner_report_20260105_2103.pdf
#
# 📁 Managing scan history...

# %% [markdown]
# ## Cell 4: Display BALANCED Stocks (Priority Buy List)

# %%
# Filter for BALANCED confluence only
balanced_df = buy_df[buy_df['confluence'] == 'BALANCED'].copy()
balanced_df = balanced_df.sort_values('ticker')

print(f"🎯 BALANCED STOCKS (Priority Buy Candidates): {len(balanced_df)}\n")

if not balanced_df.empty:
    # Display key columns
    display_cols = ['ticker', 'current_price', 'recommendation', 'd50', 'd200', 'w10', 'w200']
    available_cols = [col for col in display_cols if col in balanced_df.columns]
    
    print(balanced_df[available_cols].to_string(index=False))
    
    print(f"\n✅ These {len(balanced_df)} stocks have:")
    print("  ✓ FULL HOLD + ADD signal (Weekly P1 + Daily P1)")
    print("  ✓ BALANCED confluence (healthy technical setup)")
    print("  ✓ 'Enter on Dip' recommendation")
else:
    print("No BALANCED stocks found in this scan.")
# Out:
# 🎯 BALANCED STOCKS (Priority Buy Candidates): 25
#
# ticker  current_price recommendation        d50       d200        w10       w200
#   AAPL       266.5830   Enter on Dip 272.927306 231.961426 273.241919 192.075811
#    ALL       205.6500   Enter on Dip 204.372413 200.652723 207.069797 152.023959
#   AMGN       319.6400   Enter on Dip 323.189772 294.274142 328.813226 261.673271
#  BRK-B       500.2500   Enter on Dip 498.314832 497.789557 501.965158 395.114157
#   CBOE       250.2600   Enter on Dip 251.678799 236.577324 253.331001 172.121504
#    CEG       355.5400   Enter on Dip 360.477316 313.337904 354.762369 173.915560
#   CINF       162.4716   Enter on Dip 162.205866 150.710768 163.947443 118.919189
#   CSCO        75.7850   Enter on Dip  75.465330  67.039646  76.260978  51.473406
#   CTRA        25.6900   Enter on Dip  25.748594  24.727640  26.217453  24.481066
#     EW        84.2500   Enter on Dip  84.379800  78.079850  85.285001  81.407850
#    EXE       105.9700   Enter on Dip 112.466108 106.296730 113.516422  86.068663
#    HSY       181.0450   Enter on Dip 179.939282 174.247023 182.083870 191.145470
#    IBM       295.8600   Enter on Dip 303.791978 269.977237 302.540381 177.720620
#   IDXX       682.2150   Enter on Dip 696.517697 583.953875 703.649500 486.466824
#    LVS        64.9400   Enter on Dip  64.761454  50.482517  65.758590  46.531841
#    MCD       300.2550   Enter on Dip 306.614111 303.335600 307.666437 269.831551
#   MPWR       949.7150   Enter on Dip 956.098876 795.780888 934.401752 606.515616
#   PLTR       174.5328   Enter on Dip 180.916556 151.483139 176.507001  51.395350
#    PWR       436.9050   Enter on Dip 442.549889 379.282906 440.297098 242.227966
#    STE       256.6000   Enter on Dip 254.718800 240.104951 258.321999 215.659556
#   TRMB        79.3950   Enter on Dip  79.908099  75.977575  79.749499  62.072375
#    UHS       221.9150   Enter on Dip 226.182371 193.489100 227.944200 160.555580
#    VTR        77.0700   Enter on Dip  77.038946  68.465088  78.121726  51.599678
#   WELL       185.9200   Enter on Dip 191.081729 165.586998 192.849609 105.639555
#   WYNN       120.8400   Enter on Dip 124.208966 107.082767 123.927114  90.692612
#
# ✅ These 25 stocks have:
#   ✓ FULL HOLD + ADD signal (Weekly P1 + Daily P1)
#   ✓ BALANCED confluence (healthy technical setup)
#   ✓ 'Enter on Dip' recommendation

# %% [markdown]
# ## Cell 5: Display EXTENDED Stocks (Watch List)

# %%
# Filter for EXTENDED confluence
extended_df = buy_df[buy_df['confluence'] == 'EXTENDED'].copy()
extended_df = extended_df.sort_values('ticker')

print(f"⏳ EXTENDED STOCKS (Wait for Pullback): {len(extended_df)}\n")

if not extended_df.empty:
    display_cols = ['ticker', 'current_price', 'recommendation', 'd50', 'd200']
    available_cols = [col for col in display_cols if col in extended_df.columns]
    
    # Show first 20
    print(extended_df[available_cols].head(20).to_string(index=False))
    
    if len(extended_df) > 20:
        print(f"\n... and {len(extended_df) - 20} more (see Excel file)")
    
    print(f"\n⚠️ These stocks have strong signals but are technically overbought.")
    print("  → Wait for pullback to support before entering")
else:
    print("No EXTENDED stocks found.")
# Out:
# ⏳ EXTENDED STOCKS (Wait for Pullback): 39
#
# ticker  current_price   recommendation        d50       d200
#   ACGL        94.7600 Wait for Support  92.031200  91.305400
#   AMZN       232.9300 Wait for Support 231.825800 217.215450
#    APH       139.6800 Wait for Support 136.630449 107.053555
#    AXP       380.7400 Wait for Support 365.804067 316.685991
#    CAH       205.6750 Wait for Support 198.561030 162.192933
#   CBRE       163.9350 Wait for Support 157.930700 145.898325
#    CME       274.5550 Wait for Support 272.467766 269.330497
#    CRH       128.4400 Wait for Support 119.777801 105.144963
#   CTSH        81.8550 Wait for Support  77.404719  74.245567
#    CVS        80.3700 Wait for Support  78.768200  70.199586
#     DG       138.0300 Wait for Support 115.699600 105.662801
#   EXPD       154.5700 Wait for Support 141.720193 121.840211
#   EXPE       287.2900 Wait for Support 257.713495 202.829519
#      F        13.4655 Wait for Support  13.165866  11.311818
#   FSLR       270.4000 Wait for Support 260.116601 195.751751
#    HIG       137.8900 Wait for Support 132.723345 127.143730
#    HPE        23.9800 Wait for Support  23.212052  20.478828
#    HST        18.2400 Wait for Support  17.220949  15.700410
#   INTC        39.2900 Wait for Support  38.056802  27.598050
#   ISRG       566.3750 Wait for Support 560.362904 511.735275
#
# ... and 19 more (see Excel file)
#
# ⚠️ These stocks have strong signals but are technically overbought.
#   → Wait for pullback to support before entering

# %% [markdown]
# ## Cell 6: Compare with Current Holdings (stocks.txt)

# %%
from technical_analysis import parse_stocks_file

# Load current holdings
stocks_file = Path.cwd() / 'stocks.txt'
individual_tickers, baskets = parse_stocks_file(stocks_file)

# Find BALANCED stocks NOT in your portfolio
balanced_tickers = set(balanced_df['ticker'].tolist())
current_tickers = set(individual_tickers)
new_opportunities = balanced_tickers - current_tickers

print(f"📋 Current Portfolio: {len(current_tickers)} stocks")
print(f"🎯 BALANCED Opportunities: {len(balanced_tickers)} stocks")
print(f"\n✨ NEW BALANCED Stocks (not in your portfolio): {len(new_opportunities)}\n")

if new_opportunities:
    new_df = balanced_df[balanced_df['ticker'].isin(new_opportunities)].sort_values('ticker')
    display_cols = ['ticker', 'current_price', 'd50', 'd200', 'w10', 'w200']
    available_cols = [col for col in display_cols if col in new_df.columns]
    print(new_df[available_cols].to_string(index=False))
    print(f"\n💡 Consider adding these {len(new_opportunities)} stocks to stocks.txt for detailed analysis")
else:
    print("All BALANCED opportunities are already in your portfolio!")

# Check which current holdings are also BALANCED
holdings_balanced = balanced_tickers & current_tickers
print(f"\n✅ Current holdings that are BALANCED: {len(holdings_balanced)}")
if holdings_balanced:
    print(f"   {', '.join(sorted(holdings_balanced))}")
# Out:
# 📋 Current Portfolio: 13 stocks
# 🎯 BALANCED Opportunities: 25 stocks
#
# ✨ NEW BALANCED Stocks (not in your portfolio): 24
#
# ticker  current_price        d50       d200        w10       w200
#   AAPL       266.5830 272.927306 231.961426 273.241919 192.075811
#    ALL       205.6500 204.372413 200.652723 207.069797 152.023959
#   AMGN       319.6400 323.189772 294.274142 328.813226 261.673271
#  BRK-B       500.2500 498.314832 497.789557 501.965158 395.114157
#   CBOE       250.2600 251.678799 236.577324 253.331001 172.121504
#    CEG       355.5400 360.477316 313.337904 354.762369 173.915560
#   CINF       162.4716 162.205866 150.710768 163.947443 118.919189
#   CSCO        75.7850  75.465330  67.039646  76.260978  51.473406
#   CTRA        25.6900  25.748594  24.727640  26.217453  24.481066
#     EW        84.2500  84.379800  78.079850  85.285001  81.407850
#    EXE       105.9700 112.466108 106.296730 113.516422  86.068663
#    HSY       181.0450 179.939282 174.247023 182.083870 191.145470
#    IBM       295.8600 303.791978 269.977237 302.540381 177.720620
#   IDXX       682.2150 696.517697 583.953875 703.649500 486.466824
#    LVS        64.9400  64.761454  50.482517  65.758590  46.531841
#    MCD       300.2550 306.614111 303.335600 307.666437 269.831551
#   MPWR       949.7150 956.098876 795.780888 934.401752 606.515616
#    PWR       436.9050 442.549889 379.282906 440.297098 242.227966
#    STE       256.6000 254.718800 240.104951 258.321999 215.659556
#   TRMB        79.3950  79.908099  75.977575  79.749499  62.072375
#    UHS       221.9150 226.182371 193.489100 227.944200 160.555580
#    VTR        77.0700  77.038946  68.465088  78.121726  51.599678
#   WELL       185.9200 191.081729 165.586998 192.849609 105.639555
#   WYNN       120.8400 124.208966 107.082767 123.927114  90.692612
#
# 💡 Consider adding these 24 stocks to stocks.txt for detailed analysis
#
# ✅ Current holdings that are BALANCED: 1
#    PLTR

# %% [markdown]
# ## Cell 7: Overall Signal Distribution

# %%
print("📊 Complete S&P 500 Signal Distribution:\n")
print(results_df['signal'].value_counts().to_string())

print(f"\n\n{'='*80}")
print("Summary")
print(f"{'='*80}")
print(f"Total S&P 500 stocks analyzed: {len(results_df)}")
print(f"FULL HOLD + ADD signals: {len(buy_df)}")
print(f"  ├─ BALANCED (buy now): {len(buy_df[buy_df['confluence'] == 'BALANCED'])}")
print(f"  ├─ EXTENDED (watch): {len(buy_df[buy_df['confluence'] == 'EXTENDED'])}")
print(f"  └─ WEAK (skip): {len(buy_df[buy_df['confluence'] == 'WEAK'])}")
print(f"\nExcel file: {excel_path}")
print(f"PDF report: {pdf_path}")
# Out:
# 📊 Complete S&P 500 Signal Distribution:
#
# signal
# FULL HOLD + ADD       202
# HOLD MOST → REDUCE     76
# FULL CASH / DEFEND     72
# CASH                   56
# REDUCE                 35
# HOLD                   34
# SCALE IN               20
# LIGHT / CASH            7
#
#
# ================================================================================
# Summary
# ================================================================================
# Total S&P 500 stocks analyzed: 502
# FULL HOLD + ADD signals: 202
#   ├─ BALANCED (buy now): 25
#   ├─ EXTENDED (watch): 39
#   └─ WEAK (skip): 138
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 12
#      10 print(f"  ├─ EXTENDED (watch): {len(buy_df[buy_df['confluence'] == 'EXTENDED'])}")
#      11 print(f"  └─ WEAK (skip): {len(buy_df[buy_df['confluence'] == 'WEAK'])}")
# ---> 12 print(f"\nExcel file: {output_path}")
#
# NameError: name 'output_path' is not defined
