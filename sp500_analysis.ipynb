# %% [markdown]
# ## Cell 1: Environment Setup

# %%
from pathlib import Path
from datetime import datetime
import pandas as pd
import importlib

# Import and reload scanner module (ensures latest code changes are used)
import sp500_scanner
importlib.reload(sp500_scanner)
from sp500_scanner import get_sp500_tickers, scan_sp500, filter_buy_signals, create_excel_output, create_pdf_report, cleanup_old_scans

print("✓ Imports complete")
print(f"Ready to scan S&P 500 as of {datetime.now().strftime('%Y-%m-%d %H:%M')}")
# Out:
# ✓ Imports complete
# Ready to scan S&P 500 as of 2026-01-05 22:38

# %% [markdown]
# ## Cell 2: Run Full S&P 500 Scan
#
# **This will take 5-10 minutes to complete.**
#
# Parameters:
# - `daily_bars=60` - 60 days of daily data
# - `weekly_bars=52` - 52 weeks of weekly data
# - `concurrency=15` - 15 parallel threads (adjust if needed)

# %%
# Run the scan
start_time = datetime.now()
print(f"🔍 Starting S&P 500 scan at {start_time.strftime('%H:%M:%S')}...\n")

results_df = scan_sp500(daily_bars=60, weekly_bars=52, concurrency=15)

elapsed = (datetime.now() - start_time).total_seconds()
print(f"\n✓ Scan completed in {elapsed:.1f} seconds")
# Out:
# 🔍 Starting S&P 500 scan at 22:38:51...
#
# Fetching S&P 500 ticker list...
# ✓ Loaded 503 S&P 500 tickers
#
# Found 503 S&P 500 stocks
#
# 🔍 Scanning 503 stocks for 'FULL HOLD + ADD' signals...
# Parameters: 60 daily bars, 52 weekly bars, 15 threads
# ================================================================================
# ✓ [1/503] ABBV   -> FULL HOLD + ADD      $220.18
# ✓ [5/503] ALB    -> FULL HOLD + ADD      $146.13
# ✓ [10/503] AFL    -> FULL HOLD + ADD      $112.19
# ✓ [18/503] GOOGL  -> FULL HOLD + ADD      $316.54
# ✓ [19/503] GOOG   -> FULL HOLD + ADD      $317.32
# ✓ [20/503] ALL    -> FULL HOLD + ADD      $205.57
# ✓ [25/503] AXP    -> FULL HOLD + ADD      $379.80
# ✓ [26/503] AMZN   -> FULL HOLD + ADD      $233.06
# ✓ [29/503] AIG    -> FULL HOLD + ADD      $84.38
# ✓ [32/503] AME    -> FULL HOLD + ADD      $211.31
# ✓ [33/503] APH    -> FULL HOLD + ADD      $139.88
# ✓ [34/503] AMGN   -> FULL HOLD + ADD      $320.72
# ✓ [35/503] APP    -> FULL HOLD + ADD      $632.91
# ✓ [36/503] AAPL   -> FULL HOLD + ADD      $267.26
# ✓ [37/503] APO    -> FULL HOLD + ADD      $149.76
# ✓ [39/503] ADI    -> FULL HOLD + ADD      $277.29
# ✓ [40/503] AMAT   -> FULL HOLD + ADD      $284.32
# ✓ [43/503] ARES   -> FULL HOLD + ADD      $172.05
# ✓ [44/503] ACGL   -> FULL HOLD + ADD      $94.44
# ✓ [48/503] AIZ    -> FULL HOLD + ADD      $240.42
#   [50/503] Scanning...
# ✓ [59/503] BAC    -> FULL HOLD + ADD      $56.89
# ✓ [64/503] BRK-B  -> FULL HOLD + ADD      $498.52
# ✓ [69/503] BK     -> FULL HOLD + ADD      $121.04
# ✓ [72/503] BKNG   -> FULL HOLD + ADD      $5367.37
# ✓ [82/503] CHRW   -> FULL HOLD + ADD      $167.21
# ✓ [86/503] COF    -> FULL HOLD + ADD      $250.51
# ✓ [87/503] CCL    -> FULL HOLD + ADD      $31.49
# ✓ [88/503] CAH    -> FULL HOLD + ADD      $205.45
# ✓ [89/503] CVNA   -> FULL HOLD + ADD      $430.06
# ✓ [90/503] CBRE   -> FULL HOLD + ADD      $164.40
# ✓ [91/503] CBOE   -> FULL HOLD + ADD      $252.11
# ✓ [93/503] COR    -> FULL HOLD + ADD      $340.92
# ✓ [95/503] CAT    -> FULL HOLD + ADD      $616.10
# ✓ [99/503] SCHW   -> FULL HOLD + ADD      $103.74
#   [100/503] Scanning...
# ✓ [101/503] CB     -> FULL HOLD + ADD      $315.19
# ✓ [102/503] CVX    -> FULL HOLD + ADD      $163.85
# ✓ [106/503] C      -> FULL HOLD + ADD      $123.30
# ✓ [107/503] CINF   -> FULL HOLD + ADD      $161.96
# ✓ [108/503] CFG    -> FULL HOLD + ADD      $61.05
# ✓ [109/503] CSCO   -> FULL HOLD + ADD      $75.58
# ✓ [110/503] CME    -> FULL HOLD + ADD      $275.06
# ✓ [114/503] KO     -> FULL HOLD + ADD      $67.94
# ✓ [116/503] CTSH   -> FULL HOLD + ADD      $81.63
# ✓ [119/503] FIX    -> FULL HOLD + ADD      $1032.31
# ✓ [124/503] CEG    -> FULL HOLD + ADD      $354.94
# ✓ [127/503] GLW    -> FULL HOLD + ADD      $88.69
# ✓ [131/503] CTRA   -> FULL HOLD + ADD      $25.82
# ✓ [134/503] CRH    -> FULL HOLD + ADD      $128.31
# ✓ [138/503] CSX    -> FULL HOLD + ADD      $35.91
# ✓ [139/503] CVS    -> FULL HOLD + ADD      $80.42
# ✓ [140/503] CMI    -> FULL HOLD + ADD      $531.70
# ✓ [141/503] DAY    -> FULL HOLD + ADD      $69.34
# ✓ [146/503] DAL    -> FULL HOLD + ADD      $71.82
#   [150/503] Scanning...
# ✓ [152/503] DG     -> FULL HOLD + ADD      $138.93
# ✓ [153/503] DLTR   -> FULL HOLD + ADD      $128.57
# ✓ [159/503] DOV    -> FULL HOLD + ADD      $202.27
# ✓ [164/503] DD     -> FULL HOLD + ADD      $42.01
# ✓ [167/503] EA     -> FULL HOLD + ADD      $204.36
# ✓ [169/503] EW     -> FULL HOLD + ADD      $84.17
# ✓ [171/503] EMR    -> FULL HOLD + ADD      $142.85
# ✓ [185/503] EXE    -> FULL HOLD + ADD      $106.82
# ✓ [187/503] EXPE   -> FULL HOLD + ADD      $287.47
# ✓ [188/503] XOM    -> FULL HOLD + ADD      $125.36
# ✓ [189/503] EXPD   -> FULL HOLD + ADD      $154.40
# ✓ [194/503] FDX    -> FULL HOLD + ADD      $297.46
# ✓ [195/503] FRT    -> FULL HOLD + ADD      $99.56
# ✓ [198/503] FITB   -> FULL HOLD + ADD      $48.62
# ✓ [199/503] FSLR   -> FULL HOLD + ADD      $272.00
#   [200/503] Scanning...
# ✓ [202/503] FOX    -> FULL HOLD + ADD      $67.76
# ✓ [205/503] FOXA   -> FULL HOLD + ADD      $75.67
# ✓ [206/503] F      -> FULL HOLD + ADD      $13.47
# ✓ [207/503] BEN    -> FULL HOLD + ADD      $24.49
# ✓ [208/503] FCX    -> FULL HOLD + ADD      $54.41
# ✓ [209/503] GEV    -> FULL HOLD + ADD      $680.86
# ✓ [213/503] GE     -> FULL HOLD + ADD      $324.32
# ✓ [216/503] GM     -> FULL HOLD + ADD      $83.15
# ✓ [217/503] GD     -> FULL HOLD + ADD      $355.56
# ✓ [221/503] GILD   -> FULL HOLD + ADD      $118.30
# ✓ [222/503] GL     -> FULL HOLD + ADD      $140.63
# ✓ [224/503] GS     -> FULL HOLD + ADD      $948.44
# ✓ [225/503] HIG    -> FULL HOLD + ADD      $137.75
# ✓ [228/503] HCA    -> FULL HOLD + ADD      $477.83
# ✓ [230/503] HAS    -> FULL HOLD + ADD      $85.58
# ✓ [231/503] HSY    -> FULL HOLD + ADD      $179.99
# ✓ [232/503] HPE    -> FULL HOLD + ADD      $24.13
# ✓ [233/503] HLT    -> FULL HOLD + ADD      $285.77
# ✓ [237/503] HST    -> FULL HOLD + ADD      $18.12
# ✓ [238/503] HWM    -> FULL HOLD + ADD      $212.92
# ✓ [240/503] HUBB   -> FULL HOLD + ADD      $465.48
# ✓ [241/503] HII    -> FULL HOLD + ADD      $363.48
# ✓ [244/503] IBM    -> FULL HOLD + ADD      $294.97
# ✓ [245/503] HBAN   -> FULL HOLD + ADD      $17.88
# ✓ [247/503] IDXX   -> FULL HOLD + ADD      $682.23
# ✓ [248/503] INCY   -> FULL HOLD + ADD      $101.79
#   [250/503] Scanning...
# ✓ [251/503] INTC   -> FULL HOLD + ADD      $39.37
# ✓ [257/503] ISRG   -> FULL HOLD + ADD      $566.38
# ✓ [259/503] IVZ    -> FULL HOLD + ADD      $28.16
# ✓ [260/503] IQV    -> FULL HOLD + ADD      $234.59
# ✓ [263/503] JBL    -> FULL HOLD + ADD      $223.44
# ✓ [264/503] JKHY   -> FULL HOLD + ADD      $181.46
# ✓ [265/503] JBHT   -> FULL HOLD + ADD      $202.02
# ✓ [267/503] JPM    -> FULL HOLD + ADD      $334.04
# ✓ [268/503] JNJ    -> FULL HOLD + ADD      $204.31
# ✓ [269/503] JCI    -> FULL HOLD + ADD      $121.53
# ✓ [271/503] KEY    -> FULL HOLD + ADD      $21.37
# ✓ [274/503] KEYS   -> FULL HOLD + ADD      $208.82
# ✓ [276/503] KMI    -> FULL HOLD + ADD      $27.90
# ✓ [277/503] KKR    -> FULL HOLD + ADD      $134.57
# ✓ [278/503] KLAC   -> FULL HOLD + ADD      $1352.45
# ✓ [281/503] LHX    -> FULL HOLD + ADD      $311.38
# ✓ [283/503] LRCX   -> FULL HOLD + ADD      $194.76
# ✓ [285/503] LVS    -> FULL HOLD + ADD      $64.64
# ✓ [291/503] LLY    -> FULL HOLD + ADD      $1041.51
# ✓ [292/503] LMT    -> FULL HOLD + ADD      $511.57
# ✓ [293/503] LOW    -> FULL HOLD + ADD      $244.75
# ✓ [294/503] L      -> FULL HOLD + ADD      $105.67
# ✓ [297/503] MAR    -> FULL HOLD + ADD      $311.03
# ✓ [298/503] MTB    -> FULL HOLD + ADD      $209.45
# ✓ [300/503] MLM    -> FULL HOLD + ADD      $642.00
# ✓ [303/503] MA     -> FULL HOLD + ADD      $568.57
# ✓ [305/503] MCK    -> FULL HOLD + ADD      $824.92
# ✓ [308/503] MCD    -> FULL HOLD + ADD      $299.86
# ✓ [310/503] MET    -> FULL HOLD + ADD      $81.77
# ✓ [311/503] MDT    -> FULL HOLD + ADD      $97.36
# ✓ [312/503] MTD    -> FULL HOLD + ADD      $1446.63
# ✓ [317/503] MU     -> FULL HOLD + ADD      $312.15
# ✓ [320/503] MCO    -> FULL HOLD + ADD      $526.88
# ✓ [322/503] MPWR   -> FULL HOLD + ADD      $955.03
# ✓ [323/503] MNST   -> FULL HOLD + ADD      $75.67
# ✓ [325/503] MS     -> FULL HOLD + ADD      $186.54
# ✓ [327/503] MSCI   -> FULL HOLD + ADD      $577.60
# ✓ [330/503] NDAQ   -> FULL HOLD + ADD      $98.45
# ✓ [332/503] NEM    -> FULL HOLD + ADD      $103.53
# ✓ [337/503] NSC    -> FULL HOLD + ADD      $287.92
# ✓ [338/503] NTRS   -> FULL HOLD + ADD      $144.00
# ✓ [339/503] NDSN   -> FULL HOLD + ADD      $245.89
# ✓ [341/503] NOC    -> FULL HOLD + ADD      $611.32
# ✓ [343/503] NXPI   -> FULL HOLD + ADD      $223.88
# ✓ [347/503] NVDA   -> FULL HOLD + ADD      $188.12
# ✓ [348/503] NUE    -> FULL HOLD + ADD      $168.13
#   [350/503] Scanning...
# ✓ [356/503] PCAR   -> FULL HOLD + ADD      $112.92
# ✓ [357/503] PKG    -> FULL HOLD + ADD      $211.13
# ✓ [358/503] PLTR   -> FULL HOLD + ADD      $174.04
# ✓ [364/503] PH     -> FULL HOLD + ADD      $906.89
# ✓ [370/503] PNC    -> FULL HOLD + ADD      $215.80
# ✓ [376/503] PFG    -> FULL HOLD + ADD      $90.51
# ✓ [378/503] PRU    -> FULL HOLD + ADD      $117.36
# ✓ [379/503] PLD    -> FULL HOLD + ADD      $129.69
# ✓ [385/503] PWR    -> FULL HOLD + ADD      $435.82
# ✓ [388/503] QCOM   -> FULL HOLD + ADD      $176.31
# ✓ [389/503] RL     -> FULL HOLD + ADD      $358.52
# ✓ [390/503] RTX    -> FULL HOLD + ADD      $188.26
# ✓ [394/503] RF     -> FULL HOLD + ADD      $28.27
# ✓ [396/503] RJF    -> FULL HOLD + ADD      $167.33
# ✓ [400/503] ROK    -> FULL HOLD + ADD      $404.73
# ✓ [401/503] ROL    -> FULL HOLD + ADD      $58.93
# ✓ [403/503] SNDK   -> FULL HOLD + ADD      $274.08
# ✓ [405/503] ROST   -> FULL HOLD + ADD      $186.68
# ✓ [407/503] SPGI   -> FULL HOLD + ADD      $532.90
# ✓ [410/503] STX    -> FULL HOLD + ADD      $289.83
# ✓ [415/503] SOLV   -> FULL HOLD + ADD      $80.80
# ✓ [417/503] SPG    -> FULL HOLD + ADD      $183.11
# ✓ [420/503] SNA    -> FULL HOLD + ADD      $354.20
# ✓ [421/503] LUV    -> FULL HOLD + ADD      $42.44
# ✓ [424/503] STLD   -> FULL HOLD + ADD      $171.83
# ✓ [425/503] STE    -> FULL HOLD + ADD      $256.75
# ✓ [426/503] STT    -> FULL HOLD + ADD      $133.01
# ✓ [429/503] SYF    -> FULL HOLD + ADD      $86.74
# ✓ [433/503] TROW   -> FULL HOLD + ADD      $106.49
# ✓ [434/503] TTWO   -> FULL HOLD + ADD      $257.31
# ✓ [435/503] TPR    -> FULL HOLD + ADD      $128.53
# ✓ [436/503] TRGP   -> FULL HOLD + ADD      $183.47
# ✓ [439/503] TER    -> FULL HOLD + ADD      $219.50
# ✓ [440/503] TEL    -> FULL HOLD + ADD      $231.40
# ✓ [442/503] TXT    -> FULL HOLD + ADD      $89.00
# ✓ [443/503] TSLA   -> FULL HOLD + ADD      $451.67
# ✓ [446/503] TKO    -> FULL HOLD + ADD      $203.65
# ✓ [447/503] TMO    -> FULL HOLD + ADD      $611.20
# ✓ [450/503] TRV    -> FULL HOLD + ADD      $287.76
# ✓ [451/503] TJX    -> FULL HOLD + ADD      $153.84
# ✓ [453/503] TRMB   -> FULL HOLD + ADD      $79.27
# ✓ [454/503] TFC    -> FULL HOLD + ADD      $50.48
# ✓ [457/503] USB    -> FULL HOLD + ADD      $55.49
# ✓ [459/503] ULTA   -> FULL HOLD + ADD      $631.15
# ✓ [461/503] UNP    -> FULL HOLD + ADD      $231.97
# ✓ [462/503] UHS    -> FULL HOLD + ADD      $222.87
# ✓ [466/503] UAL    -> FULL HOLD + ADD      $114.89
# ✓ [467/503] VTR    -> FULL HOLD + ADD      $76.44
# ✓ [476/503] VTRS   -> FULL HOLD + ADD      $12.37
# ✓ [477/503] V      -> FULL HOLD + ADD      $353.80
# ✓ [482/503] WMT    -> FULL HOLD + ADD      $112.71
# ✓ [483/503] WBD    -> FULL HOLD + ADD      $28.53
# ✓ [485/503] WAB    -> FULL HOLD + ADD      $217.01
# ✓ [486/503] WAT    -> FULL HOLD + ADD      $394.97
# ✓ [488/503] WFC    -> FULL HOLD + ADD      $96.38
# ✓ [489/503] WELL   -> FULL HOLD + ADD      $184.73
# ✓ [491/503] WDC    -> FULL HOLD + ADD      $187.88
# ✓ [494/503] WYNN   -> FULL HOLD + ADD      $119.68
# ✓ [496/503] YUM    -> FULL HOLD + ADD      $150.29
# ✓ [497/503] WTW    -> FULL HOLD + ADD      $334.60
# ✓ [499/503] WMB    -> FULL HOLD + ADD      $61.16
#   [500/503] Scanning...
# ================================================================================
#
# ✓ Scan complete: 502 analyzed, 201 FULL HOLD + ADD signals found
#
#
# ✓ Scan completed in 107.8 seconds

# %% [markdown]
# ## Cell 3: Filter and Display Results by Confluence

# %%
# Filter for FULL HOLD + ADD signals
buy_df = filter_buy_signals(results_df, 'FULL HOLD + ADD')

print(f"{'='*80}")
print(f"🎯 FULL HOLD + ADD SIGNALS: {len(buy_df)} stocks")
print(f"{'='*80}\n")

# Breakdown by confluence
print("📊 Breakdown by Confluence:")
confluence_counts = buy_df['confluence'].value_counts()
for conf, count in confluence_counts.items():
    print(f"  {conf:12s}: {count:3d} stocks")

# Save to workspace scanner_results folder
results_dir = Path.cwd() / 'scanner_results'
results_dir.mkdir(exist_ok=True)

timestamp = datetime.now().strftime("%Y%m%d_%H%M")
excel_path = results_dir / f'sp500_analysis_{timestamp}.xlsx'
pdf_path = results_dir / f'scanner_report_{timestamp}.pdf'

# Generate Excel
create_excel_output(buy_df, excel_path)
print(f"\n✓ Excel saved to: {excel_path}")

# Generate PDF
print(f"\n📄 Creating PDF research document...")
create_pdf_report(buy_df, results_df, pdf_path, timestamp)
print(f"✓ PDF saved to: {pdf_path}")

# Cleanup old scans (keep 1 most recent, archive rest)
print("\n📁 Managing scan history...")
cleanup_old_scans(results_dir, max_files=1)
# Out:
# ================================================================================
# 🎯 FULL HOLD + ADD SIGNALS: 201 stocks
# ================================================================================
#
# 📊 Breakdown by Confluence:
#   WEAK        : 130 stocks
#   EXTENDED    :  48 stocks
#   BALANCED    :  23 stocks
# ✓ Excel file created: c:\workspace\my_script_project\scanner_results\sp500_analysis_20260105_2240.xlsx
#   - All: 201 stocks
#   - Balanced: 23 stocks
#   - Extended: 48 stocks
#   - Weak: 130 stocks
#
# ✓ Excel saved to: c:\workspace\my_script_project\scanner_results\sp500_analysis_20260105_2240.xlsx
#
# 📄 Creating PDF research document...
# ✓ PDF report created: c:\workspace\my_script_project\scanner_results\scanner_report_20260105_2240.pdf
#   - 23 BALANCED stocks detailed
#   - 48 EXTENDED stocks in watch list
# ✓ PDF saved to: c:\workspace\my_script_project\scanner_results\scanner_report_20260105_2240.pdf
#
# 📁 Managing scan history...
#   📦 Archived: sp500_analysis_20260105_2226.xlsx
#   📦 Archived: sp500_analysis_20260105_2207.xlsx
#   📦 Archived: sp500_analysis_20260105_2103.xlsx
#   📦 Archived: sp500_analysis_20260105_1945.xlsx
#   📦 Archived: scanner_report_20260105_2226.pdf
#   📦 Archived: scanner_report_20260105_2207.pdf
#   📦 Archived: scanner_report_20260105_2103.pdf
#   📦 Archived: scanner_report_20260105_2057.pdf
#   ✅ Archived 8 file(s), kept 1 most recent

# %% [markdown]
# ## Cell 4: Display BALANCED Stocks (Priority Buy List)

# %%
# Filter for BALANCED confluence only
balanced_df = buy_df[buy_df['confluence'] == 'BALANCED'].copy()
balanced_df = balanced_df.sort_values('ticker')

print(f"🎯 BALANCED STOCKS (Priority Buy Candidates): {len(balanced_df)}\n")

if not balanced_df.empty:
    # Display key columns
    display_cols = ['ticker', 'current_price', 'recommendation', 'd50', 'd200', 'w10', 'w200']
    available_cols = [col for col in display_cols if col in balanced_df.columns]
    
    print(balanced_df[available_cols].to_string(index=False))
    
    print(f"\n✅ These {len(balanced_df)} stocks have:")
    print("  ✓ FULL HOLD + ADD signal (Weekly P1 + Daily P1)")
    print("  ✓ BALANCED confluence (healthy technical setup)")
    print("  ✓ 'Enter on Dip' recommendation")
else:
    print("No BALANCED stocks found in this scan.")
# Out:
# 🎯 BALANCED STOCKS (Priority Buy Candidates): 23
#
# ticker  current_price recommendation        d50       d200        w10       w200
#   AAPL         267.26   Enter on Dip 272.940846 231.964811 273.594434 191.501618
#   AMGN         320.72   Enter on Dip 323.211371 294.279542 326.479382 261.091445
#  BRK-B         498.52   Enter on Dip 498.280000 497.780849 499.692999 394.245849
#   CBOE         252.11   Enter on Dip 251.715800 236.586574 252.869002 171.415324
#    CEG         354.94   Enter on Dip 360.465316 313.334904 356.867160 172.377178
#   CINF         161.96   Enter on Dip 162.195634 150.708210 163.078886 118.656421
#   CSCO          75.58   Enter on Dip  75.461230  67.038620  75.954564  51.337482
#     EW          84.17   Enter on Dip  84.378200  78.079450  85.105000  81.503850
#    EXE         106.82   Enter on Dip 112.483108 106.300980 113.200696  85.873113
#   GILD         118.30   Enter on Dip 122.147535 112.444059 122.189639  79.935261
#    HSY         179.99   Enter on Dip 179.918182 174.241748 180.812688 191.171457
#    IBM         294.97   Enter on Dip 303.772977 269.972487 303.520816 176.776665
#   IDXX         682.23   Enter on Dip 696.517996 583.953949 698.378998 485.546148
#    LVS          64.64   Enter on Dip  64.755454  50.481016  65.175554  46.381016
#    MCD         299.86   Enter on Dip 306.606210 303.333625 307.305923 269.371157
#   MPWR         955.03   Enter on Dip 956.205176 795.807462 939.760559 603.686429
#   PLTR         174.04   Enter on Dip 180.906700 151.480675 179.099001  50.579550
#    PWR         435.82   Enter on Dip 442.528189 379.277481 441.507892 240.656087
#   TRMB          79.27   Enter on Dip  79.905599  75.976950  79.784999  62.002750
#    UHS         222.87   Enter on Dip 226.201471 193.493875 227.435886 160.184954
#    VTR          76.44   Enter on Dip  77.026346  68.461938  77.748807  51.469063
#   WELL         184.73   Enter on Dip 191.057928 165.581048 192.291191 105.124827
#   WYNN         119.68   Enter on Dip 124.185766 107.076967 123.717474  90.439882
#
# ✅ These 23 stocks have:
#   ✓ FULL HOLD + ADD signal (Weekly P1 + Daily P1)
#   ✓ BALANCED confluence (healthy technical setup)
#   ✓ 'Enter on Dip' recommendation

# %% [markdown]
# ## Cell 5: Display EXTENDED Stocks (Watch List)

# %%
# Filter for EXTENDED confluence
extended_df = buy_df[buy_df['confluence'] == 'EXTENDED'].copy()
extended_df = extended_df.sort_values('ticker')

print(f"⏳ EXTENDED STOCKS (Wait for Pullback): {len(extended_df)}\n")

if not extended_df.empty:
    display_cols = ['ticker', 'current_price', 'recommendation', 'd50', 'd200']
    available_cols = [col for col in display_cols if col in extended_df.columns]
    
    # Show first 20
    print(extended_df[available_cols].head(20).to_string(index=False))
    
    if len(extended_df) > 20:
        print(f"\n... and {len(extended_df) - 20} more (see Excel file)")
    
    print(f"\n⚠️ These stocks have strong signals but are technically overbought.")
    print("  → Wait for pullback to support before entering")
else:
    print("No EXTENDED stocks found.")
# Out:
# ⏳ EXTENDED STOCKS (Wait for Pullback): 48
#
# ticker  current_price   recommendation        d50       d200
#   ACGL          94.44 Wait for Support  92.024800  91.303800
#    AIZ         240.42 Wait for Support 226.028422 206.790342
#   AMZN         233.06 Wait for Support 231.828401 217.216100
#    APH         139.88 Wait for Support 136.634449 107.054555
#    AXP         379.80 Wait for Support 365.784266 316.681041
#    CAH         205.45 Wait for Support 198.556530 162.191808
#     CB         315.19 Wait for Support 297.325400 285.489081
#    CCL          31.49 Wait for Support  27.741200  26.361200
#    CME         275.06 Wait for Support 272.477866 269.333022
#    CRH         128.31 Wait for Support 119.775201 105.144313
#   CTSH          81.63 Wait for Support  77.400219  74.244442
#    CVS          80.42 Wait for Support  78.769200  70.199836
#     DG         138.93 Wait for Support 115.717600 105.667301
#   EXPD         154.40 Wait for Support 141.716793 121.839361
#   EXPE         287.47 Wait for Support 257.717095 202.830419
#      F          13.47 Wait for Support  13.165866  11.311818
#   FSLR         272.00 Wait for Support 260.148601 195.759751
#    GLW          88.69 Wait for Support  86.529627  65.438066
#    HIG         137.75 Wait for Support 132.720545 127.143031
#    HPE          24.13 Wait for Support  23.215052  20.479578
#
# ... and 28 more (see Excel file)
#
# ⚠️ These stocks have strong signals but are technically overbought.
#   → Wait for pullback to support before entering

# %% [markdown]
# ## Cell 6: Overall Signal Distribution

# %%
print("📊 Complete S&P 500 Signal Distribution:\n")
print(results_df['signal'].value_counts().to_string())

print(f"\n\n{'='*80}")
print("Summary")
print(f"{'='*80}")
print(f"Total S&P 500 stocks analyzed: {len(results_df)}")
print(f"FULL HOLD + ADD signals: {len(buy_df)}")
print(f"  ├─ BALANCED (buy now): {len(buy_df[buy_df['confluence'] == 'BALANCED'])}")
print(f"  ├─ EXTENDED (watch): {len(buy_df[buy_df['confluence'] == 'EXTENDED'])}")
print(f"  └─ WEAK (skip): {len(buy_df[buy_df['confluence'] == 'WEAK'])}")
print(f"\nExcel file: {excel_path}")
print(f"PDF report: {pdf_path}")
# Out:
# 📊 Complete S&P 500 Signal Distribution:
#
# signal
# FULL HOLD + ADD       201
# HOLD MOST → REDUCE     79
# FULL CASH / DEFEND     72
# CASH                   52
# REDUCE                 36
# HOLD                   34
# SCALE IN               21
# LIGHT / CASH            7
#
#
# ================================================================================
# Summary
# ================================================================================
# Total S&P 500 stocks analyzed: 502
# FULL HOLD + ADD signals: 201
#   ├─ BALANCED (buy now): 23
#   ├─ EXTENDED (watch): 48
#   └─ WEAK (skip): 130
#
# Excel file: c:\workspace\my_script_project\scanner_results\sp500_analysis_20260105_2240.xlsx
# PDF report: c:\workspace\my_script_project\scanner_results\scanner_report_20260105_2240.pdf
