# %% [markdown]
# ## Cell 1: Environment Setup

# %%
from pathlib import Path
from datetime import datetime
import pandas as pd
import importlib

# Import and reload scanner module (ensures latest code changes are used)
import sp500_scanner
importlib.reload(sp500_scanner)
from sp500_scanner import get_sp500_tickers, scan_sp500, filter_buy_signals, create_excel_output, create_pdf_report, cleanup_old_scans

print("✓ Imports complete")
print(f"Ready to scan S&P 500 as of {datetime.now().strftime('%Y-%m-%d %H:%M')}")
# Out:
# ✓ Imports complete
# Ready to scan S&P 500 as of 2026-01-05 22:05

# %% [markdown]
# ## Cell 2: Run Full S&P 500 Scan
#
# **This will take 5-10 minutes to complete.**
#
# Parameters:
# - `daily_bars=60` - 60 days of daily data
# - `weekly_bars=52` - 52 weeks of weekly data
# - `concurrency=15` - 15 parallel threads (adjust if needed)

# %%
# Run the scan
start_time = datetime.now()
print(f"🔍 Starting S&P 500 scan at {start_time.strftime('%H:%M:%S')}...\n")

results_df = scan_sp500(daily_bars=60, weekly_bars=52, concurrency=15)

elapsed = (datetime.now() - start_time).total_seconds()
print(f"\n✓ Scan completed in {elapsed:.1f} seconds")
# Out:
# 🔍 Starting S&P 500 scan at 22:05:30...
#
# Fetching S&P 500 ticker list...
# ✓ Loaded 503 S&P 500 tickers
#
# Found 503 S&P 500 stocks
#
# 🔍 Scanning 503 stocks for 'FULL HOLD + ADD' signals...
# Parameters: 60 daily bars, 52 weekly bars, 15 threads
# ================================================================================
# ✓ [4/503] ALB    -> FULL HOLD + ADD      $146.11
# ✓ [7/503] ABBV   -> FULL HOLD + ADD      $220.18
# ✓ [14/503] AFL    -> FULL HOLD + ADD      $112.12
# ✓ [18/503] GOOG   -> FULL HOLD + ADD      $317.32
# ✓ [19/503] ALL    -> FULL HOLD + ADD      $205.64
# ✓ [24/503] GOOGL  -> FULL HOLD + ADD      $316.54
# ✓ [25/503] AXP    -> FULL HOLD + ADD      $379.83
# ✓ [26/503] AIG    -> FULL HOLD + ADD      $84.37
# ✓ [28/503] AMZN   -> FULL HOLD + ADD      $233.06
# ✓ [32/503] ADI    -> FULL HOLD + ADD      $277.29
# ✓ [33/503] AME    -> FULL HOLD + ADD      $211.38
# ✓ [34/503] AMGN   -> FULL HOLD + ADD      $320.72
# ✓ [35/503] APH    -> FULL HOLD + ADD      $139.89
# ✓ [36/503] APO    -> FULL HOLD + ADD      $149.76
# ✓ [37/503] AAPL   -> FULL HOLD + ADD      $267.26
# ✓ [40/503] AMAT   -> FULL HOLD + ADD      $284.32
# ✓ [41/503] APP    -> FULL HOLD + ADD      $632.91
# ✓ [42/503] ACGL   -> FULL HOLD + ADD      $94.44
# ✓ [44/503] ARES   -> FULL HOLD + ADD      $172.12
# ✓ [48/503] AIZ    -> FULL HOLD + ADD      $240.37
#   [50/503] Scanning...
# ✓ [60/503] BAC    -> FULL HOLD + ADD      $56.89
# ✓ [61/503] BRK-B  -> FULL HOLD + ADD      $498.56
# ✓ [69/503] BK     -> FULL HOLD + ADD      $121.03
# ✓ [73/503] BKNG   -> FULL HOLD + ADD      $5367.37
# ✓ [82/503] CHRW   -> FULL HOLD + ADD      $167.21
# ✓ [86/503] CAH    -> FULL HOLD + ADD      $205.47
# ✓ [87/503] COF    -> FULL HOLD + ADD      $250.52
# ✓ [88/503] CCL    -> FULL HOLD + ADD      $31.50
# ✓ [89/503] CVNA   -> FULL HOLD + ADD      $430.17
# ✓ [90/503] CBOE   -> FULL HOLD + ADD      $251.83
# ✓ [91/503] CBRE   -> FULL HOLD + ADD      $164.36
# ✓ [93/503] COR    -> FULL HOLD + ADD      $341.07
# ✓ [94/503] CAT    -> FULL HOLD + ADD      $616.65
# ✓ [99/503] SCHW   -> FULL HOLD + ADD      $103.74
#   [100/503] Scanning...
# ✓ [101/503] CVX    -> FULL HOLD + ADD      $163.89
# ✓ [103/503] CB     -> FULL HOLD + ADD      $315.22
# ✓ [106/503] C      -> FULL HOLD + ADD      $123.31
# ✓ [107/503] CINF   -> FULL HOLD + ADD      $161.96
# ✓ [108/503] CSCO   -> FULL HOLD + ADD      $75.58
# ✓ [110/503] CME    -> FULL HOLD + ADD      $275.06
# ✓ [111/503] CFG    -> FULL HOLD + ADD      $61.08
# ✓ [114/503] CTSH   -> FULL HOLD + ADD      $81.63
# ✓ [117/503] KO     -> FULL HOLD + ADD      $67.97
# ✓ [118/503] FIX    -> FULL HOLD + ADD      $1031.73
# ✓ [122/503] CEG    -> FULL HOLD + ADD      $354.94
# ✓ [128/503] GLW    -> FULL HOLD + ADD      $88.69
# ✓ [131/503] CTRA   -> FULL HOLD + ADD      $25.84
# ✓ [134/503] CRH    -> FULL HOLD + ADD      $128.32
# ✓ [136/503] CSX    -> FULL HOLD + ADD      $35.91
# ✓ [137/503] CMI    -> FULL HOLD + ADD      $531.81
# ✓ [140/503] CVS    -> FULL HOLD + ADD      $80.42
# ✓ [143/503] DAY    -> FULL HOLD + ADD      $69.33
# ✓ [144/503] DAL    -> FULL HOLD + ADD      $71.84
# ✓ [150/503] DLTR   -> FULL HOLD + ADD      $128.57
# ✓ [152/503] DG     -> FULL HOLD + ADD      $138.93
# ✓ [155/503] DOV    -> FULL HOLD + ADD      $202.38
# ✓ [162/503] DD     -> FULL HOLD + ADD      $42.02
# ✓ [167/503] EW     -> FULL HOLD + ADD      $84.18
# ✓ [168/503] EA     -> FULL HOLD + ADD      $204.36
# ✓ [170/503] EMR    -> FULL HOLD + ADD      $142.86
# ✓ [182/503] EXE    -> FULL HOLD + ADD      $106.82
# ✓ [187/503] EXPE   -> FULL HOLD + ADD      $287.47
# ✓ [189/503] EXPD   -> FULL HOLD + ADD      $154.33
# ✓ [191/503] XOM    -> FULL HOLD + ADD      $125.39
# ✓ [195/503] FRT    -> FULL HOLD + ADD      $99.58
# ✓ [196/503] FDX    -> FULL HOLD + ADD      $297.59
# ✓ [197/503] FSLR   -> FULL HOLD + ADD      $272.00
# ✓ [199/503] FITB   -> FULL HOLD + ADD      $48.62
#   [200/503] Scanning...
# ✓ [202/503] F      -> FULL HOLD + ADD      $13.46
# ✓ [205/503] FOXA   -> FULL HOLD + ADD      $75.67
# ✓ [206/503] FOX    -> FULL HOLD + ADD      $67.76
# ✓ [207/503] FCX    -> FULL HOLD + ADD      $54.41
# ✓ [208/503] BEN    -> FULL HOLD + ADD      $24.48
# ✓ [212/503] GEV    -> FULL HOLD + ADD      $680.64
# ✓ [214/503] GE     -> FULL HOLD + ADD      $324.28
# ✓ [216/503] GD     -> FULL HOLD + ADD      $355.65
# ✓ [218/503] GM     -> FULL HOLD + ADD      $83.14
# ✓ [219/503] GILD   -> FULL HOLD + ADD      $118.30
# ✓ [223/503] GL     -> FULL HOLD + ADD      $140.65
# ✓ [224/503] GS     -> FULL HOLD + ADD      $948.82
# ✓ [225/503] HIG    -> FULL HOLD + ADD      $137.63
# ✓ [227/503] HCA    -> FULL HOLD + ADD      $477.77
# ✓ [228/503] HAS    -> FULL HOLD + ADD      $85.58
# ✓ [231/503] HPE    -> FULL HOLD + ADD      $24.13
# ✓ [232/503] HSY    -> FULL HOLD + ADD      $179.92
# ✓ [236/503] HLT    -> FULL HOLD + ADD      $285.82
# ✓ [238/503] HST    -> FULL HOLD + ADD      $18.12
# ✓ [239/503] HWM    -> FULL HOLD + ADD      $212.91
# ✓ [240/503] HUBB   -> FULL HOLD + ADD      $465.91
# ✓ [243/503] HBAN   -> FULL HOLD + ADD      $17.88
# ✓ [244/503] HII    -> FULL HOLD + ADD      $363.58
# ✓ [245/503] IDXX   -> FULL HOLD + ADD      $682.23
# ✓ [246/503] IBM    -> FULL HOLD + ADD      $294.96
# ✓ [250/503] INCY   -> FULL HOLD + ADD      $101.79
# ✓ [252/503] INTC   -> FULL HOLD + ADD      $39.37
# ✓ [258/503] ISRG   -> FULL HOLD + ADD      $566.38
# ✓ [260/503] IQV    -> FULL HOLD + ADD      $234.64
# ✓ [261/503] IVZ    -> FULL HOLD + ADD      $28.16
# ✓ [262/503] JBL    -> FULL HOLD + ADD      $223.42
# ✓ [264/503] JBHT   -> FULL HOLD + ADD      $202.02
# ✓ [265/503] JKHY   -> FULL HOLD + ADD      $181.46
# ✓ [266/503] JNJ    -> FULL HOLD + ADD      $204.30
# ✓ [269/503] JCI    -> FULL HOLD + ADD      $121.49
# ✓ [271/503] JPM    -> FULL HOLD + ADD      $334.15
# ✓ [272/503] KEYS   -> FULL HOLD + ADD      $208.80
# ✓ [273/503] KEY    -> FULL HOLD + ADD      $21.36
# ✓ [276/503] KKR    -> FULL HOLD + ADD      $134.60
# ✓ [277/503] KMI    -> FULL HOLD + ADD      $27.91
# ✓ [280/503] KLAC   -> FULL HOLD + ADD      $1352.45
# ✓ [281/503] LRCX   -> FULL HOLD + ADD      $194.76
# ✓ [282/503] LHX    -> FULL HOLD + ADD      $311.47
# ✓ [285/503] LVS    -> FULL HOLD + ADD      $64.60
# ✓ [289/503] LLY    -> FULL HOLD + ADD      $1041.44
# ✓ [292/503] L      -> FULL HOLD + ADD      $105.66
# ✓ [294/503] LMT    -> FULL HOLD + ADD      $511.46
# ✓ [296/503] LOW    -> FULL HOLD + ADD      $244.76
# ✓ [298/503] MTB    -> FULL HOLD + ADD      $209.51
# ✓ [300/503] MLM    -> FULL HOLD + ADD      $642.01
# ✓ [301/503] MAR    -> FULL HOLD + ADD      $311.03
# ✓ [303/503] MA     -> FULL HOLD + ADD      $568.95
# ✓ [305/503] MCD    -> FULL HOLD + ADD      $299.82
# ✓ [307/503] MCK    -> FULL HOLD + ADD      $824.66
# ✓ [308/503] MDT    -> FULL HOLD + ADD      $97.39
# ✓ [311/503] MTD    -> FULL HOLD + ADD      $1446.61
# ✓ [312/503] MET    -> FULL HOLD + ADD      $81.78
# ✓ [321/503] MNST   -> FULL HOLD + ADD      $75.67
# ✓ [322/503] MS     -> FULL HOLD + ADD      $186.56
# ✓ [323/503] MPWR   -> FULL HOLD + ADD      $955.03
# ✓ [325/503] MCO    -> FULL HOLD + ADD      $526.90
# ✓ [327/503] MSCI   -> FULL HOLD + ADD      $577.64
# ✓ [329/503] NEM    -> FULL HOLD + ADD      $103.57
# ✓ [333/503] NDSN   -> FULL HOLD + ADD      $245.89
# ✓ [337/503] NOC    -> FULL HOLD + ADD      $611.34
# ✓ [338/503] NTRS   -> FULL HOLD + ADD      $144.00
# ✓ [340/503] NSC    -> FULL HOLD + ADD      $288.03
# ✓ [343/503] NUE    -> FULL HOLD + ADD      $168.18
# ✓ [344/503] MU     -> FULL HOLD + ADD      $312.15
# ✓ [345/503] NVDA   -> FULL HOLD + ADD      $188.12
# ✓ [346/503] NXPI   -> FULL HOLD + ADD      $223.88
#   [350/503] Scanning...
# ✓ [355/503] PLTR   -> FULL HOLD + ADD      $174.04
# ✓ [356/503] PCAR   -> FULL HOLD + ADD      $112.92
# ✓ [358/503] PKG    -> FULL HOLD + ADD      $211.18
# ✓ [360/503] PH     -> FULL HOLD + ADD      $906.89
# ✓ [370/503] PNC    -> FULL HOLD + ADD      $215.88
# ✓ [375/503] PFG    -> FULL HOLD + ADD      $90.51
# ✓ [378/503] PRU    -> FULL HOLD + ADD      $117.39
# ✓ [379/503] PLD    -> FULL HOLD + ADD      $129.72
# ✓ [384/503] PWR    -> FULL HOLD + ADD      $435.77
# ✓ [385/503] QCOM   -> FULL HOLD + ADD      $176.31
# ✓ [388/503] RL     -> FULL HOLD + ADD      $358.32
# ✓ [389/503] RJF    -> FULL HOLD + ADD      $167.19
# ✓ [392/503] RTX    -> FULL HOLD + ADD      $188.27
# ✓ [393/503] RF     -> FULL HOLD + ADD      $28.27
# ✓ [400/503] ROL    -> FULL HOLD + ADD      $58.94
# ✓ [401/503] ROK    -> FULL HOLD + ADD      $404.83
# ✓ [402/503] ROST   -> FULL HOLD + ADD      $186.68
# ✓ [404/503] SNDK   -> FULL HOLD + ADD      $274.08
# ✓ [405/503] SPGI   -> FULL HOLD + ADD      $533.05
# ✓ [411/503] NDAQ   -> FULL HOLD + ADD      $98.45
# ✓ [412/503] STX    -> FULL HOLD + ADD      $289.83
# ✓ [414/503] SPG    -> FULL HOLD + ADD      $183.19
# ✓ [415/503] SOLV   -> FULL HOLD + ADD      $80.79
# ✓ [419/503] SNA    -> FULL HOLD + ADD      $354.12
# ✓ [420/503] LUV    -> FULL HOLD + ADD      $42.44
# ✓ [423/503] STE    -> FULL HOLD + ADD      $256.55
# ✓ [425/503] STLD   -> FULL HOLD + ADD      $171.83
# ✓ [426/503] STT    -> FULL HOLD + ADD      $132.98
# ✓ [429/503] SYF    -> FULL HOLD + ADD      $86.68
# ✓ [431/503] TTWO   -> FULL HOLD + ADD      $257.31
# ✓ [434/503] TROW   -> FULL HOLD + ADD      $106.49
# ✓ [435/503] TPR    -> FULL HOLD + ADD      $128.52
# ✓ [437/503] TER    -> FULL HOLD + ADD      $219.50
# ✓ [439/503] TEL    -> FULL HOLD + ADD      $231.45
# ✓ [440/503] TRGP   -> FULL HOLD + ADD      $183.47
# ✓ [441/503] TSLA   -> FULL HOLD + ADD      $451.67
# ✓ [444/503] TXT    -> FULL HOLD + ADD      $88.96
# ✓ [445/503] TKO    -> FULL HOLD + ADD      $203.66
# ✓ [447/503] TMO    -> FULL HOLD + ADD      $611.41
# ✓ [449/503] TJX    -> FULL HOLD + ADD      $153.84
#   [450/503] Scanning...
# ✓ [452/503] TRV    -> FULL HOLD + ADD      $287.81
# ✓ [454/503] TRMB   -> FULL HOLD + ADD      $79.27
# ✓ [455/503] TFC    -> FULL HOLD + ADD      $50.49
# ✓ [458/503] USB    -> FULL HOLD + ADD      $55.49
# ✓ [459/503] UAL    -> FULL HOLD + ADD      $114.89
# ✓ [462/503] UNP    -> FULL HOLD + ADD      $231.99
# ✓ [464/503] ULTA   -> FULL HOLD + ADD      $631.15
# ✓ [466/503] UHS    -> FULL HOLD + ADD      $222.85
# ✓ [471/503] VTR    -> FULL HOLD + ADD      $76.42
# ✓ [475/503] VTRS   -> FULL HOLD + ADD      $12.37
# ✓ [476/503] V      -> FULL HOLD + ADD      $353.85
# ✓ [480/503] WAB    -> FULL HOLD + ADD      $217.11
# ✓ [482/503] WMT    -> FULL HOLD + ADD      $112.71
# ✓ [484/503] WBD    -> FULL HOLD + ADD      $28.53
# ✓ [486/503] WAT    -> FULL HOLD + ADD      $394.73
# ✓ [488/503] WFC    -> FULL HOLD + ADD      $96.41
# ✓ [489/503] WELL   -> FULL HOLD + ADD      $184.71
# ✓ [491/503] WDC    -> FULL HOLD + ADD      $187.88
# ✓ [493/503] WMB    -> FULL HOLD + ADD      $61.16
# ✓ [496/503] WYNN   -> FULL HOLD + ADD      $119.68
# ✓ [499/503] WTW    -> FULL HOLD + ADD      $334.60
#   [500/503] Scanning...
# ✓ [501/503] YUM    -> FULL HOLD + ADD      $150.28
# ================================================================================
#
# ✓ Scan complete: 502 analyzed, 201 FULL HOLD + ADD signals found
#
#
# ✓ Scan completed in 99.2 seconds

# %% [markdown]
# ## Cell 3: Filter and Display Results by Confluence

# %%
# Filter for FULL HOLD + ADD signals
buy_df = filter_buy_signals(results_df, 'FULL HOLD + ADD')

print(f"{'='*80}")
print(f"🎯 FULL HOLD + ADD SIGNALS: {len(buy_df)} stocks")
print(f"{'='*80}\n")

# Breakdown by confluence
print("📊 Breakdown by Confluence:")
confluence_counts = buy_df['confluence'].value_counts()
for conf, count in confluence_counts.items():
    print(f"  {conf:12s}: {count:3d} stocks")

# Save to workspace scanner_results folder
results_dir = Path.cwd() / 'scanner_results'
results_dir.mkdir(exist_ok=True)

timestamp = datetime.now().strftime("%Y%m%d_%H%M")
excel_path = results_dir / f'sp500_analysis_{timestamp}.xlsx'
pdf_path = results_dir / f'scanner_report_{timestamp}.pdf'

# Generate Excel
create_excel_output(buy_df, excel_path)
print(f"\n✓ Excel saved to: {excel_path}")

# Generate PDF
print(f"\n📄 Creating PDF research document...")
create_pdf_report(buy_df, results_df, pdf_path, timestamp)
print(f"✓ PDF saved to: {pdf_path}")

# Cleanup old scans (keep 7 most recent, archive rest)
print("\n📁 Managing scan history...")
cleanup_old_scans(results_dir, max_files=7)
# Out:
# ================================================================================
# 🎯 FULL HOLD + ADD SIGNALS: 201 stocks
# ================================================================================
#
# 📊 Breakdown by Confluence:
#   WEAK        : 129 stocks
#   EXTENDED    :  49 stocks
#   BALANCED    :  23 stocks
# ✓ Excel file created: c:\workspace\my_script_project\scanner_results\sp500_analysis_20260105_2207.xlsx
#   - All: 201 stocks
#   - Balanced: 23 stocks
#   - Extended: 49 stocks
#   - Weak: 129 stocks
#
# ✓ Excel saved to: c:\workspace\my_script_project\scanner_results\sp500_analysis_20260105_2207.xlsx
#
# 📄 Creating PDF research document...
# ✓ PDF report created: c:\workspace\my_script_project\scanner_results\scanner_report_20260105_2207.pdf
#   - 23 BALANCED stocks detailed
#   - 49 EXTENDED stocks in watch list
# ✓ PDF saved to: c:\workspace\my_script_project\scanner_results\scanner_report_20260105_2207.pdf
#
# 📁 Managing scan history...

# %% [markdown]
# ## Cell 4: Display BALANCED Stocks (Priority Buy List)

# %%
# Filter for BALANCED confluence only
balanced_df = buy_df[buy_df['confluence'] == 'BALANCED'].copy()
balanced_df = balanced_df.sort_values('ticker')

print(f"🎯 BALANCED STOCKS (Priority Buy Candidates): {len(balanced_df)}\n")

if not balanced_df.empty:
    # Display key columns
    display_cols = ['ticker', 'current_price', 'recommendation', 'd50', 'd200', 'w10', 'w200']
    available_cols = [col for col in display_cols if col in balanced_df.columns]
    
    print(balanced_df[available_cols].to_string(index=False))
    
    print(f"\n✅ These {len(balanced_df)} stocks have:")
    print("  ✓ FULL HOLD + ADD signal (Weekly P1 + Daily P1)")
    print("  ✓ BALANCED confluence (healthy technical setup)")
    print("  ✓ 'Enter on Dip' recommendation")
else:
    print("No BALANCED stocks found in this scan.")
# Out:
# 🎯 BALANCED STOCKS (Priority Buy Candidates): 23
#
# ticker  current_price recommendation        d50       d200        w10       w200
#   AAPL        267.260   Enter on Dip 272.940846 231.964810 273.594434 191.501617
#   AMGN        320.720   Enter on Dip 323.211371 294.279543 326.479382 261.091446
#  BRK-B        498.565   Enter on Dip 498.280900 497.781074 499.692999 394.245849
#   CBOE        251.830   Enter on Dip 251.710200 236.585174 252.869002 171.415324
#    CEG        354.940   Enter on Dip 360.465316 313.334904 356.867160 172.377177
#   CINF        161.960   Enter on Dip 162.195634 150.708209 163.078886 118.656421
#   CSCO         75.580   Enter on Dip  75.461230  67.038620  75.954564  51.337482
#     EW         84.180   Enter on Dip  84.378400  78.079500  85.105000  81.503850
#    EXE        106.820   Enter on Dip 112.483108 106.300980 113.200696  85.873114
#   GILD        118.300   Enter on Dip 122.147535 112.444060 122.189639  79.935261
#    HSY        179.920   Enter on Dip 179.916782 174.241398 180.812688 191.171458
#    IBM        294.960   Enter on Dip 303.772777 269.972437 303.520816 176.776666
#   IDXX        682.230   Enter on Dip 696.517996 583.953949 698.378998 485.546148
#    LVS         64.600   Enter on Dip  64.754654  50.480816  65.175554  46.381016
#    MCD        299.825   Enter on Dip 306.605511 303.333449 307.305923 269.371158
#   MPWR        955.030   Enter on Dip 956.205176 795.807460 939.760559 603.686429
#   PLTR        174.040   Enter on Dip 180.906700 151.480675 179.099001  50.579550
#    PWR        435.770   Enter on Dip 442.527189 379.277230 441.507892 240.656089
#   TRMB         79.270   Enter on Dip  79.905599  75.976950  79.784999  62.002750
#    UHS        222.850   Enter on Dip 226.201071 193.493775 227.435886 160.184955
#    VTR         76.425   Enter on Dip  77.026046  68.461863  77.748807  51.469063
#   WELL        184.710   Enter on Dip 191.057529 165.580948 192.291191 105.124826
#   WYNN        119.680   Enter on Dip 124.185766 107.076967 123.717474  90.439882
#
# ✅ These 23 stocks have:
#   ✓ FULL HOLD + ADD signal (Weekly P1 + Daily P1)
#   ✓ BALANCED confluence (healthy technical setup)
#   ✓ 'Enter on Dip' recommendation

# %% [markdown]
# ## Cell 5: Display EXTENDED Stocks (Watch List)

# %%
# Filter for EXTENDED confluence
extended_df = buy_df[buy_df['confluence'] == 'EXTENDED'].copy()
extended_df = extended_df.sort_values('ticker')

print(f"⏳ EXTENDED STOCKS (Wait for Pullback): {len(extended_df)}\n")

if not extended_df.empty:
    display_cols = ['ticker', 'current_price', 'recommendation', 'd50', 'd200']
    available_cols = [col for col in display_cols if col in extended_df.columns]
    
    # Show first 20
    print(extended_df[available_cols].head(20).to_string(index=False))
    
    if len(extended_df) > 20:
        print(f"\n... and {len(extended_df) - 20} more (see Excel file)")
    
    print(f"\n⚠️ These stocks have strong signals but are technically overbought.")
    print("  → Wait for pullback to support before entering")
else:
    print("No EXTENDED stocks found.")
# Out:
# ⏳ EXTENDED STOCKS (Wait for Pullback): 49
#
# ticker  current_price   recommendation        d50       d200
#   ACGL         94.440 Wait for Support  92.024800  91.303800
#    AFL        112.119 Wait for Support 109.937330 106.050442
#    AIZ        240.371 Wait for Support 226.027442 206.790098
#   AMZN        233.060 Wait for Support 231.828401 217.216100
#    APH        139.890 Wait for Support 136.634649 107.054605
#    AXP        379.835 Wait for Support 365.784966 316.681215
#    CAH        205.470 Wait for Support 198.556930 162.191908
#     CB        315.220 Wait for Support 297.326000 285.489231
#    CCL         31.505 Wait for Support  27.741500  26.361275
#    CME        275.060 Wait for Support 272.477866 269.333022
#    CRH        128.325 Wait for Support 119.775500 105.144388
#   CTSH         81.630 Wait for Support  77.400219  74.244442
#    CVS         80.420 Wait for Support  78.769200  70.199836
#     DG        138.930 Wait for Support 115.717600 105.667301
#   EXPD        154.330 Wait for Support 141.715393 121.839011
#   EXPE        287.470 Wait for Support 257.717095 202.830420
#      F         13.465 Wait for Support  13.165766  11.311793
#   FSLR        272.000 Wait for Support 260.148601 195.759751
#    GLW         88.685 Wait for Support  86.529527  65.438041
#    HIG        137.630 Wait for Support 132.718145 127.142431
#
# ... and 29 more (see Excel file)
#
# ⚠️ These stocks have strong signals but are technically overbought.
#   → Wait for pullback to support before entering

# %% [markdown]
# ## Cell 6: Compare with Current Holdings (stocks.txt)

# %%
from technical_analysis import parse_stocks_file

# Load current holdings
stocks_file = Path.cwd() / 'stocks.txt'
individual_tickers, baskets = parse_stocks_file(stocks_file)

# Find BALANCED stocks NOT in your portfolio
balanced_tickers = set(balanced_df['ticker'].tolist())
current_tickers = set(individual_tickers)
new_opportunities = balanced_tickers - current_tickers

print(f"📋 Current Portfolio: {len(current_tickers)} stocks")
print(f"🎯 BALANCED Opportunities: {len(balanced_tickers)} stocks")
print(f"\n✨ NEW BALANCED Stocks (not in your portfolio): {len(new_opportunities)}\n")

if new_opportunities:
    new_df = balanced_df[balanced_df['ticker'].isin(new_opportunities)].sort_values('ticker')
    display_cols = ['ticker', 'current_price', 'd50', 'd200', 'w10', 'w200']
    available_cols = [col for col in display_cols if col in new_df.columns]
    print(new_df[available_cols].to_string(index=False))
    print(f"\n💡 Consider adding these {len(new_opportunities)} stocks to stocks.txt for detailed analysis")
else:
    print("All BALANCED opportunities are already in your portfolio!")

# Check which current holdings are also BALANCED
holdings_balanced = balanced_tickers & current_tickers
print(f"\n✅ Current holdings that are BALANCED: {len(holdings_balanced)}")
if holdings_balanced:
    print(f"   {', '.join(sorted(holdings_balanced))}")
# Out:
# 📋 Current Portfolio: 13 stocks
# 🎯 BALANCED Opportunities: 23 stocks
#
# ✨ NEW BALANCED Stocks (not in your portfolio): 22
#
# ticker  current_price        d50       d200        w10       w200
#   AAPL        267.260 272.940846 231.964810 273.594434 191.501617
#   AMGN        320.720 323.211371 294.279543 326.479382 261.091446
#  BRK-B        498.565 498.280900 497.781074 499.692999 394.245849
#   CBOE        251.830 251.710200 236.585174 252.869002 171.415324
#    CEG        354.940 360.465316 313.334904 356.867160 172.377177
#   CINF        161.960 162.195634 150.708209 163.078886 118.656421
#   CSCO         75.580  75.461230  67.038620  75.954564  51.337482
#     EW         84.180  84.378400  78.079500  85.105000  81.503850
#    EXE        106.820 112.483108 106.300980 113.200696  85.873114
#   GILD        118.300 122.147535 112.444060 122.189639  79.935261
#    HSY        179.920 179.916782 174.241398 180.812688 191.171458
#    IBM        294.960 303.772777 269.972437 303.520816 176.776666
#   IDXX        682.230 696.517996 583.953949 698.378998 485.546148
#    LVS         64.600  64.754654  50.480816  65.175554  46.381016
#    MCD        299.825 306.605511 303.333449 307.305923 269.371158
#   MPWR        955.030 956.205176 795.807460 939.760559 603.686429
#    PWR        435.770 442.527189 379.277230 441.507892 240.656089
#   TRMB         79.270  79.905599  75.976950  79.784999  62.002750
#    UHS        222.850 226.201071 193.493775 227.435886 160.184955
#    VTR         76.425  77.026046  68.461863  77.748807  51.469063
#   WELL        184.710 191.057529 165.580948 192.291191 105.124826
#   WYNN        119.680 124.185766 107.076967 123.717474  90.439882
#
# 💡 Consider adding these 22 stocks to stocks.txt for detailed analysis
#
# ✅ Current holdings that are BALANCED: 1
#    PLTR

# %% [markdown]
# ## Cell 7: Overall Signal Distribution

# %%
print("📊 Complete S&P 500 Signal Distribution:\n")
print(results_df['signal'].value_counts().to_string())

print(f"\n\n{'='*80}")
print("Summary")
print(f"{'='*80}")
print(f"Total S&P 500 stocks analyzed: {len(results_df)}")
print(f"FULL HOLD + ADD signals: {len(buy_df)}")
print(f"  ├─ BALANCED (buy now): {len(buy_df[buy_df['confluence'] == 'BALANCED'])}")
print(f"  ├─ EXTENDED (watch): {len(buy_df[buy_df['confluence'] == 'EXTENDED'])}")
print(f"  └─ WEAK (skip): {len(buy_df[buy_df['confluence'] == 'WEAK'])}")
print(f"\nExcel file: {excel_path}")
print(f"PDF report: {pdf_path}")
# Out:
# 📊 Complete S&P 500 Signal Distribution:
#
# signal
# FULL HOLD + ADD       201
# HOLD MOST → REDUCE     79
# FULL CASH / DEFEND     72
# CASH                   52
# REDUCE                 36
# HOLD                   34
# SCALE IN               21
# LIGHT / CASH            7
#
#
# ================================================================================
# Summary
# ================================================================================
# Total S&P 500 stocks analyzed: 502
# FULL HOLD + ADD signals: 201
#   ├─ BALANCED (buy now): 23
#   ├─ EXTENDED (watch): 49
#   └─ WEAK (skip): 129
#
# Excel file: c:\workspace\my_script_project\scanner_results\sp500_analysis_20260105_2207.xlsx
# PDF report: c:\workspace\my_script_project\scanner_results\scanner_report_20260105_2207.pdf
