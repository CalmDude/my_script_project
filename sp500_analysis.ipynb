# %% [markdown]
# ## Cell 1: Environment Setup

# %%
from pathlib import Path
from datetime import datetime
import pandas as pd
import importlib

# Import and reload scanner module (ensures latest code changes are used)
import sp500_scanner
importlib.reload(sp500_scanner)
from sp500_scanner import get_sp500_tickers, scan_sp500, filter_buy_signals, create_excel_output, create_pdf_report, cleanup_old_scans

print("✓ Imports complete")
print(f"Ready to scan S&P 500 as of {datetime.now().strftime('%Y-%m-%d %H:%M')}")
# Out:
# ✓ Imports complete
# Ready to scan S&P 500 as of 2026-01-05 19:44

# %% [markdown]
# ## Cell 2: Run Full S&P 500 Scan
#
# **This will take 5-10 minutes to complete.**
#
# Parameters:
# - `daily_bars=60` - 60 days of daily data
# - `weekly_bars=52` - 52 weeks of weekly data
# - `concurrency=15` - 15 parallel threads (adjust if needed)

# %%
# Run the scan
start_time = datetime.now()
print(f"🔍 Starting S&P 500 scan at {start_time.strftime('%H:%M:%S')}...\n")

results_df = scan_sp500(daily_bars=60, weekly_bars=52, concurrency=15)

elapsed = (datetime.now() - start_time).total_seconds()
print(f"\n✓ Scan completed in {elapsed:.1f} seconds")
# Out:
# 🔍 Starting S&P 500 scan at 19:29:50...
#
# Fetching S&P 500 ticker list...
# ✓ Loaded 503 S&P 500 tickers
#
# Found 503 S&P 500 stocks
#
# 🔍 Scanning 503 stocks for 'FULL HOLD + ADD' signals...
# Parameters: 60 daily bars, 52 weekly bars, 15 threads
# ================================================================================
# ✓ [9/503] AFL    -> FULL HOLD + ADD      $112.53
# ✓ [10/503] ABBV   -> FULL HOLD + ADD      $219.79
# ✓ [11/503] ALB    -> FULL HOLD + ADD      $147.80
# ✓ [18/503] ALL    -> FULL HOLD + ADD      $205.75
# ✓ [20/503] AMZN   -> FULL HOLD + ADD      $232.64
# ✓ [21/503] GOOG   -> FULL HOLD + ADD      $317.44
# ✓ [26/503] GOOGL  -> FULL HOLD + ADD      $316.89
# ✓ [28/503] AIG    -> FULL HOLD + ADD      $85.39
# ✓ [31/503] AXP    -> FULL HOLD + ADD      $382.22
# ✓ [32/503] AME    -> FULL HOLD + ADD      $211.77
# ✓ [33/503] AMGN   -> FULL HOLD + ADD      $319.33
# ✓ [34/503] APH    -> FULL HOLD + ADD      $140.17
# ✓ [35/503] ADI    -> FULL HOLD + ADD      $278.43
# ✓ [38/503] APP    -> FULL HOLD + ADD      $635.62
# ✓ [39/503] APO    -> FULL HOLD + ADD      $151.34
# ✓ [40/503] AMAT   -> FULL HOLD + ADD      $284.53
# ✓ [42/503] AAPL   -> FULL HOLD + ADD      $267.39
# ✓ [43/503] ACGL   -> FULL HOLD + ADD      $95.23
# ✓ [45/503] ARES   -> FULL HOLD + ADD      $172.27
# ✓ [47/503] AIZ    -> FULL HOLD + ADD      $240.67
#   [50/503] Scanning...
# ✓ [60/503] BAC    -> FULL HOLD + ADD      $57.13
# ✓ [63/503] BRK-B  -> FULL HOLD + ADD      $500.82
# ✓ [69/503] BK     -> FULL HOLD + ADD      $122.03
# ✓ [72/503] BKNG   -> FULL HOLD + ADD      $5417.36
# ✓ [82/503] CHRW   -> FULL HOLD + ADD      $166.89
# ✓ [85/503] COF    -> FULL HOLD + ADD      $252.73
# ✓ [86/503] CCL    -> FULL HOLD + ADD      $31.68
# ✓ [87/503] CAH    -> FULL HOLD + ADD      $206.33
# ✓ [89/503] CVNA   -> FULL HOLD + ADD      $432.20
# ✓ [90/503] CBOE   -> FULL HOLD + ADD      $252.17
# ✓ [91/503] CBRE   -> FULL HOLD + ADD      $163.52
# ✓ [94/503] COR    -> FULL HOLD + ADD      $339.77
# ✓ [95/503] CAT    -> FULL HOLD + ADD      $619.06
# ✓ [99/503] SCHW   -> FULL HOLD + ADD      $104.02
#   [100/503] Scanning...
# ✓ [103/503] CB     -> FULL HOLD + ADD      $315.93
# ✓ [104/503] CVX    -> FULL HOLD + ADD      $164.90
# ✓ [106/503] CME    -> FULL HOLD + ADD      $275.07
# ✓ [108/503] CSCO   -> FULL HOLD + ADD      $75.74
# ✓ [109/503] CFG    -> FULL HOLD + ADD      $61.29
# ✓ [110/503] CINF   -> FULL HOLD + ADD      $162.80
# ✓ [111/503] C      -> FULL HOLD + ADD      $123.80
# ✓ [115/503] CTSH   -> FULL HOLD + ADD      $81.94
# ✓ [117/503] FIX    -> FULL HOLD + ADD      $1036.40
# ✓ [118/503] KO     -> FULL HOLD + ADD      $68.03
# ✓ [120/503] CEG    -> FULL HOLD + ADD      $351.05
# ✓ [128/503] GLW    -> FULL HOLD + ADD      $87.53
# ✓ [133/503] CTRA   -> FULL HOLD + ADD      $25.46
# ✓ [134/503] CRH    -> FULL HOLD + ADD      $127.83
# ✓ [136/503] CSX    -> FULL HOLD + ADD      $36.16
# ✓ [137/503] CVS    -> FULL HOLD + ADD      $80.44
# ✓ [138/503] CMI    -> FULL HOLD + ADD      $530.23
# ✓ [139/503] DAY    -> FULL HOLD + ADD      $69.39
# ✓ [144/503] DAL    -> FULL HOLD + ADD      $72.50
# ✓ [150/503] DLTR   -> FULL HOLD + ADD      $128.30
# ✓ [152/503] DG     -> FULL HOLD + ADD      $137.33
# ✓ [159/503] DOV    -> FULL HOLD + ADD      $202.97
# ✓ [162/503] DD     -> FULL HOLD + ADD      $42.04
# ✓ [164/503] EW     -> FULL HOLD + ADD      $84.17
# ✓ [166/503] EA     -> FULL HOLD + ADD      $204.40
# ✓ [172/503] EMR    -> FULL HOLD + ADD      $142.94
# ✓ [184/503] EXE    -> FULL HOLD + ADD      $104.95
# ✓ [187/503] EXPE   -> FULL HOLD + ADD      $289.23
# ✓ [188/503] EXPD   -> FULL HOLD + ADD      $154.25
# ✓ [192/503] XOM    -> FULL HOLD + ADD      $125.51
# ✓ [195/503] FITB   -> FULL HOLD + ADD      $48.86
# ✓ [196/503] FRT    -> FULL HOLD + ADD      $99.67
# ✓ [197/503] FDX    -> FULL HOLD + ADD      $296.95
#   [200/503] Scanning...
# ✓ [202/503] F      -> FULL HOLD + ADD      $13.43
# ✓ [203/503] FSLR   -> FULL HOLD + ADD      $266.99
# ✓ [205/503] FOX    -> FULL HOLD + ADD      $67.88
# ✓ [206/503] FOXA   -> FULL HOLD + ADD      $75.91
# ✓ [207/503] FCX    -> FULL HOLD + ADD      $54.30
# ✓ [209/503] BEN    -> FULL HOLD + ADD      $24.59
# ✓ [210/503] GE     -> FULL HOLD + ADD      $326.88
# ✓ [212/503] GEV    -> FULL HOLD + ADD      $679.32
# ✓ [216/503] GD     -> FULL HOLD + ADD      $354.12
# ✓ [218/503] GILD   -> FULL HOLD + ADD      $117.72
# ✓ [219/503] GM     -> FULL HOLD + ADD      $83.03
# ✓ [223/503] GS     -> FULL HOLD + ADD      $956.02
# ✓ [224/503] GL     -> FULL HOLD + ADD      $141.17
# ✓ [226/503] HIG    -> FULL HOLD + ADD      $138.23
# ✓ [227/503] HAS    -> FULL HOLD + ADD      $86.36
# ✓ [228/503] HCA    -> FULL HOLD + ADD      $473.76
# ✓ [230/503] HSIC   -> FULL HOLD + ADD      $77.97
# ✓ [231/503] HPE    -> FULL HOLD + ADD      $24.02
# ✓ [232/503] HLT    -> FULL HOLD + ADD      $288.77
# ✓ [233/503] HSY    -> FULL HOLD + ADD      $182.02
# ✓ [237/503] HWM    -> FULL HOLD + ADD      $213.21
# ✓ [239/503] HST    -> FULL HOLD + ADD      $18.20
# ✓ [242/503] HII    -> FULL HOLD + ADD      $363.97
# ✓ [243/503] HUBB   -> FULL HOLD + ADD      $468.19
# ✓ [244/503] IBM    -> FULL HOLD + ADD      $295.04
# ✓ [245/503] HBAN   -> FULL HOLD + ADD      $18.00
# ✓ [247/503] IDXX   -> FULL HOLD + ADD      $676.86
# ✓ [249/503] INCY   -> FULL HOLD + ADD      $102.28
#   [250/503] Scanning...
# ✓ [252/503] INTC   -> FULL HOLD + ADD      $39.52
# ✓ [257/503] ISRG   -> FULL HOLD + ADD      $564.77
# ✓ [259/503] IQV    -> FULL HOLD + ADD      $232.76
# ✓ [260/503] IVZ    -> FULL HOLD + ADD      $28.24
# ✓ [263/503] JBHT   -> FULL HOLD + ADD      $202.87
# ✓ [264/503] JBL    -> FULL HOLD + ADD      $224.73
# ✓ [265/503] JKHY   -> FULL HOLD + ADD      $181.46
# ✓ [266/503] JNJ    -> FULL HOLD + ADD      $203.07
# ✓ [269/503] JPM    -> FULL HOLD + ADD      $336.55
# ✓ [270/503] JCI    -> FULL HOLD + ADD      $123.54
# ✓ [272/503] KEYS   -> FULL HOLD + ADD      $207.83
# ✓ [274/503] KEY    -> FULL HOLD + ADD      $21.51
# ✓ [275/503] KLAC   -> FULL HOLD + ADD      $1357.61
# ✓ [276/503] KKR    -> FULL HOLD + ADD      $135.23
# ✓ [277/503] KMI    -> FULL HOLD + ADD      $27.68
# ✓ [281/503] LHX    -> FULL HOLD + ADD      $310.83
# ✓ [282/503] LRCX   -> FULL HOLD + ADD      $195.81
# ✓ [285/503] LVS    -> FULL HOLD + ADD      $64.75
# ✓ [291/503] LLY    -> FULL HOLD + ADD      $1040.72
# ✓ [292/503] LMT    -> FULL HOLD + ADD      $510.82
# ✓ [293/503] L      -> FULL HOLD + ADD      $106.07
# ✓ [295/503] LOW    -> FULL HOLD + ADD      $246.54
# ✓ [297/503] MAR    -> FULL HOLD + ADD      $313.31
# ✓ [298/503] MTB    -> FULL HOLD + ADD      $210.20
#   [300/503] Scanning...
# ✓ [301/503] MLM    -> FULL HOLD + ADD      $640.73
# ✓ [303/503] MA     -> FULL HOLD + ADD      $574.08
# ✓ [306/503] MCD    -> FULL HOLD + ADD      $301.49
# ✓ [307/503] MCK    -> FULL HOLD + ADD      $822.90
# ✓ [308/503] MDT    -> FULL HOLD + ADD      $97.03
# ✓ [311/503] MET    -> FULL HOLD + ADD      $82.80
# ✓ [313/503] MTD    -> FULL HOLD + ADD      $1441.69
# ✓ [317/503] MU     -> FULL HOLD + ADD      $312.79
# ✓ [321/503] MPWR   -> FULL HOLD + ADD      $945.72
# ✓ [323/503] MNST   -> FULL HOLD + ADD      $75.37
# ✓ [324/503] MCO    -> FULL HOLD + ADD      $531.26
# ✓ [326/503] MS     -> FULL HOLD + ADD      $187.92
# ✓ [328/503] MSCI   -> FULL HOLD + ADD      $582.07
# ✓ [329/503] NDAQ   -> FULL HOLD + ADD      $98.31
# ✓ [334/503] NEM    -> FULL HOLD + ADD      $103.91
# ✓ [338/503] NDSN   -> FULL HOLD + ADD      $246.04
# ✓ [339/503] NOC    -> FULL HOLD + ADD      $605.54
# ✓ [340/503] NSC    -> FULL HOLD + ADD      $289.55
# ✓ [341/503] NTRS   -> FULL HOLD + ADD      $144.51
# ✓ [344/503] NUE    -> FULL HOLD + ADD      $168.63
# ✓ [345/503] NXPI   -> FULL HOLD + ADD      $225.32
# ✓ [347/503] NVDA   -> FULL HOLD + ADD      $187.90
#   [350/503] Scanning...
# ✓ [356/503] PKG    -> FULL HOLD + ADD      $210.73
# ✓ [357/503] PCAR   -> FULL HOLD + ADD      $112.74
# ✓ [358/503] PLTR   -> FULL HOLD + ADD      $173.49
# ✓ [363/503] PH     -> FULL HOLD + ADD      $911.44
# ✓ [372/503] PNC    -> FULL HOLD + ADD      $217.74
# ✓ [375/503] PFG    -> FULL HOLD + ADD      $91.18
# ✓ [380/503] PRU    -> FULL HOLD + ADD      $117.83
# ✓ [381/503] PLD    -> FULL HOLD + ADD      $130.41
# ✓ [386/503] PWR    -> FULL HOLD + ADD      $441.28
# ✓ [388/503] QCOM   -> FULL HOLD + ADD      $176.08
# ✓ [389/503] RL     -> FULL HOLD + ADD      $360.90
# ✓ [390/503] RJF    -> FULL HOLD + ADD      $168.36
# ✓ [391/503] RTX    -> FULL HOLD + ADD      $188.27
# ✓ [393/503] RF     -> FULL HOLD + ADD      $28.27
# ✓ [400/503] ROK    -> FULL HOLD + ADD      $408.13
# ✓ [401/503] ROST   -> FULL HOLD + ADD      $185.31
# ✓ [402/503] ROL    -> FULL HOLD + ADD      $59.22
# ✓ [404/503] SNDK   -> FULL HOLD + ADD      $272.16
# ✓ [406/503] SPGI   -> FULL HOLD + ADD      $536.32
# ✓ [409/503] STX    -> FULL HOLD + ADD      $287.80
# ✓ [413/503] SPG    -> FULL HOLD + ADD      $184.26
# ✓ [415/503] SOLV   -> FULL HOLD + ADD      $81.20
# ✓ [419/503] SNA    -> FULL HOLD + ADD      $354.64
# ✓ [420/503] LUV    -> FULL HOLD + ADD      $42.60
# ✓ [422/503] STLD   -> FULL HOLD + ADD      $171.70
# ✓ [424/503] STE    -> FULL HOLD + ADD      $256.59
# ✓ [428/503] SYF    -> FULL HOLD + ADD      $87.18
# ✓ [432/503] TROW   -> FULL HOLD + ADD      $106.84
# ✓ [433/503] TTWO   -> FULL HOLD + ADD      $257.79
# ✓ [434/503] STT    -> FULL HOLD + ADD      $134.23
# ✓ [435/503] TRGP   -> FULL HOLD + ADD      $181.23
# ✓ [437/503] TPR    -> FULL HOLD + ADD      $129.92
# ✓ [438/503] TEL    -> FULL HOLD + ADD      $231.56
# ✓ [440/503] TER    -> FULL HOLD + ADD      $218.18
# ✓ [441/503] TSLA   -> FULL HOLD + ADD      $454.93
# ✓ [443/503] TMO    -> FULL HOLD + ADD      $606.64
# ✓ [444/503] TXT    -> FULL HOLD + ADD      $89.25
# ✓ [446/503] TKO    -> FULL HOLD + ADD      $204.45
# ✓ [447/503] TJX    -> FULL HOLD + ADD      $154.19
# ✓ [449/503] TRV    -> FULL HOLD + ADD      $291.04
#   [450/503] Scanning...
# ✓ [453/503] TRMB   -> FULL HOLD + ADD      $79.40
# ✓ [455/503] TFC    -> FULL HOLD + ADD      $50.66
# ✓ [457/503] ULTA   -> FULL HOLD + ADD      $631.82
# ✓ [460/503] USB    -> FULL HOLD + ADD      $55.90
# ✓ [461/503] UNP    -> FULL HOLD + ADD      $232.80
# ✓ [462/503] UAL    -> FULL HOLD + ADD      $115.43
# ✓ [467/503] UHS    -> FULL HOLD + ADD      $222.40
# ✓ [469/503] VTR    -> FULL HOLD + ADD      $76.76
# ✓ [474/503] VTRS   -> FULL HOLD + ADD      $12.37
# ✓ [476/503] V      -> FULL HOLD + ADD      $355.52
# ✓ [480/503] WAB    -> FULL HOLD + ADD      $218.17
# ✓ [483/503] WMT    -> FULL HOLD + ADD      $113.58
# ✓ [485/503] WBD    -> FULL HOLD + ADD      $28.66
# ✓ [486/503] WAT    -> FULL HOLD + ADD      $394.62
# ✓ [487/503] WFC    -> FULL HOLD + ADD      $96.58
# ✓ [490/503] WELL   -> FULL HOLD + ADD      $185.93
# ✓ [491/503] WDC    -> FULL HOLD + ADD      $186.59
# ✓ [493/503] WMB    -> FULL HOLD + ADD      $60.74
# ✓ [497/503] WTW    -> FULL HOLD + ADD      $334.18
# ✓ [499/503] WYNN   -> FULL HOLD + ADD      $121.56
# ✓ [500/503] YUM    -> FULL HOLD + ADD      $149.16
# ================================================================================
#
# ✓ Scan complete: 502 analyzed, 202 FULL HOLD + ADD signals found
#
#
# ✓ Scan completed in 96.0 seconds

# %% [markdown]
# ## Cell 3: Filter and Display Results by Confluence

# %%
# Filter for FULL HOLD + ADD signals
buy_df = filter_buy_signals(results_df, 'FULL HOLD + ADD')

print(f"{'='*80}")
print(f"🎯 FULL HOLD + ADD SIGNALS: {len(buy_df)} stocks")
print(f"{'='*80}\n")

# Breakdown by confluence
print("📊 Breakdown by Confluence:")
confluence_counts = buy_df['confluence'].value_counts()
for conf, count in confluence_counts.items():
    print(f"  {conf:12s}: {count:3d} stocks")

# Save to workspace scanner_results folder
results_dir = Path.cwd() / 'scanner_results'
results_dir.mkdir(exist_ok=True)

timestamp = datetime.now().strftime("%Y%m%d_%H%M")
excel_path = results_dir / f'sp500_analysis_{timestamp}.xlsx'
pdf_path = results_dir / f'scanner_report_{timestamp}.pdf'

# Generate Excel
create_excel_output(buy_df, excel_path)
print(f"\n✓ Excel saved to: {excel_path}")

# Generate PDF
print(f"\n📄 Creating PDF research document...")
create_pdf_report(buy_df, results_df, pdf_path, timestamp)
print(f"✓ PDF saved to: {pdf_path}")

# Cleanup old scans (keep 7 most recent, archive rest)
print("\n📁 Managing scan history...")
cleanup_old_scans(results_dir, max_files=7)
# Out:
# ================================================================================
# 🎯 FULL HOLD + ADD SIGNALS: 202 stocks
# ================================================================================
#
# 📊 Breakdown by Confluence:
#   WEAK        : 137 stocks
#   EXTENDED    :  42 stocks
#   BALANCED    :  23 stocks
# ✓ Excel file created: c:\workspace\my_script_project\scanner_results\sp500_analysis_20260105_1945.xlsx
#   - All: 202 stocks
#   - Balanced: 23 stocks
#   - Extended: 42 stocks
#   - Weak: 137 stocks
#
# ✓ Results saved to: c:\workspace\my_script_project\scanner_results\sp500_analysis_20260105_1945.xlsx
#
# 📁 Managing scan history...

# %% [markdown]
# ## Cell 4: Display BALANCED Stocks (Priority Buy List)

# %%
# Filter for BALANCED confluence only
balanced_df = buy_df[buy_df['confluence'] == 'BALANCED'].copy()
balanced_df = balanced_df.sort_values('ticker')

print(f"🎯 BALANCED STOCKS (Priority Buy Candidates): {len(balanced_df)}\n")

if not balanced_df.empty:
    # Display key columns
    display_cols = ['ticker', 'current_price', 'recommendation', 'd50', 'd200', 'w10', 'w200']
    available_cols = [col for col in display_cols if col in balanced_df.columns]
    
    print(balanced_df[available_cols].to_string(index=False))
    
    print(f"\n✅ These {len(balanced_df)} stocks have:")
    print("  ✓ FULL HOLD + ADD signal (Weekly P1 + Daily P1)")
    print("  ✓ BALANCED confluence (healthy technical setup)")
    print("  ✓ 'Enter on Dip' recommendation")
else:
    print("No BALANCED stocks found in this scan.")
# Out:
# 🎯 BALANCED STOCKS (Priority Buy Candidates): 23
#
# ticker  current_price recommendation        d50       d200        w10       w200
#   AAPL       267.3900   Enter on Dip 272.943346 231.965436 273.322119 192.079822
#    ALL       205.7500   Enter on Dip 204.374413 200.653223 207.079797 152.024460
#   AMGN       319.3300   Enter on Dip 323.183571 294.272593 328.780725 261.671647
#   CBOE       252.1700   Enter on Dip 251.717000 236.586874 253.522002 172.131055
#    CEG       351.0500   Enter on Dip 360.359692 312.646408 354.315369 173.893209
#   CINF       162.8000   Enter on Dip 162.212434 150.712410 163.980283 118.920830
#    COR       339.7750   Enter on Dip 348.422795 306.013406 350.234854 215.510328
#   CSCO        75.7439   Enter on Dip  75.464507  67.039440  76.256867  51.473201
#   CTRA        25.4600   Enter on Dip  25.743994  24.726490  26.194452  24.479916
#     EW        84.1700   Enter on Dip  84.378200  78.079450  85.277000  81.407450
#    EXE       104.9500   Enter on Dip 112.445908 106.291680 113.415422  86.063613
#    IBM       295.0350   Enter on Dip 303.774277 269.972813 302.451880 177.716194
#   IDXX       676.8600   Enter on Dip 696.410596 583.927099 703.113995 486.440048
#    LVS        64.7450   Enter on Dip  64.757554  50.481542  65.739090  46.530867
#    MCD       301.4850   Enter on Dip 306.638710 303.341750 307.789435 269.837699
#   MPWR       945.7150   Enter on Dip 956.018876 795.760888 934.001752 606.495620
#   PLTR       173.4921   Enter on Dip 180.895742 151.477936 176.401210  51.390061
#    STE       256.5900   Enter on Dip 254.718600 240.104901 258.320998 215.659508
#   TRMB        79.4000   Enter on Dip  79.908199  75.977600  79.749999  62.072400
#    UHS       222.4000   Enter on Dip 226.192071 193.491525 227.992700 160.558007
#    VTR        76.7600   Enter on Dip  77.032746  68.463538  78.090726  51.598127
#   WELL       185.9300   Enter on Dip 191.081928 165.587048 192.850609 105.639606
#   WYNN       121.5600   Enter on Dip 124.223366 107.086367 123.999114  90.696211
#
# ✅ These 23 stocks have:
#   ✓ FULL HOLD + ADD signal (Weekly P1 + Daily P1)
#   ✓ BALANCED confluence (healthy technical setup)
#   ✓ 'Enter on Dip' recommendation

# %% [markdown]
# ## Cell 5: Display EXTENDED Stocks (Watch List)

# %%
# Filter for EXTENDED confluence
extended_df = buy_df[buy_df['confluence'] == 'EXTENDED'].copy()
extended_df = extended_df.sort_values('ticker')

print(f"⏳ EXTENDED STOCKS (Wait for Pullback): {len(extended_df)}\n")

if not extended_df.empty:
    display_cols = ['ticker', 'current_price', 'recommendation', 'd50', 'd200']
    available_cols = [col for col in display_cols if col in extended_df.columns]
    
    # Show first 20
    print(extended_df[available_cols].head(20).to_string(index=False))
    
    if len(extended_df) > 20:
        print(f"\n... and {len(extended_df) - 20} more (see Excel file)")
    
    print(f"\n⚠️ These stocks have strong signals but are technically overbought.")
    print("  → Wait for pullback to support before entering")
else:
    print("No EXTENDED stocks found.")

# %% [markdown]
# ## Cell 6: Compare with Current Holdings (stocks.txt)

# %%
from technical_analysis import parse_stocks_file

# Load current holdings
stocks_file = Path.cwd() / 'stocks.txt'
individual_tickers, baskets = parse_stocks_file(stocks_file)

# Find BALANCED stocks NOT in your portfolio
balanced_tickers = set(balanced_df['ticker'].tolist())
current_tickers = set(individual_tickers)
new_opportunities = balanced_tickers - current_tickers

print(f"📋 Current Portfolio: {len(current_tickers)} stocks")
print(f"🎯 BALANCED Opportunities: {len(balanced_tickers)} stocks")
print(f"\n✨ NEW BALANCED Stocks (not in your portfolio): {len(new_opportunities)}\n")

if new_opportunities:
    new_df = balanced_df[balanced_df['ticker'].isin(new_opportunities)].sort_values('ticker')
    display_cols = ['ticker', 'current_price', 'd50', 'd200', 'w10', 'w200']
    available_cols = [col for col in display_cols if col in new_df.columns]
    print(new_df[available_cols].to_string(index=False))
    print(f"\n💡 Consider adding these {len(new_opportunities)} stocks to stocks.txt for detailed analysis")
else:
    print("All BALANCED opportunities are already in your portfolio!")

# Check which current holdings are also BALANCED
holdings_balanced = balanced_tickers & current_tickers
print(f"\n✅ Current holdings that are BALANCED: {len(holdings_balanced)}")
if holdings_balanced:
    print(f"   {', '.join(sorted(holdings_balanced))}")
# Out:
# 📋 Current Portfolio: 13 stocks
# 🎯 BALANCED Opportunities: 23 stocks
#
# ✨ NEW BALANCED Stocks (not in your portfolio): 22
#
# ticker  current_price        d50       d200        w10       w200
#   AAPL       267.3900 272.943346 231.965436 273.322119 192.079822
#    ALL       205.7500 204.374413 200.653223 207.079797 152.024460
#   AMGN       319.3300 323.183571 294.272593 328.780725 261.671647
#   CBOE       252.1700 251.717000 236.586874 253.522002 172.131055
#    CEG       351.0500 360.359692 312.646408 354.315369 173.893209
#   CINF       162.8000 162.212434 150.712410 163.980283 118.920830
#    COR       339.7750 348.422795 306.013406 350.234854 215.510328
#   CSCO        75.7439  75.464507  67.039440  76.256867  51.473201
#   CTRA        25.4600  25.743994  24.726490  26.194452  24.479916
#     EW        84.1700  84.378200  78.079450  85.277000  81.407450
#    EXE       104.9500 112.445908 106.291680 113.415422  86.063613
#    IBM       295.0350 303.774277 269.972813 302.451880 177.716194
#   IDXX       676.8600 696.410596 583.927099 703.113995 486.440048
#    LVS        64.7450  64.757554  50.481542  65.739090  46.530867
#    MCD       301.4850 306.638710 303.341750 307.789435 269.837699
#   MPWR       945.7150 956.018876 795.760888 934.001752 606.495620
#    STE       256.5900 254.718600 240.104901 258.320998 215.659508
#   TRMB        79.4000  79.908199  75.977600  79.749999  62.072400
#    UHS       222.4000 226.192071 193.491525 227.992700 160.558007
#    VTR        76.7600  77.032746  68.463538  78.090726  51.598127
#   WELL       185.9300 191.081928 165.587048 192.850609 105.639606
#   WYNN       121.5600 124.223366 107.086367 123.999114  90.696211
#
# 💡 Consider adding these 22 stocks to stocks.txt for detailed analysis
#
# ✅ Current holdings that are BALANCED: 1
#    PLTR

# %% [markdown]
# ## Cell 7: Overall Signal Distribution

# %%
print("📊 Complete S&P 500 Signal Distribution:\n")
print(results_df['signal'].value_counts().to_string())

print(f"\n\n{'='*80}")
print("Summary")
print(f"{'='*80}")
print(f"Total S&P 500 stocks analyzed: {len(results_df)}")
print(f"FULL HOLD + ADD signals: {len(buy_df)}")
print(f"  ├─ BALANCED (buy now): {len(buy_df[buy_df['confluence'] == 'BALANCED'])}")
print(f"  ├─ EXTENDED (watch): {len(buy_df[buy_df['confluence'] == 'EXTENDED'])}")
print(f"  └─ WEAK (skip): {len(buy_df[buy_df['confluence'] == 'WEAK'])}")
print(f"\nExcel file: {output_path}")
# Out:
# 📊 Complete S&P 500 Signal Distribution:
#
# signal
# FULL HOLD + ADD       202
# HOLD MOST → REDUCE     76
# FULL CASH / DEFEND     72
# CASH                   55
# REDUCE                 36
# HOLD                   34
# SCALE IN               20
# LIGHT / CASH            7
#
#
# ================================================================================
# Summary
# ================================================================================
# Total S&P 500 stocks analyzed: 502
# FULL HOLD + ADD signals: 202
#   ├─ BALANCED (buy now): 23
#   ├─ EXTENDED (watch): 42
#   └─ WEAK (skip): 137
#
# Excel file: C:\Users\karms\Downloads\sp500_analysis_20260105_1931.xlsx
