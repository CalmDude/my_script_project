# %%
from pathlib import Path
from datetime import datetime
import pandas as pd
import sys
import importlib

# Determine root directory - go up from notebooks folder to portfolio_analyser
if Path.cwd().name == 'notebooks':
    ROOT = Path.cwd().parent
else:
    ROOT = Path.cwd()

src_path = ROOT / 'src'

# Add src to path if not already there
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

# Reload module to pick up any code changes without restarting kernel
if 'full_scanner' in sys.modules:
    import full_scanner
    importlib.reload(full_scanner)

from full_scanner import (
    get_sp500_tickers,
    get_nasdaq100_tickers,
    get_portfolio_tickers,
    scan_stocks,
    filter_buy_signals,
    filter_sell_signals,
    create_excel_output,
    create_portfolio_excel,
    create_pdf_report,
    create_best_trades_excel,
    create_best_trades_pdf,
    cleanup_old_scans
)

# Setup results directory
results_dir = ROOT / 'scanner_results'
results_dir.mkdir(exist_ok=True)

timestamp = datetime.now().strftime("%Y%m%d_%H%M")

print("[OK] Scanner modules loaded")
print(f"[OK] Results directory: {results_dir}")
print(f"[OK] Timestamp: {timestamp}")
# Out:
# [OK] Scanner modules loaded
# [OK] Results directory: c:\workspace\portfolio_analyser\scanner_results
# [OK] Timestamp: 20260110_2254

# %% [markdown]
# ## Configuration
#
# Set your scan parameters:
# - **daily_bars**: Number of daily bars to analyze (default: 60)
# - **weekly_bars**: Number of weekly bars to analyze (default: 52)
# - **concurrency**: Number of parallel workers (default: 2, max recommended: 5)

# %%
# Scan parameters
DAILY_BARS = 60
WEEKLY_BARS = 52
CONCURRENCY = 2  # Be careful with higher values (rate limits)

print(f"Daily bars: {DAILY_BARS}")
print(f"Weekly bars: {WEEKLY_BARS}")
print(f"Concurrency: {CONCURRENCY}")
# Out:
# Daily bars: 60
# Weekly bars: 52
# Concurrency: 2

# %% [markdown]
# ## Scan Portfolio Stocks
#
# Quick scan of your portfolio stocks from stocks.txt. Shows both buy opportunities (FULL HOLD + ADD) and sell signals (bearish signals).

# %%
print("Loading portfolio tickers from stocks.txt...")
portfolio_tickers = get_portfolio_tickers()

if portfolio_tickers:
    print(f"Found {len(portfolio_tickers)} portfolio stocks\n")

    # Run scan
    portfolio_results = scan_stocks(
        portfolio_tickers,
        category="Portfolio",
        daily_bars=DAILY_BARS,
        weekly_bars=WEEKLY_BARS,
        concurrency=CONCURRENCY
    )

    if not portfolio_results.empty:
        # Get buy signals (all and quality-filtered)
        portfolio_buy_all = filter_buy_signals(portfolio_results, 'FULL HOLD + ADD', quality_filter=False)
        portfolio_buy = filter_buy_signals(portfolio_results, 'FULL HOLD + ADD', quality_filter=True)
        
        # Get sell signals (all bearish signals)
        portfolio_sell = filter_sell_signals(portfolio_results, quality_filter=False)
        
        # Display summary
        print(f"\n[STATS] Portfolio Results:")
        print(f"   [OK] {len(portfolio_buy)} buy signals (EXCELLENT/GOOD/OK)")
        if len(portfolio_buy_all) > len(portfolio_buy):
            print(f"   [WAIT] {len(portfolio_buy_all) - len(portfolio_buy)} extended/weak (wait)")
        print(f"   [SELL] {len(portfolio_sell)} sell signals (bearish)")
        
        # Display buy opportunities
        if not portfolio_buy.empty:
            print("\n[OK] BUY OPPORTUNITIES (EXCELLENT/GOOD/OK quality):")
            display_cols = ['ticker', 'signal', 'current_price', 'buy_quality', 's1']
            if all(col in portfolio_buy.columns for col in display_cols):
                print(portfolio_buy[display_cols].to_string(index=False))
            else:
                print(portfolio_buy[['ticker', 'signal', 'current_price']].to_string(index=False))
        
        # Display sell signals
        if not portfolio_sell.empty:
            print("\n[SELL] SELL SIGNALS (Bearish - reduce exposure):")
            display_cols = ['ticker', 'signal', 'current_price', 'r1_quality', 'r1']
            if all(col in portfolio_sell.columns for col in display_cols):
                print(portfolio_sell[display_cols].to_string(index=False))
            else:
                print(portfolio_sell[['ticker', 'signal', 'current_price']].to_string(index=False))
        
        # Save combined results
        if not portfolio_buy.empty or not portfolio_sell.empty:
            # Create portfolio subfolder
            portfolio_dir = results_dir / 'portfolio'
            portfolio_dir.mkdir(exist_ok=True)
            
            xlsx_path = portfolio_dir / f'portfolio_scanner_{timestamp}.xlsx'
            pdf_path = portfolio_dir / f'scanner_report_portfolio_{timestamp}.pdf'
            best_trades_xlsx = portfolio_dir / f'portfolio_best_trades_{timestamp}.xlsx'
            best_trades_pdf = portfolio_dir / f'portfolio_best_trades_{timestamp}.pdf'
            
            # Create standard reports with both buy and sell data
            create_excel_output(portfolio_buy, portfolio_sell, xlsx_path, category="Portfolio")
            create_pdf_report(portfolio_buy, portfolio_sell, pdf_path, timestamp, category="Portfolio")
            
            # Create best trades reports
            create_best_trades_excel(portfolio_buy, portfolio_sell, best_trades_xlsx, category="Portfolio")
            create_best_trades_pdf(portfolio_buy, portfolio_sell, best_trades_pdf, category="Portfolio")
            
            print(f"\n[OK] Excel: portfolio/{xlsx_path.name}")
            print(f"[OK] PDF: portfolio/{pdf_path.name}")
            print(f"[OK] Best Trades Excel: portfolio/{best_trades_xlsx.name}")
            print(f"[OK] Best Trades PDF: portfolio/{best_trades_pdf.name}")
else:
    print("[WARN] No portfolio tickers found in stocks.txt")
# Out:
# Loading portfolio tickers from stocks.txt...
# [OK] Loaded 9 portfolio tickers from stocks.txt
#
# Found 9 portfolio stocks
#
# [SCAN] Scanning 9 Portfolio stocks for 'FULL HOLD + ADD' signals...
# Parameters: 60 daily bars, 52 weekly bars, 2 threads
# ================================================================================
# [OK] [1/9] TSLA   -> FULL HOLD + ADD      $445.01 | Entry: CAUTION    ⚠️ THIN
# [OK] [2/9] NVDA   -> FULL HOLD + ADD      $184.86 | Entry: CAUTION    ⚠️ THIN
# [OK] [3/9] ASML   -> FULL HOLD + ADD      $1,273.88 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [6/9] MRVL   -> FULL HOLD + ADD      $83.22 | Entry: GOOD       ✓ SAFE ENTRY
# ================================================================================
#
# [OK] Scan complete: 9 analyzed, 4 FULL HOLD + ADD signals found
#
#
# [STATS] Portfolio Results:
#    [OK] 1 buy signals (EXCELLENT/GOOD/OK)
#    [WAIT] 3 extended/weak (wait)
#    [SELL] 3 sell signals (bearish)
#
# [OK] BUY OPPORTUNITIES (EXCELLENT/GOOD/OK quality):
# ticker          signal  current_price buy_quality        s1
#   MRVL FULL HOLD + ADD          83.22        GOOD 81.121628
#
# [SELL] SELL SIGNALS (Bearish - reduce exposure):
#  ticker             signal  current_price r1_quality            r1
#    ALAB HOLD MOST + REDUCE      162.61000         OK    201.860001
# BTC-USD HOLD MOST + REDUCE    90413.56000       GOOD 116273.312500
# SOL-USD               CASH      135.66878       GOOD    175.475311
# [OK] Excel file created: c:\workspace\portfolio_analyser\scanner_results\portfolio\portfolio_scanner_20260110_2254.xlsx
#   - Buy Opportunities: 1 stocks
#   - Sell Opportunities: 3 stocks
# [OK] PDF report created: c:\workspace\portfolio_analyser\scanner_results\portfolio\scanner_report_portfolio_20260110_2254.pdf
# [OK] Best Trades Excel created: c:\workspace\portfolio_analyser\scanner_results\portfolio\portfolio_best_trades_20260110_2254.xlsx
# [OK] Best Trades PDF created: c:\workspace\portfolio_analyser\scanner_results\portfolio\portfolio_best_trades_20260110_2254.pdf
#
# [OK] Excel: portfolio/portfolio_scanner_20260110_2254.xlsx
# [OK] PDF: portfolio/scanner_report_portfolio_20260110_2254.pdf
# [OK] Best Trades Excel: portfolio/portfolio_best_trades_20260110_2254.xlsx
# [OK] Best Trades PDF: portfolio/portfolio_best_trades_20260110_2254.pdf

# %% [markdown]
# ## Scan S&P 500
#
# Full scan of ~500 stocks. Takes 5-10 minutes depending on cache. Shows both buy opportunities (FULL HOLD + ADD) and sell signals (bearish signals).

# %%
print("Fetching S&P 500 ticker list...")
sp500_tickers = get_sp500_tickers()
print(f"Found {len(sp500_tickers)} S&P 500 stocks\n")

# Run scan
sp500_results = scan_stocks(
    sp500_tickers,
    category="S&P 500",
    daily_bars=DAILY_BARS,
    weekly_bars=WEEKLY_BARS,
    concurrency=CONCURRENCY
)

if not sp500_results.empty:
    # Get buy signals (all and quality-filtered)
    sp500_buy_all = filter_buy_signals(sp500_results, 'FULL HOLD + ADD', quality_filter=False)
    sp500_buy = filter_buy_signals(sp500_results, 'FULL HOLD + ADD', quality_filter=True)
    
    # Get sell signals (all bearish signals, matching portfolio_analysis logic)
    sp500_sell = filter_sell_signals(sp500_results, quality_filter=False)
    
    # Display summary
    print(f"\n[STATS] S&P 500 Results:")
    print(f"   [OK] {len(sp500_buy)} buy signals (EXCELLENT/GOOD/OK)")
    if len(sp500_buy_all) > len(sp500_buy):
        print(f"   [WAIT] {len(sp500_buy_all) - len(sp500_buy)} extended/weak (wait)")
    print(f"   [SELL] {len(sp500_sell)} sell signals (bearish)")
    
    # Display buy opportunities
    if not sp500_buy.empty:
        print("\n[OK] TOP BUY OPPORTUNITIES (EXCELLENT/GOOD/OK quality):")
        display_cols = ['ticker', 'signal', 'current_price', 'buy_quality', 's1']
        if all(col in sp500_buy.columns for col in display_cols):
            print(sp500_buy[display_cols].head(10).to_string(index=False))
        else:
            print(sp500_buy[['ticker', 'signal', 'current_price']].head(10).to_string(index=False))
    
    # Display sell signals (matches portfolio_analysis behavior)
    if not sp500_sell.empty:
        print("\n[SELL] SELL SIGNALS (Bearish - reduce exposure):")
        display_cols = ['ticker', 'signal', 'current_price', 'r1_quality', 'r1']
        if all(col in sp500_sell.columns for col in display_cols):
            print(sp500_sell[display_cols].head(10).to_string(index=False))
        else:
            print(sp500_sell[['ticker', 'signal', 'current_price']].head(10).to_string(index=False))
    
    # Save combined results if we have either buy or sell signals
    if not sp500_buy.empty or not sp500_sell.empty:
        # Create sp500 subfolder
        sp500_dir = results_dir / 'sp500'
        sp500_dir.mkdir(exist_ok=True)
        
        xlsx_path = sp500_dir / f'sp500_analysis_{timestamp}.xlsx'
        pdf_path = sp500_dir / f'scanner_report_sp500_{timestamp}.pdf'
        best_trades_xlsx = sp500_dir / f'sp500_best_trades_{timestamp}.xlsx'
        best_trades_pdf = sp500_dir / f'sp500_best_trades_{timestamp}.pdf'
        
        # Create standard reports with both buy and sell data
        create_excel_output(sp500_buy, sp500_sell, xlsx_path, category="S&P 500")
        create_pdf_report(sp500_buy, sp500_sell, pdf_path, timestamp, category="S&P 500")
        
        # Create best trades reports
        create_best_trades_excel(sp500_buy, sp500_sell, best_trades_xlsx, category="S&P 500")
        create_best_trades_pdf(sp500_buy, sp500_sell, best_trades_pdf, category="S&P 500")
        
        print(f"\n[OK] Excel: sp500/{xlsx_path.name}")
        print(f"[OK] PDF: sp500/{pdf_path.name}")
        print(f"[OK] Best Trades Excel: sp500/{best_trades_xlsx.name}")
        print(f"[OK] Best Trades PDF: sp500/{best_trades_pdf.name}")
else:
    print("[WARN] No results from S&P 500 scan")
# Out:
# Fetching S&P 500 ticker list...
# [OK] Loaded 503 S&P 500 tickers
#
# Found 503 S&P 500 stocks
#
# [SCAN] Scanning 503 S&P 500 stocks for 'FULL HOLD + ADD' signals...
# Parameters: 60 daily bars, 52 weekly bars, 2 threads
# ================================================================================
# [OK] [4/503] ABBV   -> FULL HOLD + ADD      $220.08 | Entry: OK         🎯 ACCEPTABLE
# [OK] [8/503] AFL    -> FULL HOLD + ADD      $109.24 | Entry: GOOD       ✓ SAFE ENTRY
# [OK] [10/503] A      -> FULL HOLD + ADD      $148.52 | Entry: OK         🎯 ACCEPTABLE
# [OK] [14/503] ALB    -> FULL HOLD + ADD      $161.29 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [19/503] GOOGL  -> FULL HOLD + ADD      $328.57 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [20/503] ALL    -> FULL HOLD + ADD      $212.21 | Entry: OK         🎯 ACCEPTABLE
# [OK] [21/503] GOOG   -> FULL HOLD + ADD      $329.14 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [22/503] AMZN   -> FULL HOLD + ADD      $247.38 | Entry: CAUTION    ⚠️ THIN
# [OK] [27/503] AXP    -> FULL HOLD + ADD      $375.61 | Entry: CAUTION    ⚠️ THIN
# [OK] [28/503] AIG    -> FULL HOLD + ADD      $75.43 | Entry: GOOD       🎯 IDEAL
# [OK] [32/503] AME    -> FULL HOLD + ADD      $210.64 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [33/503] AMGN   -> FULL HOLD + ADD      $326.10 | Entry: EXCELLENT  ✓ SAFE ENTRY
# [OK] [34/503] APH    -> FULL HOLD + ADD      $140.16 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [35/503] ADI    -> FULL HOLD + ADD      $300.93 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [38/503] APO    -> FULL HOLD + ADD      $145.82 | Entry: EXCELLENT  ✓ SAFE ENTRY
# [OK] [39/503] AAPL   -> FULL HOLD + ADD      $259.37 | Entry: CAUTION    ⚠️ THIN
# [OK] [40/503] AMAT   -> FULL HOLD + ADD      $301.18 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [41/503] APP    -> FULL HOLD + ADD      $647.72 | Entry: CAUTION    ⚠️ THIN
# [OK] [42/503] APTV   -> FULL HOLD + ADD      $88.67 | Entry: CAUTION    ⚠️ THIN
# [OK] [43/503] ACGL   -> FULL HOLD + ADD      $95.18 | Entry: OK         🎯 ACCEPTABLE
# [OK] [45/503] ARES   -> FULL HOLD + ADD      $175.91 | Entry: EXCELLENT  ✓ SAFE ENTRY
# [OK] [48/503] AIZ    -> FULL HOLD + ADD      $238.00 | Entry: OK         🎯 ACCEPTABLE
#   [50/503] Scanning...
# [OK] [57/503] BKR    -> FULL HOLD + ADD      $49.97 | Entry: CAUTION    ⚠️ THIN
# [OK] [59/503] BAC    -> FULL HOLD + ADD      $55.85 | Entry: CAUTION    ⚠️ THIN
# [OK] [62/503] BRK-B  -> FULL HOLD + ADD      $499.10 | Entry: OK         🎯 ACCEPTABLE
# [OK] [69/503] BK     -> FULL HOLD + ADD      $119.04 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [70/503] BA     -> FULL HOLD + ADD      $234.53 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [71/503] BKNG   -> FULL HOLD + ADD      $5,492.11 | Entry: OK         🎯 ACCEPTABLE
# [OK] [79/503] BG     -> FULL HOLD + ADD      $99.99 | Entry: GOOD       ✓ SAFE ENTRY
# [OK] [81/503] CHRW   -> FULL HOLD + ADD      $170.77 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [85/503] CAH    -> FULL HOLD + ADD      $201.11 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [86/503] COF    -> FULL HOLD + ADD      $249.20 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [88/503] CCL    -> FULL HOLD + ADD      $32.13 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [89/503] CVNA   -> FULL HOLD + ADD      $463.09 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [90/503] CAT    -> FULL HOLD + ADD      $617.62 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [91/503] CBOE   -> FULL HOLD + ADD      $260.95 | Entry: OK         🎯 ACCEPTABLE
# [OK] [92/503] CBRE   -> FULL HOLD + ADD      $165.46 | Entry: CAUTION    ⚠️ THIN
# [OK] [94/503] COR    -> FULL HOLD + ADD      $335.69 | Entry: CAUTION    🎯 IDEAL
# [OK] [99/503] SCHW   -> FULL HOLD + ADD      $100.17 | Entry: CAUTION    ⚠️ THIN
#   [100/503] Scanning...
# [OK] [101/503] CVX    -> FULL HOLD + ADD      $162.11 | Entry: CAUTION    ⚠️ THIN
# [OK] [103/503] CB     -> FULL HOLD + ADD      $306.81 | Entry: OK         🎯 ACCEPTABLE
# [OK] [106/503] CINF   -> FULL HOLD + ADD      $162.99 | Entry: OK         🎯 ACCEPTABLE
# [OK] [108/503] CSCO   -> FULL HOLD + ADD      $73.88 | Entry: CAUTION    ⚠️ THIN
# [OK] [109/503] C      -> FULL HOLD + ADD      $121.32 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [110/503] CFG    -> FULL HOLD + ADD      $60.53 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [115/503] CTSH   -> FULL HOLD + ADD      $85.26 | Entry: CAUTION    ⏳ WAIT
# [OK] [119/503] FIX    -> FULL HOLD + ADD      $1,010.41 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [122/503] ED     -> FULL HOLD + ADD      $99.21 | Entry: OK         🎯 ACCEPTABLE
# [OK] [127/503] GLW    -> FULL HOLD + ADD      $85.23 | Entry: CAUTION    ⚠️ THIN
# [OK] [129/503] CTVA   -> FULL HOLD + ADD      $68.65 | Entry: GOOD       🎯 IDEAL
# [OK] [132/503] CTRA   -> FULL HOLD + ADD      $24.82 | Entry: OK         🎯 ACCEPTABLE
# [OK] [133/503] CRH    -> FULL HOLD + ADD      $131.38 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [136/503] CSX    -> FULL HOLD + ADD      $35.20 | Entry: EXCELLENT  ✓ SAFE ENTRY
# [OK] [137/503] CMI    -> FULL HOLD + ADD      $552.09 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [138/503] CVS    -> FULL HOLD + ADD      $80.30 | Entry: GOOD       ✓ SAFE ENTRY
# [OK] [143/503] DAY    -> FULL HOLD + ADD      $69.42 | Entry: GOOD       🎯 IDEAL
# [OK] [145/503] DE     -> FULL HOLD + ADD      $488.08 | Entry: OK         🎯 ACCEPTABLE
# [OK] [147/503] DAL    -> FULL HOLD + ADD      $72.31 | Entry: CAUTION    ⚠️ EXTENDED
#   [150/503] Scanning...
# [OK] [152/503] DG     -> FULL HOLD + ADD      $142.74 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [153/503] DLTR   -> FULL HOLD + ADD      $132.38 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [157/503] DOV    -> FULL HOLD + ADD      $201.89 | Entry: CAUTION    ⏳ WAIT
# [OK] [162/503] DD     -> FULL HOLD + ADD      $43.81 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [167/503] EW     -> FULL HOLD + ADD      $85.13 | Entry: EXCELLENT  🎯 IDEAL
# [OK] [168/503] EA     -> FULL HOLD + ADD      $204.10 | Entry: CAUTION    ⚠️ THIN
# [OK] [171/503] EMR    -> FULL HOLD + ADD      $144.20 | Entry: CAUTION    ⚠️ THIN
# [OK] [187/503] EXPE   -> FULL HOLD + ADD      $296.33 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [188/503] EXPD   -> FULL HOLD + ADD      $158.89 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [190/503] XOM    -> FULL HOLD + ADD      $124.61 | Entry: CAUTION    ⚠️ THIN
# [OK] [195/503] FRT    -> FULL HOLD + ADD      $101.64 | Entry: GOOD       ✓ SAFE ENTRY
# [OK] [196/503] FDX    -> FULL HOLD + ADD      $312.36 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [198/503] FITB   -> FULL HOLD + ADD      $49.27 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [199/503] FSLR   -> FULL HOLD + ADD      $238.66 | Entry: CAUTION    ⚠️ THIN
#   [200/503] Scanning...
# [OK] [202/503] F      -> FULL HOLD + ADD      $14.20 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [205/503] FOXA   -> FULL HOLD + ADD      $73.68 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [206/503] FOX    -> FULL HOLD + ADD      $66.42 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [207/503] BEN    -> FULL HOLD + ADD      $25.66 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [208/503] FCX    -> FULL HOLD + ADD      $56.53 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [211/503] GE     -> FULL HOLD + ADD      $321.59 | Entry: CAUTION    ⚠️ THIN
# [OK] [213/503] GEV    -> FULL HOLD + ADD      $622.50 | Entry: CAUTION    ⚠️ THIN
# [OK] [216/503] GD     -> FULL HOLD + ADD      $353.89 | Entry: CAUTION    ⚠️ THIN
# [OK] [218/503] GM     -> FULL HOLD + ADD      $82.87 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [220/503] GILD   -> FULL HOLD + ADD      $121.10 | Entry: OK         🎯 ACCEPTABLE
# [OK] [222/503] GL     -> FULL HOLD + ADD      $141.95 | Entry: GOOD       ✓ SAFE ENTRY
# [OK] [224/503] GS     -> FULL HOLD + ADD      $938.98 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [226/503] HIG    -> FULL HOLD + ADD      $136.26 | Entry: OK         🎯 ACCEPTABLE
# [OK] [227/503] HAS    -> FULL HOLD + ADD      $86.72 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [228/503] HCA    -> FULL HOLD + ADD      $472.07 | Entry: CAUTION    ⚠️ THIN
# [OK] [230/503] HSIC   -> FULL HOLD + ADD      $77.64 | Entry: EXCELLENT  🎯 IDEAL
# [OK] [231/503] HSY    -> FULL HOLD + ADD      $189.07 | Entry: GOOD       ✓ SAFE ENTRY
# [OK] [232/503] HPE    -> FULL HOLD + ADD      $22.17 | Entry: OK         🎯 IDEAL
# [OK] [233/503] HLT    -> FULL HOLD + ADD      $300.36 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [238/503] HST    -> FULL HOLD + ADD      $18.44 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [239/503] HWM    -> FULL HOLD + ADD      $218.27 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [241/503] HUBB   -> FULL HOLD + ADD      $470.53 | Entry: CAUTION    ⚠️ THIN
# [OK] [243/503] HBAN   -> FULL HOLD + ADD      $18.24 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [244/503] HII    -> FULL HOLD + ADD      $386.99 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [245/503] IBM    -> FULL HOLD + ADD      $304.22 | Entry: CAUTION    ⚠️ THIN
# [OK] [247/503] IDXX   -> FULL HOLD + ADD      $713.35 | Entry: CAUTION    ⚠️ THIN
# [OK] [249/503] INCY   -> FULL HOLD + ADD      $106.87 | Entry: CAUTION    ⚠️ EXTENDED
#   [250/503] Scanning...
# [OK] [252/503] INTC   -> FULL HOLD + ADD      $45.55 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [253/503] IBKR   -> FULL HOLD + ADD      $70.47 | Entry: CAUTION    ⚠️ THIN
# [OK] [258/503] ISRG   -> FULL HOLD + ADD      $586.24 | Entry: CAUTION    ⏳ WAIT
# [OK] [259/503] IVZ    -> FULL HOLD + ADD      $28.57 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [261/503] IQV    -> FULL HOLD + ADD      $242.41 | Entry: OK         🎯 ACCEPTABLE
# [OK] [263/503] JBHT   -> FULL HOLD + ADD      $206.85 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [264/503] JKHY   -> FULL HOLD + ADD      $189.16 | Entry: CAUTION    ⏳ WAIT
# [OK] [265/503] JBL    -> FULL HOLD + ADD      $226.15 | Entry: CAUTION    ⚠️ THIN
# [OK] [267/503] JNJ    -> FULL HOLD + ADD      $204.39 | Entry: CAUTION    ⚠️ THIN
# [OK] [268/503] JCI    -> FULL HOLD + ADD      $110.85 | Entry: OK         🎯 ACCEPTABLE
# [OK] [269/503] JPM    -> FULL HOLD + ADD      $329.19 | Entry: CAUTION    ⚠️ THIN
# [OK] [272/503] KEY    -> FULL HOLD + ADD      $21.19 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [273/503] KEYS   -> FULL HOLD + ADD      $207.30 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [276/503] KMI    -> FULL HOLD + ADD      $27.12 | Entry: OK         🎯 ACCEPTABLE
# [OK] [277/503] KKR    -> FULL HOLD + ADD      $134.65 | Entry: GOOD       🎯 IDEAL
# [OK] [278/503] KLAC   -> FULL HOLD + ADD      $1,400.00 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [281/503] LHX    -> FULL HOLD + ADD      $335.77 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [283/503] LRCX   -> FULL HOLD + ADD      $218.36 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [285/503] LVS    -> FULL HOLD + ADD      $58.95 | Entry: CAUTION    ⚠️ THIN
# [OK] [286/503] LDOS   -> FULL HOLD + ADD      $198.34 | Entry: OK         🎯 ACCEPTABLE
# [OK] [289/503] LLY    -> FULL HOLD + ADD      $1,063.56 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [292/503] LMT    -> FULL HOLD + ADD      $542.92 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [293/503] L      -> FULL HOLD + ADD      $104.58 | Entry: CAUTION    ⚠️ THIN
# [OK] [294/503] LOW    -> FULL HOLD + ADD      $267.21 | Entry: OK         🎯 ACCEPTABLE
# [OK] [297/503] MTB    -> FULL HOLD + ADD      $211.68 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [299/503] MAR    -> FULL HOLD + ADD      $328.18 | Entry: CAUTION    ⚠️ EXTENDED
#   [300/503] Scanning...
# [OK] [301/503] MLM    -> FULL HOLD + ADD      $666.67 | Entry: CAUTION    ⚠️ THIN
# [OK] [303/503] MA     -> FULL HOLD + ADD      $575.54 | Entry: OK         🎯 ACCEPTABLE
# [OK] [306/503] MCD    -> FULL HOLD + ADD      $307.32 | Entry: GOOD       ✓ SAFE ENTRY
# [OK] [307/503] MCK    -> FULL HOLD + ADD      $816.06 | Entry: CAUTION    ⚠️ THIN
# [OK] [308/503] MDT    -> FULL HOLD + ADD      $97.53 | Entry: GOOD       ✓ SAFE ENTRY
# [OK] [311/503] MET    -> FULL HOLD + ADD      $79.41 | Entry: GOOD       ✓ SAFE ENTRY
# [OK] [312/503] MTD    -> FULL HOLD + ADD      $1,485.12 | Entry: GOOD       ✓ SAFE ENTRY
# [OK] [315/503] MU     -> FULL HOLD + ADD      $345.09 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [322/503] MPWR   -> FULL HOLD + ADD      $958.97 | Entry: CAUTION    ⚠️ THIN
# [OK] [323/503] MNST   -> FULL HOLD + ADD      $77.34 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [324/503] MCO    -> FULL HOLD + ADD      $531.61 | Entry: CAUTION    ⚠️ THIN
# [OK] [325/503] MS     -> FULL HOLD + ADD      $186.32 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [328/503] MSCI   -> FULL HOLD + ADD      $581.16 | Entry: GOOD       ✓ SAFE ENTRY
# [OK] [329/503] NDAQ   -> FULL HOLD + ADD      $98.24 | Entry: CAUTION    ⚠️ THIN
# [OK] [332/503] NEM    -> FULL HOLD + ADD      $108.99 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [338/503] NDSN   -> FULL HOLD + ADD      $261.22 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [339/503] NSC    -> FULL HOLD + ADD      $287.21 | Entry: OK         🎯 ACCEPTABLE
# [OK] [340/503] NTRS   -> FULL HOLD + ADD      $145.74 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [341/503] NOC    -> FULL HOLD + ADD      $618.82 | Entry: CAUTION    ⚠️ THIN
# [OK] [342/503] NCLH   -> FULL HOLD + ADD      $24.53 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [344/503] NUE    -> FULL HOLD + ADD      $163.77 | Entry: EXCELLENT  🎯 IDEAL
# [OK] [345/503] NVDA   -> FULL HOLD + ADD      $184.86 | Entry: CAUTION    ⚠️ THIN
# [OK] [347/503] NXPI   -> FULL HOLD + ADD      $241.15 | Entry: CAUTION    ⚠️ EXTENDED
#   [350/503] Scanning...
# [OK] [356/503] PCAR   -> FULL HOLD + ADD      $118.80 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [357/503] PKG    -> FULL HOLD + ADD      $219.35 | Entry: OK         🎯 ACCEPTABLE
# [OK] [358/503] PLTR   -> FULL HOLD + ADD      $177.49 | Entry: CAUTION    ⚠️ THIN
# [OK] [361/503] PH     -> FULL HOLD + ADD      $920.99 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [370/503] PSX    -> FULL HOLD + ADD      $142.16 | Entry: CAUTION    ⚠️ THIN
# [OK] [372/503] PNC    -> FULL HOLD + ADD      $217.55 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [376/503] PFG    -> FULL HOLD + ADD      $90.29 | Entry: CAUTION    ⚠️ THIN
# [OK] [379/503] PLD    -> FULL HOLD + ADD      $129.40 | Entry: CAUTION    ⚠️ THIN
# [OK] [380/503] PRU    -> FULL HOLD + ADD      $118.08 | Entry: EXCELLENT  ✓ SAFE ENTRY
# [OK] [386/503] QCOM   -> FULL HOLD + ADD      $177.78 | Entry: CAUTION    ⚠️ THIN
# [OK] [388/503] RL     -> FULL HOLD + ADD      $369.81 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [389/503] RJF    -> FULL HOLD + ADD      $167.71 | Entry: OK         🎯 ACCEPTABLE
# [OK] [390/503] RTX    -> FULL HOLD + ADD      $188.50 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [394/503] RF     -> FULL HOLD + ADD      $28.52 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [399/503] ROK    -> FULL HOLD + ADD      $410.53 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [400/503] ROL    -> FULL HOLD + ADD      $60.68 | Entry: OK         🎯 ACCEPTABLE
# [OK] [402/503] ROST   -> FULL HOLD + ADD      $191.44 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [404/503] SPGI   -> FULL HOLD + ADD      $541.94 | Entry: OK         🎯 ACCEPTABLE
# [OK] [406/503] SNDK   -> FULL HOLD + ADD      $377.41 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [409/503] STX    -> FULL HOLD + ADD      $304.01 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [413/503] SPG    -> FULL HOLD + ADD      $184.69 | Entry: OK         🎯 ACCEPTABLE
# [OK] [417/503] SNA    -> FULL HOLD + ADD      $362.17 | Entry: CAUTION    ⚠️ THIN
# [OK] [418/503] SOLV   -> FULL HOLD + ADD      $86.14 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [420/503] LUV    -> FULL HOLD + ADD      $44.52 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [423/503] STT    -> FULL HOLD + ADD      $132.57 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [424/503] STLD   -> FULL HOLD + ADD      $169.27 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [425/503] STE    -> FULL HOLD + ADD      $256.82 | Entry: GOOD       ✓ SAFE ENTRY
# [OK] [428/503] SYF    -> FULL HOLD + ADD      $86.89 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [432/503] TROW   -> FULL HOLD + ADD      $107.31 | Entry: EXCELLENT  ✓ SAFE ENTRY
# [OK] [433/503] TTWO   -> FULL HOLD + ADD      $250.71 | Entry: GOOD       ✓ SAFE ENTRY
# [OK] [434/503] TPR    -> FULL HOLD + ADD      $134.35 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [435/503] TRGP   -> FULL HOLD + ADD      $176.86 | Entry: EXCELLENT  ✓ SAFE ENTRY
# [OK] [437/503] TEL    -> FULL HOLD + ADD      $231.60 | Entry: CAUTION    ⚠️ THIN
# [OK] [439/503] TER    -> FULL HOLD + ADD      $217.26 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [440/503] TSLA   -> FULL HOLD + ADD      $445.01 | Entry: CAUTION    ⚠️ THIN
# [OK] [443/503] TXT    -> FULL HOLD + ADD      $93.83 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [444/503] TMO    -> FULL HOLD + ADD      $618.86 | Entry: CAUTION    ⏳ WAIT
# [OK] [445/503] TJX    -> FULL HOLD + ADD      $157.81 | Entry: CAUTION    ⚠️ THIN
# [OK] [446/503] TKO    -> FULL HOLD + ADD      $199.63 | Entry: CAUTION    ⚠️ THIN
# [OK] [450/503] TDG    -> FULL HOLD + ADD      $1,392.09 | Entry: OK         🎯 ACCEPTABLE
# [OK] [451/503] TRV    -> FULL HOLD + ADD      $281.96 | Entry: OK         🎯 ACCEPTABLE
# [OK] [452/503] TRMB   -> FULL HOLD + ADD      $80.61 | Entry: OK         🎯 ACCEPTABLE
# [OK] [453/503] TFC    -> FULL HOLD + ADD      $50.62 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [456/503] USB    -> FULL HOLD + ADD      $55.21 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [459/503] ULTA   -> FULL HOLD + ADD      $666.18 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [460/503] UNP    -> FULL HOLD + ADD      $228.44 | Entry: EXCELLENT  🎯 IDEAL
# [OK] [461/503] UAL    -> FULL HOLD + ADD      $117.32 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [465/503] UHS    -> FULL HOLD + ADD      $207.03 | Entry: OK         🎯 ACCEPTABLE
# [OK] [466/503] VLO    -> FULL HOLD + ADD      $185.28 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [467/503] VTR    -> FULL HOLD + ADD      $74.90 | Entry: CAUTION    ⚠️ THIN
# [OK] [473/503] VTRS   -> FULL HOLD + ADD      $12.76 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [475/503] V      -> FULL HOLD + ADD      $349.77 | Entry: OK         🎯 ACCEPTABLE
# [OK] [477/503] VMC    -> FULL HOLD + ADD      $311.62 | Entry: CAUTION    ⚠️ THIN
# [OK] [480/503] WAB    -> FULL HOLD + ADD      $224.42 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [481/503] WMT    -> FULL HOLD + ADD      $114.53 | Entry: CAUTION    ⚠️ THIN
# [OK] [482/503] DIS    -> FULL HOLD + ADD      $115.88 | Entry: GOOD       ✓ SAFE ENTRY
# [OK] [483/503] WBD    -> FULL HOLD + ADD      $28.89 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [485/503] WAT    -> FULL HOLD + ADD      $396.75 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [487/503] WFC    -> FULL HOLD + ADD      $95.95 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [488/503] WELL   -> FULL HOLD + ADD      $186.08 | Entry: CAUTION    ⚠️ THIN
# [OK] [490/503] WDC    -> FULL HOLD + ADD      $200.46 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [492/503] WSM    -> FULL HOLD + ADD      $199.04 | Entry: CAUTION    ⚠️ THIN
# [OK] [493/503] WMB    -> FULL HOLD + ADD      $60.32 | Entry: OK         🎯 ACCEPTABLE
# [OK] [494/503] WTW    -> FULL HOLD + ADD      $330.26 | Entry: GOOD       ✓ SAFE ENTRY
# [OK] [499/503] YUM    -> FULL HOLD + ADD      $155.52 | Entry: OK         🎯 ACCEPTABLE
#   [500/503] Scanning...
# ================================================================================
#
# [OK] Scan complete: 502 analyzed, 213 FULL HOLD + ADD signals found
#
#
# [STATS] S&P 500 Results:
#    [OK] 65 buy signals (EXCELLENT/GOOD/OK)
#    [WAIT] 148 extended/weak (wait)
#    [SELL] 242 sell signals (bearish)
#
# [OK] TOP BUY OPPORTUNITIES (EXCELLENT/GOOD/OK quality):
# ticker          signal  current_price buy_quality         s1
#      A FULL HOLD + ADD         148.52          OK 139.989806
#   ABBV FULL HOLD + ADD         220.08    EXTENDED 211.690002
#   ACGL FULL HOLD + ADD          95.18          OK  90.500000
#    AFL FULL HOLD + ADD         109.24        GOOD 107.010002
#    AIG FULL HOLD + ADD          75.43        GOOD  74.856368
#    AIZ FULL HOLD + ADD         238.00        GOOD 219.529999
#    ALL FULL HOLD + ADD         212.21    EXTENDED 199.259995
#   AMGN FULL HOLD + ADD         326.10   EXCELLENT 312.390015
#    APO FULL HOLD + ADD         145.82   EXCELLENT 136.732438
#   ARES FULL HOLD + ADD         175.91   EXCELLENT 171.505122
#
# [SELL] SELL SIGNALS (Bearish - reduce exposure):
# ticker             signal  current_price r1_quality         r1
#   ABNB             REDUCE         139.27       GOOD 170.100006
#    ABT HOLD MOST + REDUCE         125.92         OK 139.331034
#    ACN             REDUCE         280.67       GOOD 361.142950
#   ADBE               CASH         333.95    CAUTION 422.950012
#    ADP               CASH         266.02         OK 324.495730
#   ADSK HOLD MOST + REDUCE         276.02    CAUTION 329.089996
#    AEE HOLD MOST + REDUCE          99.91         OK 105.967030
#    AJG FULL CASH / DEFEND         264.59       GOOD 343.276861
#   AKAM             REDUCE          88.12         OK 113.360001
#   ALGN             REDUCE         172.79       GOOD 208.309998
# [OK] Excel file created: c:\workspace\portfolio_analyser\scanner_results\sp500\sp500_analysis_20260110_2254.xlsx
#   - Buy Opportunities: 65 stocks
#   - Sell Opportunities: 242 stocks
# [OK] PDF report created: c:\workspace\portfolio_analyser\scanner_results\sp500\scanner_report_sp500_20260110_2254.pdf
# [OK] Best Trades Excel created: c:\workspace\portfolio_analyser\scanner_results\sp500\sp500_best_trades_20260110_2254.xlsx
# [OK] Best Trades PDF created: c:\workspace\portfolio_analyser\scanner_results\sp500\sp500_best_trades_20260110_2254.pdf
#
# [OK] Excel: sp500/sp500_analysis_20260110_2254.xlsx
# [OK] PDF: sp500/scanner_report_sp500_20260110_2254.pdf
# [OK] Best Trades Excel: sp500/sp500_best_trades_20260110_2254.xlsx
# [OK] Best Trades PDF: sp500/sp500_best_trades_20260110_2254.pdf

# %% [markdown]
# ## Scan NASDAQ 100
#
# Scan ~100 tech-heavy stocks. Takes 2-5 minutes. Shows both buy opportunities (FULL HOLD + ADD) and sell signals (bearish signals).

# %%
print("Fetching NASDAQ 100 ticker list...")
nasdaq100_tickers = get_nasdaq100_tickers()
print(f"Found {len(nasdaq100_tickers)} NASDAQ 100 stocks\n")

# Run scan
nasdaq100_results = scan_stocks(
    nasdaq100_tickers,
    category="NASDAQ 100",
    daily_bars=DAILY_BARS,
    weekly_bars=WEEKLY_BARS,
    concurrency=CONCURRENCY
)

if not nasdaq100_results.empty:
    # Get buy signals (all and quality-filtered)
    nasdaq100_buy_all = filter_buy_signals(nasdaq100_results, 'FULL HOLD + ADD', quality_filter=False)
    nasdaq100_buy = filter_buy_signals(nasdaq100_results, 'FULL HOLD + ADD', quality_filter=True)
    
    # Get sell signals (all bearish signals, matching portfolio_analysis logic)
    nasdaq100_sell = filter_sell_signals(nasdaq100_results, quality_filter=False)
    
    # Display summary
    print(f"\n[STATS] NASDAQ 100 Results:")
    print(f"   [OK] {len(nasdaq100_buy)} buy signals (EXCELLENT/GOOD/OK)")
    if len(nasdaq100_buy_all) > len(nasdaq100_buy):
        print(f"   [WAIT] {len(nasdaq100_buy_all) - len(nasdaq100_buy)} extended/weak (wait)")
    print(f"   [SELL] {len(nasdaq100_sell)} sell signals (bearish)")
    
    # Display buy opportunities
    if not nasdaq100_buy.empty:
        print("\n[OK] TOP BUY OPPORTUNITIES (EXCELLENT/GOOD/OK quality):")
        display_cols = ['ticker', 'signal', 'current_price', 'buy_quality', 's1']
        if all(col in nasdaq100_buy.columns for col in display_cols):
            print(nasdaq100_buy[display_cols].head(10).to_string(index=False))
        else:
            print(nasdaq100_buy[['ticker', 'signal', 'current_price']].head(10).to_string(index=False))
    
    # Display sell signals (matches portfolio_analysis behavior)
    if not nasdaq100_sell.empty:
        print("\n[SELL] SELL SIGNALS (Bearish - reduce exposure):")
        display_cols = ['ticker', 'signal', 'current_price', 'r1_quality', 'r1']
        if all(col in nasdaq100_sell.columns for col in display_cols):
            print(nasdaq100_sell[display_cols].head(10).to_string(index=False))
        else:
            print(nasdaq100_sell[['ticker', 'signal', 'current_price']].head(10).to_string(index=False))
    
    # Save combined results if we have either buy or sell signals
    if not nasdaq100_buy.empty or not nasdaq100_sell.empty:
        # Create nasdaq100 subfolder
        nasdaq100_dir = results_dir / 'nasdaq100'
        nasdaq100_dir.mkdir(exist_ok=True)
        
        xlsx_path = nasdaq100_dir / f'nasdaq100_analysis_{timestamp}.xlsx'
        pdf_path = nasdaq100_dir / f'scanner_report_nasdaq100_{timestamp}.pdf'
        best_trades_xlsx = nasdaq100_dir / f'nasdaq100_best_trades_{timestamp}.xlsx'
        best_trades_pdf = nasdaq100_dir / f'nasdaq100_best_trades_{timestamp}.pdf'
        
        # Create standard reports with both buy and sell data
        create_excel_output(nasdaq100_buy, nasdaq100_sell, xlsx_path, category="NASDAQ 100")
        create_pdf_report(nasdaq100_buy, nasdaq100_sell, pdf_path, timestamp, category="NASDAQ 100")
        
        # Create best trades reports
        create_best_trades_excel(nasdaq100_buy, nasdaq100_sell, best_trades_xlsx, category="NASDAQ 100")
        create_best_trades_pdf(nasdaq100_buy, nasdaq100_sell, best_trades_pdf, category="NASDAQ 100")
        
        print(f"\n[OK] Excel: nasdaq100/{xlsx_path.name}")
        print(f"[OK] PDF: nasdaq100/{pdf_path.name}")
        print(f"[OK] Best Trades Excel: nasdaq100/{best_trades_xlsx.name}")
        print(f"[OK] Best Trades PDF: nasdaq100/{best_trades_pdf.name}")
else:
    print("[WARN] No results from NASDAQ 100 scan")
# Out:
# Fetching NASDAQ 100 ticker list...
# [OK] Loaded 101 NASDAQ 100 tickers
#
# Found 101 NASDAQ 100 stocks
#
# [SCAN] Scanning 101 NASDAQ 100 stocks for 'FULL HOLD + ADD' signals...
# Parameters: 60 daily bars, 52 weekly bars, 2 threads
# ================================================================================
# [OK] [5/101] GOOGL  -> FULL HOLD + ADD      $328.57 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [6/101] GOOG   -> FULL HOLD + ADD      $329.14 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [7/101] AMZN   -> FULL HOLD + ADD      $247.38 | Entry: CAUTION    ⚠️ THIN
# [OK] [9/101] AMGN   -> FULL HOLD + ADD      $326.10 | Entry: EXCELLENT  ✓ SAFE ENTRY
# [OK] [10/101] ADI    -> FULL HOLD + ADD      $300.93 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [11/101] AAPL   -> FULL HOLD + ADD      $259.37 | Entry: CAUTION    ⚠️ THIN
# [OK] [12/101] AMAT   -> FULL HOLD + ADD      $301.18 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [13/101] APP    -> FULL HOLD + ADD      $647.72 | Entry: CAUTION    ⚠️ THIN
# [OK] [15/101] ASML   -> FULL HOLD + ADD      $1,273.88 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [16/101] AZN    -> FULL HOLD + ADD      $94.65 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [21/101] BKR    -> FULL HOLD + ADD      $49.97 | Entry: CAUTION    ⚠️ THIN
# [OK] [22/101] BKNG   -> FULL HOLD + ADD      $5,492.11 | Entry: OK         🎯 ACCEPTABLE
# [OK] [27/101] CSCO   -> FULL HOLD + ADD      $73.88 | Entry: CAUTION    ⚠️ THIN
# [OK] [29/101] CTSH   -> FULL HOLD + ADD      $85.26 | Entry: CAUTION    ⏳ WAIT
# [OK] [36/101] CSX    -> FULL HOLD + ADD      $35.20 | Entry: EXCELLENT  ✓ SAFE ENTRY
# [OK] [41/101] EA     -> FULL HOLD + ADD      $204.10 | Entry: CAUTION    ⚠️ THIN
# [OK] [44/101] FER    -> FULL HOLD + ADD      $66.35 | Entry: CAUTION    ⚠️ THIN
# [OK] [47/101] GILD   -> FULL HOLD + ADD      $121.10 | Entry: OK         🎯 ACCEPTABLE
# [OK] [49/101] IDXX   -> FULL HOLD + ADD      $713.35 | Entry: CAUTION    ⚠️ THIN
#   [50/101] Scanning...
# [OK] [51/101] INTC   -> FULL HOLD + ADD      $45.55 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [53/101] ISRG   -> FULL HOLD + ADD      $586.24 | Entry: CAUTION    ⏳ WAIT
# [OK] [55/101] KLAC   -> FULL HOLD + ADD      $1,400.00 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [57/101] LRCX   -> FULL HOLD + ADD      $218.36 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [59/101] MAR    -> FULL HOLD + ADD      $328.18 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [60/101] MRVL   -> FULL HOLD + ADD      $83.22 | Entry: GOOD       ✓ SAFE ENTRY
# [OK] [64/101] MU     -> FULL HOLD + ADD      $345.09 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [68/101] MPWR   -> FULL HOLD + ADD      $958.97 | Entry: CAUTION    ⚠️ THIN
# [OK] [69/101] MNST   -> FULL HOLD + ADD      $77.34 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [71/101] NVDA   -> FULL HOLD + ADD      $184.86 | Entry: CAUTION    ⚠️ THIN
# [OK] [72/101] NXPI   -> FULL HOLD + ADD      $241.15 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [75/101] PCAR   -> FULL HOLD + ADD      $118.80 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [76/101] PLTR   -> FULL HOLD + ADD      $177.49 | Entry: CAUTION    ⚠️ THIN
# [OK] [82/101] QCOM   -> FULL HOLD + ADD      $177.78 | Entry: CAUTION    ⚠️ THIN
# [OK] [85/101] ROST   -> FULL HOLD + ADD      $191.44 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [86/101] STX    -> FULL HOLD + ADD      $304.01 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [87/101] SHOP   -> FULL HOLD + ADD      $164.48 | Entry: CAUTION    ⚠️ THIN
# [OK] [91/101] TTWO   -> FULL HOLD + ADD      $250.71 | Entry: GOOD       ✓ SAFE ENTRY
# [OK] [92/101] TSLA   -> FULL HOLD + ADD      $445.01 | Entry: CAUTION    ⚠️ THIN
# [OK] [97/101] WBD    -> FULL HOLD + ADD      $28.89 | Entry: CAUTION    ⚠️ EXTENDED
# [OK] [98/101] WDC    -> FULL HOLD + ADD      $200.46 | Entry: CAUTION    ⚠️ EXTENDED
#   [100/101] Scanning...
# ================================================================================
#
# [OK] Scan complete: 101 analyzed, 40 FULL HOLD + ADD signals found
#
#
# [STATS] NASDAQ 100 Results:
#    [OK] 6 buy signals (EXCELLENT/GOOD/OK)
#    [WAIT] 34 extended/weak (wait)
#    [SELL] 51 sell signals (bearish)
#
# [OK] TOP BUY OPPORTUNITIES (EXCELLENT/GOOD/OK quality):
# ticker          signal  current_price buy_quality          s1
#   AMGN FULL HOLD + ADD         326.10   EXCELLENT  312.390015
#   BKNG FULL HOLD + ADD        5492.11    EXTENDED 5319.766202
#    CSX FULL HOLD + ADD          35.20   EXCELLENT   33.506150
#   GILD FULL HOLD + ADD         121.10    EXTENDED  118.000631
#   MRVL FULL HOLD + ADD          83.22        GOOD   81.121628
#   TTWO FULL HOLD + ADD         250.71        GOOD  240.279999
#
# [SELL] SELL SIGNALS (Bearish - reduce exposure):
# ticker             signal  current_price r1_quality         r1
#   ABNB             REDUCE         139.27       GOOD 170.100006
#   ADBE               CASH         333.95    CAUTION 422.950012
#    ADP               CASH         266.02         OK 324.495730
#   ADSK HOLD MOST + REDUCE         276.02    CAUTION 329.089996
#   ALNY HOLD MOST + REDUCE         398.29         OK 495.549988
#    ARM               CASH         111.79         OK 145.000000
#   AXON HOLD MOST + REDUCE         631.69       GOOD 806.640015
#   CDNS HOLD MOST + REDUCE         327.31       GOOD 376.450012
#   CHTR FULL CASH / DEFEND         210.59       GOOD 271.500000
#  CMCSA               CASH          28.37         OK  36.559510
# [OK] Excel file created: c:\workspace\portfolio_analyser\scanner_results\nasdaq100\nasdaq100_analysis_20260110_2254.xlsx
#   - Buy Opportunities: 6 stocks
#   - Sell Opportunities: 51 stocks
# [OK] PDF report created: c:\workspace\portfolio_analyser\scanner_results\nasdaq100\scanner_report_nasdaq100_20260110_2254.pdf
# [OK] Best Trades Excel created: c:\workspace\portfolio_analyser\scanner_results\nasdaq100\nasdaq100_best_trades_20260110_2254.xlsx
# [OK] Best Trades PDF created: c:\workspace\portfolio_analyser\scanner_results\nasdaq100\nasdaq100_best_trades_20260110_2254.pdf
#
# [OK] Excel: nasdaq100/nasdaq100_analysis_20260110_2254.xlsx
# [OK] PDF: nasdaq100/scanner_report_nasdaq100_20260110_2254.pdf
# [OK] Best Trades Excel: nasdaq100/nasdaq100_best_trades_20260110_2254.xlsx
# [OK] Best Trades PDF: nasdaq100/nasdaq100_best_trades_20260110_2254.pdf

# %% [markdown]
# ## Cleanup Old Scan Files
#
# Archive old scan results to keep the scanner_results folder clean. Keeps the 2 most recent files per category (Portfolio, S&P 500, NASDAQ 100).

# %%
print("\n" + "="*80)
print("CLEANUP - Archiving Old Scan Files")
print("="*80)

# Keep 1 most recent scan per category (4 files per scan: 2 standard + 2 best trades)
# Archives older files, deletes archives older than 60 days
cleanup_old_scans(results_dir, max_files=1, archive_retention_days=60)

print("\n[OK] Cleanup complete")
# Out:
# ================================================================================
# CLEANUP - Archiving Old Scan Files
# ================================================================================
#   📦 Archived (sp500): sp500_analysis_20260110_2249.xlsx
#   📦 Archived (sp500): scanner_report_sp500_20260110_2249.pdf
#   📦 Archived (sp500): sp500_best_trades_20260110_2249.xlsx
#   📦 Archived (sp500): sp500_best_trades_20260110_2249.pdf
#   📦 Archived (nasdaq100): nasdaq100_analysis_20260110_2249.xlsx
#   📦 Archived (nasdaq100): scanner_report_nasdaq100_20260110_2249.pdf
#   📦 Archived (nasdaq100): nasdaq100_best_trades_20260110_2249.xlsx
#   📦 Archived (nasdaq100): nasdaq100_best_trades_20260110_2249.pdf
#   📦 Archived (portfolio): portfolio_scanner_20260110_2249.xlsx
#   📦 Archived (portfolio): scanner_report_portfolio_20260110_2249.pdf
#   📦 Archived (portfolio): portfolio_best_trades_20260110_2249.xlsx
#   📦 Archived (portfolio): portfolio_best_trades_20260110_2249.pdf
#   ✅ Archived 12 file(s), kept 1 most recent
#
# [OK] Cleanup complete
