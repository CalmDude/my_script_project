# %%
from pathlib import Path
from datetime import datetime
import pandas as pd
import sys

# Determine root directory - go up from notebooks folder to portfolio_analyser
if Path.cwd().name == 'notebooks':
    ROOT = Path.cwd().parent
else:
    ROOT = Path.cwd()

src_path = ROOT / 'src'

# Add src to path if not already there
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

from full_scanner import (
    get_sp500_tickers,
    get_nasdaq100_tickers,
    get_portfolio_tickers,
    scan_stocks,
    filter_buy_signals,
    filter_sell_signals,
    create_excel_output,
    create_portfolio_excel,
    create_pdf_report,
    cleanup_old_scans  # Added cleanup function
)

# Setup results directory
results_dir = ROOT / 'scanner_results'
results_dir.mkdir(exist_ok=True)

timestamp = datetime.now().strftime("%Y%m%d_%H%M")

print("[OK] Scanner modules loaded")
print(f"[OK] Results directory: {results_dir}")
print(f"[OK] Timestamp: {timestamp}")
# Out:
# [OK] Scanner modules loaded
# [OK] Results directory: c:\workspace\portfolio_analyser\scanner_results
# [OK] Timestamp: 20260109_1034

# %% [markdown]
# ## Configuration
#
# Set your scan parameters:
# - **daily_bars**: Number of daily bars to analyze (default: 60)
# - **weekly_bars**: Number of weekly bars to analyze (default: 52)
# - **concurrency**: Number of parallel workers (default: 2, max recommended: 5)

# %%
# Scan parameters
DAILY_BARS = 60
WEEKLY_BARS = 52
CONCURRENCY = 2  # Be careful with higher values (rate limits)

print(f"Daily bars: {DAILY_BARS}")
print(f"Weekly bars: {WEEKLY_BARS}")
print(f"Concurrency: {CONCURRENCY}")
# Out:
# Daily bars: 60
# Weekly bars: 52
# Concurrency: 2

# %% [markdown]
# ## Scan Portfolio Stocks
#
# Quick scan of your portfolio stocks from stocks.txt. Shows both buy opportunities (FULL HOLD + ADD) and sell signals (bearish signals).

# %%
print("Loading portfolio tickers from stocks.txt...")
portfolio_tickers = get_portfolio_tickers()

if portfolio_tickers:
    print(f"Found {len(portfolio_tickers)} portfolio stocks\n")

    # Run scan
    portfolio_results = scan_stocks(
        portfolio_tickers,
        category="Portfolio",
        daily_bars=DAILY_BARS,
        weekly_bars=WEEKLY_BARS,
        concurrency=CONCURRENCY
    )

    if not portfolio_results.empty:
        # Get buy signals (all and quality-filtered)
        portfolio_buy_all = filter_buy_signals(portfolio_results, 'FULL HOLD + ADD', quality_filter=False)
        portfolio_buy = filter_buy_signals(portfolio_results, 'FULL HOLD + ADD', quality_filter=True)
        
        # Get sell signals (all bearish signals)
        portfolio_sell = filter_sell_signals(portfolio_results, quality_filter=False)
        
        # Display summary
        print(f"\n[STATS] Portfolio Results:")
        print(f"   [OK] {len(portfolio_buy)} buy signals (EXCELLENT/GOOD/OK)")
        if len(portfolio_buy_all) > len(portfolio_buy):
            print(f"   [WAIT] {len(portfolio_buy_all) - len(portfolio_buy)} extended/weak (wait)")
        print(f"   [SELL] {len(portfolio_sell)} sell signals (bearish)")
        
        # Display buy opportunities
        if not portfolio_buy.empty:
            print("\n[OK] BUY OPPORTUNITIES (EXCELLENT/GOOD/OK quality):")
            display_cols = ['ticker', 'signal', 'current_price', 'buy_quality', 's1']
            if all(col in portfolio_buy.columns for col in display_cols):
                print(portfolio_buy[display_cols].to_string(index=False))
            else:
                print(portfolio_buy[['ticker', 'signal', 'current_price']].to_string(index=False))
        
        # Display sell signals
        if not portfolio_sell.empty:
            print("\n[SELL] SELL SIGNALS (Bearish - reduce exposure):")
            display_cols = ['ticker', 'signal', 'current_price', 'r1_quality', 'r1']
            if all(col in portfolio_sell.columns for col in display_cols):
                print(portfolio_sell[display_cols].to_string(index=False))
            else:
                print(portfolio_sell[['ticker', 'signal', 'current_price']].to_string(index=False))
        
        # Save combined results
        if not portfolio_buy.empty or not portfolio_sell.empty:
            xlsx_path = results_dir / f'portfolio_scanner_{timestamp}.xlsx'
            pdf_path = results_dir / f'scanner_report_portfolio_{timestamp}.pdf'
            
            # Create reports with both buy and sell data
            create_excel_output(portfolio_buy, portfolio_sell, xlsx_path, category="Portfolio")
            create_pdf_report(portfolio_buy, portfolio_sell, pdf_path, timestamp, category="Portfolio")
            
            print(f"\n[OK] Excel: {xlsx_path.name}")
            print(f"[OK] PDF: {pdf_path.name}")
else:
    print("[WARN] No portfolio tickers found in stocks.txt")
# Out:
# Loading portfolio tickers from stocks.txt...
# [OK] Loaded 9 portfolio tickers from stocks.txt
#
# Found 9 portfolio stocks
#
# [SCAN] Scanning 9 Portfolio stocks for 'FULL HOLD + ADD' signals...
# Parameters: 60 daily bars, 52 weekly bars, 2 threads
# ================================================================================
# [OK] [1/9] NVDA   -> FULL HOLD + ADD      $185.04 | Quality: EXTENDED   ⚠
# [OK] [2/9] TSLA   -> FULL HOLD + ADD      $435.80 | Quality: EXTENDED   ⚠
# [OK] [4/9] ASML   -> FULL HOLD + ADD      $1,194.32 | Quality: EXTENDED   ⚠
# [OK] [7/9] MRVL   -> FULL HOLD + ADD      $83.45 | Quality: OK         ✓
# ================================================================================
#
# [OK] Scan complete: 9 analyzed, 4 FULL HOLD + ADD signals found
#
#
# [STATS] Portfolio Results:
#    [OK] 1 buy signals (EXCELLENT/GOOD/OK)
#    [WAIT] 3 extended/weak (wait)
#    [SELL] 3 sell signals (bearish)
#
# [OK] BUY OPPORTUNITIES (EXCELLENT/GOOD/OK quality):
# ticker          signal  current_price buy_quality    s1
#   MRVL FULL HOLD + ADD          83.45          OK 81.18
#
# [SELL] SELL SIGNALS (Bearish - reduce exposure):
#  ticker             signal  current_price r1_quality            r1
#    ALAB HOLD MOST + REDUCE       156.7300    CAUTION    201.860001
# BTC-USD HOLD MOST + REDUCE     90272.1640    CAUTION 116273.312500
# SOL-USD               CASH       138.8172    CAUTION    178.634644
# [OK] Excel file created: c:\workspace\portfolio_analyser\scanner_results\portfolio_scanner_20260109_1034.xlsx
#   - Buy Opportunities: 1 stocks
#   - Sell Signals: 3 stocks
# [OK] PDF report created: c:\workspace\portfolio_analyser\scanner_results\scanner_report_portfolio_20260109_1034.pdf
#
# [OK] Excel: portfolio_scanner_20260109_1034.xlsx
# [OK] PDF: scanner_report_portfolio_20260109_1034.pdf

# %% [markdown]
# ## Scan S&P 500
#
# Full scan of ~500 stocks. Takes 5-10 minutes depending on cache. Shows both buy opportunities (FULL HOLD + ADD) and sell signals (bearish signals).

# %%
print("Fetching S&P 500 ticker list...")
sp500_tickers = get_sp500_tickers()
print(f"Found {len(sp500_tickers)} S&P 500 stocks\n")

# Run scan
sp500_results = scan_stocks(
    sp500_tickers,
    category="S&P 500",
    daily_bars=DAILY_BARS,
    weekly_bars=WEEKLY_BARS,
    concurrency=CONCURRENCY
)

if not sp500_results.empty:
    # Get buy signals (all and quality-filtered)
    sp500_buy_all = filter_buy_signals(sp500_results, 'FULL HOLD + ADD', quality_filter=False)
    sp500_buy = filter_buy_signals(sp500_results, 'FULL HOLD + ADD', quality_filter=True)
    
    # Get sell signals (all bearish signals, matching portfolio_analysis logic)
    sp500_sell = filter_sell_signals(sp500_results, quality_filter=False)
    
    # Display summary
    print(f"\n[STATS] S&P 500 Results:")
    print(f"   [OK] {len(sp500_buy)} buy signals (EXCELLENT/GOOD/OK)")
    if len(sp500_buy_all) > len(sp500_buy):
        print(f"   [WAIT] {len(sp500_buy_all) - len(sp500_buy)} extended/weak (wait)")
    print(f"   [SELL] {len(sp500_sell)} sell signals (bearish)")
    
    # Display buy opportunities
    if not sp500_buy.empty:
        print("\n[OK] TOP BUY OPPORTUNITIES (EXCELLENT/GOOD/OK quality):")
        display_cols = ['ticker', 'signal', 'current_price', 'buy_quality', 's1']
        if all(col in sp500_buy.columns for col in display_cols):
            print(sp500_buy[display_cols].head(10).to_string(index=False))
        else:
            print(sp500_buy[['ticker', 'signal', 'current_price']].head(10).to_string(index=False))
    
    # Display sell signals (matches portfolio_analysis behavior)
    if not sp500_sell.empty:
        print("\n[SELL] SELL SIGNALS (Bearish - reduce exposure):")
        display_cols = ['ticker', 'signal', 'current_price', 'r1_quality', 'r1']
        if all(col in sp500_sell.columns for col in display_cols):
            print(sp500_sell[display_cols].head(10).to_string(index=False))
        else:
            print(sp500_sell[['ticker', 'signal', 'current_price']].head(10).to_string(index=False))
    
    # Save combined results if we have either buy or sell signals
    if not sp500_buy.empty or not sp500_sell.empty:
        xlsx_path = results_dir / f'sp500_analysis_{timestamp}.xlsx'
        pdf_path = results_dir / f'scanner_report_sp500_{timestamp}.pdf'
        
        # Create reports with both buy and sell data
        create_excel_output(sp500_buy, sp500_sell, xlsx_path, category="S&P 500")
        create_pdf_report(sp500_buy, sp500_sell, pdf_path, timestamp, category="S&P 500")
        
        print(f"\n[OK] Excel: {xlsx_path.name}")
        print(f"[OK] PDF: {pdf_path.name}")
else:
    print("[WARN] No results from S&P 500 scan")
# Out:
# Fetching S&P 500 ticker list...
# [OK] Loaded 503 S&P 500 tickers
#
# Found 503 S&P 500 stocks
#
# [SCAN] Scanning 503 S&P 500 stocks for 'FULL HOLD + ADD' signals...
# Parameters: 60 daily bars, 52 weekly bars, 2 threads
# ================================================================================
# [OK] [4/503] ABBV   -> FULL HOLD + ADD      $224.13 | Quality: EXTENDED   ⚠
# [OK] [9/503] AFL    -> FULL HOLD + ADD      $110.26 | Quality: OK         ✓
# [OK] [14/503] ALB    -> FULL HOLD + ADD      $158.31 | Quality: EXTENDED   ⚠
# [OK] [19/503] ALL    -> FULL HOLD + ADD      $211.10 | Quality: EXTENDED   ⚠
# [OK] [20/503] GOOGL  -> FULL HOLD + ADD      $325.44 | Quality: EXTENDED   ⚠
# [OK] [21/503] GOOG   -> FULL HOLD + ADD      $326.01 | Quality: EXTENDED   ⚠
# [OK] [23/503] AMZN   -> FULL HOLD + ADD      $246.29 | Quality: EXTENDED   ⚠
# [OK] [27/503] AXP    -> FULL HOLD + ADD      $382.98 | Quality: EXTENDED   ⚠
# [OK] [29/503] AIG    -> FULL HOLD + ADD      $77.90 | Quality: CAUTION    ⚠
# [OK] [32/503] AME    -> FULL HOLD + ADD      $210.04 | Quality: EXTENDED   ⚠
# [OK] [33/503] AMGN   -> FULL HOLD + ADD      $330.11 | Quality: GOOD       ✓
# [OK] [34/503] APH    -> FULL HOLD + ADD      $136.25 | Quality: EXTENDED   ⚠
# [OK] [35/503] ADI    -> FULL HOLD + ADD      $299.16 | Quality: EXTENDED   ⚠
# [OK] [38/503] APO    -> FULL HOLD + ADD      $146.19 | Quality: GOOD       ✓
# [OK] [39/503] AAPL   -> FULL HOLD + ADD      $259.04 | Quality: EXTENDED   ⚠
# [OK] [40/503] AMAT   -> FULL HOLD + ADD      $281.64 | Quality: EXTENDED   ⚠
# [OK] [41/503] APP    -> FULL HOLD + ADD      $616.53 | Quality: EXTENDED   ⚠
# [OK] [43/503] ACGL   -> FULL HOLD + ADD      $96.38 | Quality: CAUTION    ⚠
# [OK] [45/503] ARES   -> FULL HOLD + ADD      $175.75 | Quality: EXCELLENT  ✓
# [OK] [48/503] AIZ    -> FULL HOLD + ADD      $238.02 | Quality: OK         ✓
#   [50/503] Scanning...
# [OK] [59/503] BAC    -> FULL HOLD + ADD      $56.18 | Quality: EXTENDED   ⚠
# [OK] [62/503] BRK-B  -> FULL HOLD + ADD      $499.77 | Quality: CAUTION    ⚠
# [OK] [69/503] BK     -> FULL HOLD + ADD      $120.05 | Quality: EXTENDED   ⚠
# [OK] [70/503] BA     -> FULL HOLD + ADD      $227.38 | Quality: EXCELLENT  ✓
# [OK] [71/503] BKNG   -> FULL HOLD + ADD      $5,445.00 | Quality: EXTENDED   ⚠
# [OK] [79/503] BG     -> FULL HOLD + ADD      $97.51 | Quality: EXCELLENT  ✓
# [OK] [81/503] CHRW   -> FULL HOLD + ADD      $166.01 | Quality: EXTENDED   ⚠
# [OK] [85/503] COF    -> FULL HOLD + ADD      $255.68 | Quality: EXTENDED   ⚠
# [OK] [86/503] CAH    -> FULL HOLD + ADD      $202.49 | Quality: EXTENDED   ⚠
# [OK] [87/503] CCL    -> FULL HOLD + ADD      $31.69 | Quality: EXTENDED   ⚠
# [OK] [89/503] CVNA   -> FULL HOLD + ADD      $442.58 | Quality: EXTENDED   ⚠
# [OK] [90/503] CAT    -> FULL HOLD + ADD      $608.13 | Quality: EXTENDED   ⚠
# [OK] [91/503] CBOE   -> FULL HOLD + ADD      $260.54 | Quality: OK         ✓
# [OK] [92/503] CBRE   -> FULL HOLD + ADD      $165.96 | Quality: EXTENDED   ⚠
# [OK] [94/503] COR    -> FULL HOLD + ADD      $335.74 | Quality: GOOD       ✓
# [OK] [99/503] SCHW   -> FULL HOLD + ADD      $101.34 | Quality: EXTENDED   ⚠
#   [100/503] Scanning...
# [OK] [101/503] CVX    -> FULL HOLD + ADD      $159.25 | Quality: CAUTION    ⚠
# [OK] [103/503] CB     -> FULL HOLD + ADD      $313.00 | Quality: GOOD       ✓
# [OK] [106/503] CINF   -> FULL HOLD + ADD      $165.19 | Quality: EXTENDED   ⚠
# [OK] [107/503] CSCO   -> FULL HOLD + ADD      $73.96 | Quality: EXTENDED   ⚠
# [OK] [109/503] CFG    -> FULL HOLD + ADD      $61.23 | Quality: EXTENDED   ⚠
# [OK] [110/503] C      -> FULL HOLD + ADD      $120.60 | Quality: EXTENDED   ⚠
# [OK] [112/503] CME    -> FULL HOLD + ADD      $266.64 | Quality: CAUTION    ⚠
# [OK] [115/503] CTSH   -> FULL HOLD + ADD      $85.77 | Quality: GOOD       ✓
# [OK] [119/503] FIX    -> FULL HOLD + ADD      $971.49 | Quality: EXTENDED   ⚠
# [OK] [127/503] GLW    -> FULL HOLD + ADD      $85.33 | Quality: EXTENDED   ⚠
# [OK] [129/503] CTVA   -> FULL HOLD + ADD      $70.14 | Quality: GOOD       ✓
# [OK] [132/503] CTRA   -> FULL HOLD + ADD      $25.41 | Quality: GOOD       ✓
# [OK] [133/503] CRH    -> FULL HOLD + ADD      $124.65 | Quality: OK         ✓
# [OK] [136/503] CSX    -> FULL HOLD + ADD      $35.32 | Quality: OK         ✓
# [OK] [137/503] CMI    -> FULL HOLD + ADD      $544.49 | Quality: EXTENDED   ⚠
# [OK] [138/503] CVS    -> FULL HOLD + ADD      $80.60 | Quality: OK         ✓
# [OK] [143/503] DAY    -> FULL HOLD + ADD      $69.43 | Quality: OK         ✓
# [OK] [147/503] DAL    -> FULL HOLD + ADD      $71.29 | Quality: EXTENDED   ⚠
#   [150/503] Scanning...
# [OK] [152/503] DG     -> FULL HOLD + ADD      $144.00 | Quality: EXTENDED   ⚠
# [OK] [153/503] DLTR   -> FULL HOLD + ADD      $131.61 | Quality: EXTENDED   ⚠
# [OK] [157/503] DOV    -> FULL HOLD + ADD      $201.99 | Quality: GOOD       ✓
# [OK] [162/503] DD     -> FULL HOLD + ADD      $43.40 | Quality: EXTENDED   ⚠
# [OK] [167/503] EW     -> FULL HOLD + ADD      $84.58 | Quality: GOOD       ✓
# [OK] [168/503] EA     -> FULL HOLD + ADD      $204.22 | Quality: GOOD       ✓
# [OK] [171/503] EMR    -> FULL HOLD + ADD      $143.85 | Quality: EXTENDED   ⚠
# [OK] [187/503] EXPE   -> FULL HOLD + ADD      $301.31 | Quality: EXTENDED   ⚠
# [OK] [188/503] EXPD   -> FULL HOLD + ADD      $158.15 | Quality: EXTENDED   ⚠
# [OK] [190/503] XOM    -> FULL HOLD + ADD      $122.91 | Quality: GOOD       ✓
# [OK] [195/503] FRT    -> FULL HOLD + ADD      $102.80 | Quality: OK         ✓
# [OK] [196/503] FDX    -> FULL HOLD + ADD      $309.01 | Quality: EXTENDED   ⚠
# [OK] [198/503] FITB   -> FULL HOLD + ADD      $49.82 | Quality: EXTENDED   ⚠
# [OK] [199/503] FSLR   -> FULL HOLD + ADD      $246.26 | Quality: EXTENDED   ⚠
#   [200/503] Scanning...
# [OK] [202/503] F      -> FULL HOLD + ADD      $14.40 | Quality: EXTENDED   ⚠
# [OK] [205/503] FOXA   -> FULL HOLD + ADD      $75.69 | Quality: EXTENDED   ⚠
# [OK] [206/503] FOX    -> FULL HOLD + ADD      $67.55 | Quality: EXTENDED   ⚠
# [OK] [207/503] BEN    -> FULL HOLD + ADD      $25.45 | Quality: EXCELLENT  ✓
# [OK] [208/503] FCX    -> FULL HOLD + ADD      $54.22 | Quality: EXTENDED   ⚠
# [OK] [211/503] GE     -> FULL HOLD + ADD      $314.44 | Quality: EXTENDED   ⚠
# [OK] [213/503] GEV    -> FULL HOLD + ADD      $628.40 | Quality: EXTENDED   ⚠
# [OK] [216/503] GD     -> FULL HOLD + ADD      $351.44 | Quality: EXTENDED   ⚠
# [OK] [218/503] GM     -> FULL HOLD + ADD      $85.13 | Quality: EXTENDED   ⚠
# [OK] [220/503] GILD   -> FULL HOLD + ADD      $120.67 | Quality: EXTENDED   ⚠
# [OK] [222/503] GL     -> FULL HOLD + ADD      $142.47 | Quality: OK         ✓
# [OK] [224/503] GS     -> FULL HOLD + ADD      $934.83 | Quality: EXTENDED   ⚠
# [OK] [226/503] HIG    -> FULL HOLD + ADD      $137.91 | Quality: EXTENDED   ⚠
# [OK] [227/503] HAS    -> FULL HOLD + ADD      $89.14 | Quality: EXTENDED   ⚠
# [OK] [228/503] HCA    -> FULL HOLD + ADD      $479.02 | Quality: EXTENDED   ⚠
# [OK] [230/503] HSIC   -> FULL HOLD + ADD      $79.00 | Quality: GOOD       ✓
# [OK] [231/503] HSY    -> FULL HOLD + ADD      $184.75 | Quality: OK         ✓
# [OK] [232/503] HPE    -> FULL HOLD + ADD      $22.02 | Quality: OK         ✓
# [OK] [233/503] HLT    -> FULL HOLD + ADD      $298.33 | Quality: EXTENDED   ⚠
# [OK] [238/503] HWM    -> FULL HOLD + ADD      $210.02 | Quality: EXTENDED   ⚠
# [OK] [239/503] HST    -> FULL HOLD + ADD      $18.21 | Quality: GOOD       ✓
# [OK] [240/503] HUBB   -> FULL HOLD + ADD      $460.87 | Quality: OK         ✓
# [OK] [243/503] HBAN   -> FULL HOLD + ADD      $18.47 | Quality: EXTENDED   ⚠
# [OK] [244/503] HII    -> FULL HOLD + ADD      $378.47 | Quality: EXTENDED   ⚠
# [OK] [245/503] IBM    -> FULL HOLD + ADD      $302.72 | Quality: EXTENDED   ⚠
# [OK] [247/503] IDXX   -> FULL HOLD + ADD      $712.39 | Quality: EXTENDED   ⚠
# [OK] [249/503] INCY   -> FULL HOLD + ADD      $105.92 | Quality: EXTENDED   ⚠
#   [250/503] Scanning...
# [OK] [252/503] INTC   -> FULL HOLD + ADD      $41.11 | Quality: EXTENDED   ⚠
# [OK] [253/503] IBKR   -> FULL HOLD + ADD      $70.16 | Quality: EXTENDED   ⚠
# [OK] [258/503] ISRG   -> FULL HOLD + ADD      $585.08 | Quality: GOOD       ✓
# [OK] [259/503] IVZ    -> FULL HOLD + ADD      $28.27 | Quality: EXTENDED   ⚠
# [OK] [261/503] IQV    -> FULL HOLD + ADD      $243.19 | Quality: EXCELLENT  ✓
# [OK] [263/503] JBHT   -> FULL HOLD + ADD      $205.42 | Quality: EXTENDED   ⚠
# [OK] [264/503] JBL    -> FULL HOLD + ADD      $221.81 | Quality: EXTENDED   ⚠
# [OK] [265/503] JKHY   -> FULL HOLD + ADD      $187.75 | Quality: OK         ✓
# [OK] [267/503] JNJ    -> FULL HOLD + ADD      $205.75 | Quality: EXTENDED   ⚠
# [OK] [268/503] JCI    -> FULL HOLD + ADD      $111.29 | Quality: EXTENDED   ⚠
# [OK] [269/503] JPM    -> FULL HOLD + ADD      $329.79 | Quality: EXTENDED   ⚠
# [OK] [272/503] KEY    -> FULL HOLD + ADD      $21.50 | Quality: EXTENDED   ⚠
# [OK] [273/503] KEYS   -> FULL HOLD + ADD      $206.67 | Quality: EXTENDED   ⚠
# [OK] [276/503] KMI    -> FULL HOLD + ADD      $27.27 | Quality: CAUTION    ⚠
# [OK] [277/503] KKR    -> FULL HOLD + ADD      $133.64 | Quality: GOOD       ✓
# [OK] [278/503] KLAC   -> FULL HOLD + ADD      $1,324.60 | Quality: EXTENDED   ⚠
# [OK] [281/503] LHX    -> FULL HOLD + ADD      $325.74 | Quality: EXTENDED   ⚠
# [OK] [283/503] LRCX   -> FULL HOLD + ADD      $200.96 | Quality: EXTENDED   ⚠
# [OK] [285/503] LVS    -> FULL HOLD + ADD      $61.90 | Quality: EXTENDED   ⚠
# [OK] [286/503] LDOS   -> FULL HOLD + ADD      $195.22 | Quality: OK         ✓
# [OK] [289/503] LLY    -> FULL HOLD + ADD      $1,085.19 | Quality: EXTENDED   ⚠
# [OK] [292/503] LMT    -> FULL HOLD + ADD      $518.44 | Quality: EXTENDED   ⚠
# [OK] [293/503] LOW    -> FULL HOLD + ADD      $256.21 | Quality: GOOD       ✓
# [OK] [294/503] L      -> FULL HOLD + ADD      $105.49 | Quality: EXTENDED   ⚠
# [OK] [297/503] MTB    -> FULL HOLD + ADD      $213.61 | Quality: EXTENDED   ⚠
# [OK] [299/503] MAR    -> FULL HOLD + ADD      $324.91 | Quality: EXTENDED   ⚠
#   [300/503] Scanning...
# [OK] [301/503] MLM    -> FULL HOLD + ADD      $638.11 | Quality: OK         ✓
# [OK] [304/503] MA     -> FULL HOLD + ADD      $580.07 | Quality: CAUTION    ⚠
# [OK] [305/503] MCD    -> FULL HOLD + ADD      $308.88 | Quality: CAUTION    ⚠
# [OK] [307/503] MCK    -> FULL HOLD + ADD      $814.63 | Quality: EXTENDED   ⚠
# [OK] [308/503] MDT    -> FULL HOLD + ADD      $98.69 | Quality: EXTENDED   ⚠
# [OK] [311/503] MET    -> FULL HOLD + ADD      $79.78 | Quality: CAUTION    ⚠
# [OK] [312/503] MTD    -> FULL HOLD + ADD      $1,465.20 | Quality: GOOD       ✓
# [OK] [315/503] MU     -> FULL HOLD + ADD      $327.02 | Quality: EXTENDED   ⚠
# [OK] [322/503] MPWR   -> FULL HOLD + ADD      $959.09 | Quality: EXTENDED   ⚠
# [OK] [323/503] MNST   -> FULL HOLD + ADD      $76.60 | Quality: EXTENDED   ⚠
# [OK] [324/503] MCO    -> FULL HOLD + ADD      $531.17 | Quality: CAUTION    ⚠
# [OK] [326/503] MS     -> FULL HOLD + ADD      $184.68 | Quality: EXTENDED   ⚠
# [OK] [328/503] MSCI   -> FULL HOLD + ADD      $581.33 | Quality: GOOD       ✓
# [OK] [330/503] NDAQ   -> FULL HOLD + ADD      $99.74 | Quality: EXTENDED   ⚠
# [OK] [332/503] NEM    -> FULL HOLD + ADD      $106.89 | Quality: EXTENDED   ⚠
# [OK] [338/503] NDSN   -> FULL HOLD + ADD      $255.26 | Quality: GOOD       ✓
# [OK] [339/503] NSC    -> FULL HOLD + ADD      $289.72 | Quality: EXTENDED   ⚠
# [OK] [340/503] NTRS   -> FULL HOLD + ADD      $144.36 | Quality: EXTENDED   ⚠
# [OK] [341/503] NOC    -> FULL HOLD + ADD      $590.79 | Quality: EXTENDED   ⚠
# [OK] [344/503] NVDA   -> FULL HOLD + ADD      $185.04 | Quality: EXTENDED   ⚠
# [OK] [345/503] NUE    -> FULL HOLD + ADD      $167.88 | Quality: EXCELLENT  ✓
# [OK] [347/503] NXPI   -> FULL HOLD + ADD      $237.89 | Quality: EXCELLENT  ✓
#   [350/503] Scanning...
# [OK] [356/503] PCAR   -> FULL HOLD + ADD      $118.20 | Quality: EXTENDED   ⚠
# [OK] [357/503] PKG    -> FULL HOLD + ADD      $213.88 | Quality: OK         ✓
# [OK] [358/503] PLTR   -> FULL HOLD + ADD      $176.86 | Quality: EXTENDED   ⚠
# [OK] [361/503] PH     -> FULL HOLD + ADD      $906.47 | Quality: EXTENDED   ⚠
# [OK] [370/503] PSX    -> FULL HOLD + ADD      $144.22 | Quality: OK         ✓
# [OK] [372/503] PNC    -> FULL HOLD + ADD      $218.64 | Quality: EXTENDED   ⚠
# [OK] [376/503] PFG    -> FULL HOLD + ADD      $91.73 | Quality: CAUTION    ⚠
# [OK] [379/503] PLD    -> FULL HOLD + ADD      $128.39 | Quality: GOOD       ✓
# [OK] [380/503] PRU    -> FULL HOLD + ADD      $118.72 | Quality: EXCELLENT  ✓
# [OK] [386/503] QCOM   -> FULL HOLD + ADD      $181.87 | Quality: OK         ✓
# [OK] [389/503] RL     -> FULL HOLD + ADD      $365.07 | Quality: EXTENDED   ⚠
# [OK] [390/503] RJF    -> FULL HOLD + ADD      $168.38 | Quality: EXTENDED   ⚠
# [OK] [391/503] RTX    -> FULL HOLD + ADD      $187.17 | Quality: EXTENDED   ⚠
# [OK] [395/503] RF     -> FULL HOLD + ADD      $28.84 | Quality: EXTENDED   ⚠
# [OK] [400/503] ROK    -> FULL HOLD + ADD      $403.66 | Quality: EXTENDED   ⚠
# [OK] [401/503] ROL    -> FULL HOLD + ADD      $60.21 | Quality: EXTENDED   ⚠
# [OK] [403/503] ROST   -> FULL HOLD + ADD      $189.27 | Quality: EXTENDED   ⚠
# [OK] [405/503] SPGI   -> FULL HOLD + ADD      $541.56 | Quality: EXCELLENT  ✓
# [OK] [407/503] SNDK   -> FULL HOLD + ADD      $334.54 | Quality: EXTENDED   ⚠
# [OK] [410/503] STX    -> FULL HOLD + ADD      $284.47 | Quality: EXTENDED   ⚠
# [OK] [414/503] SPG    -> FULL HOLD + ADD      $184.98 | Quality: OK         ✓
# [OK] [418/503] SNA    -> FULL HOLD + ADD      $361.31 | Quality: EXTENDED   ⚠
# [OK] [419/503] SOLV   -> FULL HOLD + ADD      $85.77 | Quality: EXTENDED   ⚠
# [OK] [421/503] LUV    -> FULL HOLD + ADD      $42.92 | Quality: EXTENDED   ⚠
# [OK] [424/503] STT    -> FULL HOLD + ADD      $132.80 | Quality: EXTENDED   ⚠
# [OK] [425/503] STLD   -> FULL HOLD + ADD      $172.16 | Quality: EXTENDED   ⚠
# [OK] [426/503] STE    -> FULL HOLD + ADD      $260.68 | Quality: OK         ✓
# [OK] [429/503] SYF    -> FULL HOLD + ADD      $87.73 | Quality: EXTENDED   ⚠
# [OK] [433/503] TROW   -> FULL HOLD + ADD      $108.57 | Quality: EXCELLENT  ✓
# [OK] [434/503] TTWO   -> FULL HOLD + ADD      $252.38 | Quality: OK         ✓
# [OK] [435/503] TPR    -> FULL HOLD + ADD      $133.52 | Quality: EXTENDED   ⚠
# [OK] [436/503] TRGP   -> FULL HOLD + ADD      $176.76 | Quality: GOOD       ✓
# [OK] [438/503] TEL    -> FULL HOLD + ADD      $228.03 | Quality: EXTENDED   ⚠
# [OK] [440/503] TSLA   -> FULL HOLD + ADD      $435.80 | Quality: EXTENDED   ⚠
# [OK] [441/503] TER    -> FULL HOLD + ADD      $216.31 | Quality: EXTENDED   ⚠
# [OK] [444/503] TXT    -> FULL HOLD + ADD      $91.71 | Quality: EXCELLENT  ✓
# [OK] [445/503] TMO    -> FULL HOLD + ADD      $606.50 | Quality: GOOD       ✓
# [OK] [446/503] TJX    -> FULL HOLD + ADD      $158.25 | Quality: EXTENDED   ⚠
# [OK] [447/503] TKO    -> FULL HOLD + ADD      $202.09 | Quality: EXTENDED   ⚠
#   [450/503] Scanning...
# [OK] [451/503] TDG    -> FULL HOLD + ADD      $1,377.42 | Quality: CAUTION    ⚠
# [OK] [452/503] TRMB   -> FULL HOLD + ADD      $79.51 | Quality: EXTENDED   ⚠
# [OK] [453/503] TRV    -> FULL HOLD + ADD      $284.18 | Quality: EXTENDED   ⚠
# [OK] [454/503] TFC    -> FULL HOLD + ADD      $50.95 | Quality: EXTENDED   ⚠
# [OK] [457/503] USB    -> FULL HOLD + ADD      $55.53 | Quality: EXTENDED   ⚠
# [OK] [460/503] ULTA   -> FULL HOLD + ADD      $657.46 | Quality: EXTENDED   ⚠
# [OK] [461/503] UNP    -> FULL HOLD + ADD      $229.85 | Quality: EXCELLENT  ✓
# [OK] [462/503] UAL    -> FULL HOLD + ADD      $115.47 | Quality: EXTENDED   ⚠
# [OK] [466/503] UHS    -> FULL HOLD + ADD      $211.14 | Quality: OK         ✓
# [OK] [467/503] VLO    -> FULL HOLD + ADD      $191.32 | Quality: EXTENDED   ⚠
# [OK] [469/503] VTR    -> FULL HOLD + ADD      $75.08 | Quality: EXTENDED   ⚠
# [OK] [474/503] VTRS   -> FULL HOLD + ADD      $12.60 | Quality: EXTENDED   ⚠
# [OK] [476/503] V      -> FULL HOLD + ADD      $352.23 | Quality: CAUTION    ⚠
# [OK] [478/503] VMC    -> FULL HOLD + ADD      $299.13 | Quality: OK         ✓
# [OK] [481/503] WAB    -> FULL HOLD + ADD      $222.44 | Quality: CAUTION    ⚠
# [OK] [482/503] WMT    -> FULL HOLD + ADD      $113.07 | Quality: EXTENDED   ⚠
# [OK] [483/503] DIS    -> FULL HOLD + ADD      $114.17 | Quality: OK         ✓
# [OK] [484/503] WBD    -> FULL HOLD + ADD      $28.32 | Quality: EXTENDED   ⚠
# [OK] [486/503] WAT    -> FULL HOLD + ADD      $396.65 | Quality: EXTENDED   ⚠
# [OK] [488/503] WFC    -> FULL HOLD + ADD      $95.60 | Quality: EXTENDED   ⚠
# [OK] [489/503] WELL   -> FULL HOLD + ADD      $186.31 | Quality: EXTENDED   ⚠
# [OK] [491/503] WDC    -> FULL HOLD + ADD      $187.68 | Quality: EXTENDED   ⚠
# [OK] [494/503] WMB    -> FULL HOLD + ADD      $61.15 | Quality: CAUTION    ⚠
# [OK] [496/503] WTW    -> FULL HOLD + ADD      $333.14 | Quality: OK         ✓
# [OK] [500/503] YUM    -> FULL HOLD + ADD      $153.48 | Quality: CAUTION    ⚠
# ================================================================================
#
# [OK] Scan complete: 502 analyzed, 207 FULL HOLD + ADD signals found
#
#
# [STATS] S&P 500 Results:
#    [OK] 59 buy signals (EXCELLENT/GOOD/OK)
#    [WAIT] 148 extended/weak (wait)
#    [SELL] 244 sell signals (bearish)
#
# [OK] TOP BUY OPPORTUNITIES (EXCELLENT/GOOD/OK quality):
# ticker          signal  current_price buy_quality         s1
#    AFL FULL HOLD + ADD         110.26          OK 107.010002
#    AIZ FULL HOLD + ADD         238.02          OK 219.529999
#   AMGN FULL HOLD + ADD         330.11        GOOD 312.390015
#    APO FULL HOLD + ADD         146.19        GOOD 136.732423
#   ARES FULL HOLD + ADD         175.75   EXCELLENT 171.505122
#     BA FULL HOLD + ADD         227.38   EXCELLENT 215.899994
#    BEN FULL HOLD + ADD          25.45   EXCELLENT  23.691865
#     BG FULL HOLD + ADD          97.51   EXCELLENT  96.611937
#     CB FULL HOLD + ADD         313.00        GOOD 291.029999
#   CBOE FULL HOLD + ADD         260.54          OK 244.740005
#
# [SELL] SELL SIGNALS (Bearish - reduce exposure):
# ticker             signal  current_price r1_quality         r1
#   ABNB             REDUCE         138.66    CAUTION 170.100006
#    ABT HOLD MOST + REDUCE         126.18    CAUTION 139.331050
#    ACN             REDUCE         281.82    CAUTION 365.911704
#   ADBE               CASH         339.04    CAUTION 422.950012
#    ADP               CASH         265.67    CAUTION 324.495730
#   ADSK HOLD MOST + REDUCE         276.58    CAUTION 329.089996
#    AEE HOLD MOST + REDUCE          99.54    CAUTION 105.967030
#    AJG FULL CASH / DEFEND         264.54    CAUTION 343.276861
#   AKAM             REDUCE          85.71    CAUTION 109.239998
#   ALGN             REDUCE         170.58    CAUTION 208.309998
# [OK] Excel file created: c:\workspace\portfolio_analyser\scanner_results\sp500_analysis_20260109_1034.xlsx
#   - Buy Opportunities: 59 stocks
#   - Sell Signals: 244 stocks
# [OK] PDF report created: c:\workspace\portfolio_analyser\scanner_results\scanner_report_sp500_20260109_1034.pdf
#
# [OK] Excel: sp500_analysis_20260109_1034.xlsx
# [OK] PDF: scanner_report_sp500_20260109_1034.pdf

# %% [markdown]
# ## Scan NASDAQ 100
#
# Scan ~100 tech-heavy stocks. Takes 2-5 minutes. Shows both buy opportunities (FULL HOLD + ADD) and sell signals (bearish signals).

# %%
print("Fetching NASDAQ 100 ticker list...")
nasdaq100_tickers = get_nasdaq100_tickers()
print(f"Found {len(nasdaq100_tickers)} NASDAQ 100 stocks\n")

# Run scan
nasdaq100_results = scan_stocks(
    nasdaq100_tickers,
    category="NASDAQ 100",
    daily_bars=DAILY_BARS,
    weekly_bars=WEEKLY_BARS,
    concurrency=CONCURRENCY
)

if not nasdaq100_results.empty:
    # Get buy signals (all and quality-filtered)
    nasdaq100_buy_all = filter_buy_signals(nasdaq100_results, 'FULL HOLD + ADD', quality_filter=False)
    nasdaq100_buy = filter_buy_signals(nasdaq100_results, 'FULL HOLD + ADD', quality_filter=True)
    
    # Get sell signals (all bearish signals, matching portfolio_analysis logic)
    nasdaq100_sell = filter_sell_signals(nasdaq100_results, quality_filter=False)
    
    # Display summary
    print(f"\n[STATS] NASDAQ 100 Results:")
    print(f"   [OK] {len(nasdaq100_buy)} buy signals (EXCELLENT/GOOD/OK)")
    if len(nasdaq100_buy_all) > len(nasdaq100_buy):
        print(f"   [WAIT] {len(nasdaq100_buy_all) - len(nasdaq100_buy)} extended/weak (wait)")
    print(f"   [SELL] {len(nasdaq100_sell)} sell signals (bearish)")
    
    # Display buy opportunities
    if not nasdaq100_buy.empty:
        print("\n[OK] TOP BUY OPPORTUNITIES (EXCELLENT/GOOD/OK quality):")
        display_cols = ['ticker', 'signal', 'current_price', 'buy_quality', 's1']
        if all(col in nasdaq100_buy.columns for col in display_cols):
            print(nasdaq100_buy[display_cols].head(10).to_string(index=False))
        else:
            print(nasdaq100_buy[['ticker', 'signal', 'current_price']].head(10).to_string(index=False))
    
    # Display sell signals (matches portfolio_analysis behavior)
    if not nasdaq100_sell.empty:
        print("\n[SELL] SELL SIGNALS (Bearish - reduce exposure):")
        display_cols = ['ticker', 'signal', 'current_price', 'r1_quality', 'r1']
        if all(col in nasdaq100_sell.columns for col in display_cols):
            print(nasdaq100_sell[display_cols].head(10).to_string(index=False))
        else:
            print(nasdaq100_sell[['ticker', 'signal', 'current_price']].head(10).to_string(index=False))
    
    # Save combined results if we have either buy or sell signals
    if not nasdaq100_buy.empty or not nasdaq100_sell.empty:
        xlsx_path = results_dir / f'nasdaq100_analysis_{timestamp}.xlsx'
        pdf_path = results_dir / f'scanner_report_nasdaq100_{timestamp}.pdf'
        
        # Create reports with both buy and sell data
        create_excel_output(nasdaq100_buy, nasdaq100_sell, xlsx_path, category="NASDAQ 100")
        create_pdf_report(nasdaq100_buy, nasdaq100_sell, pdf_path, timestamp, category="NASDAQ 100")
        
        print(f"\n[OK] Excel: {xlsx_path.name}")
        print(f"[OK] PDF: {pdf_path.name}")
else:
    print("[WARN] No results from NASDAQ 100 scan")
# Out:
# Fetching NASDAQ 100 ticker list...
# [OK] Loaded 101 NASDAQ 100 tickers
#
# Found 101 NASDAQ 100 stocks
#
# [SCAN] Scanning 101 NASDAQ 100 stocks for 'FULL HOLD + ADD' signals...
# Parameters: 60 daily bars, 52 weekly bars, 2 threads
# ================================================================================
# [OK] [4/101] GOOGL  -> FULL HOLD + ADD      $325.44 | Quality: EXTENDED   ⚠
# [OK] [5/101] GOOG   -> FULL HOLD + ADD      $326.01 | Quality: EXTENDED   ⚠
# [OK] [6/101] AMZN   -> FULL HOLD + ADD      $246.29 | Quality: EXTENDED   ⚠
# [OK] [8/101] AMGN   -> FULL HOLD + ADD      $330.11 | Quality: GOOD       ✓
# [OK] [9/101] ADI    -> FULL HOLD + ADD      $299.16 | Quality: EXTENDED   ⚠
# [OK] [10/101] AAPL   -> FULL HOLD + ADD      $259.04 | Quality: EXTENDED   ⚠
# [OK] [11/101] AMAT   -> FULL HOLD + ADD      $281.64 | Quality: EXTENDED   ⚠
# [OK] [12/101] APP    -> FULL HOLD + ADD      $616.53 | Quality: EXTENDED   ⚠
# [OK] [14/101] ASML   -> FULL HOLD + ADD      $1,194.32 | Quality: EXTENDED   ⚠
# [OK] [21/101] BKNG   -> FULL HOLD + ADD      $5,445.00 | Quality: EXTENDED   ⚠
# [OK] [26/101] CSCO   -> FULL HOLD + ADD      $73.96 | Quality: EXTENDED   ⚠
# [OK] [27/101] AZN    -> FULL HOLD + ADD      $94.01 | Quality: EXTENDED   ⚠
# [OK] [28/101] CTSH   -> FULL HOLD + ADD      $85.77 | Quality: GOOD       ✓
# [OK] [35/101] CSX    -> FULL HOLD + ADD      $35.32 | Quality: OK         ✓
# [OK] [40/101] EA     -> FULL HOLD + ADD      $204.22 | Quality: GOOD       ✓
# [OK] [43/101] FER    -> FULL HOLD + ADD      $67.46 | Quality: GOOD       ✓
# [OK] [46/101] GILD   -> FULL HOLD + ADD      $120.67 | Quality: EXTENDED   ⚠
# [OK] [48/101] IDXX   -> FULL HOLD + ADD      $712.39 | Quality: EXTENDED   ⚠
# [OK] [50/101] INTC   -> FULL HOLD + ADD      $41.11 | Quality: EXTENDED   ⚠
# [OK] [52/101] ISRG   -> FULL HOLD + ADD      $585.08 | Quality: GOOD       ✓
# [OK] [54/101] KLAC   -> FULL HOLD + ADD      $1,324.60 | Quality: EXTENDED   ⚠
# [OK] [56/101] LRCX   -> FULL HOLD + ADD      $200.96 | Quality: EXTENDED   ⚠
# [OK] [58/101] MAR    -> FULL HOLD + ADD      $324.91 | Quality: EXTENDED   ⚠
# [OK] [59/101] MRVL   -> FULL HOLD + ADD      $83.45 | Quality: OK         ✓
# [OK] [63/101] MU     -> FULL HOLD + ADD      $327.02 | Quality: EXTENDED   ⚠
# [OK] [67/101] MPWR   -> FULL HOLD + ADD      $959.09 | Quality: EXTENDED   ⚠
# [OK] [68/101] MNST   -> FULL HOLD + ADD      $76.60 | Quality: EXTENDED   ⚠
# [OK] [70/101] NVDA   -> FULL HOLD + ADD      $185.04 | Quality: EXTENDED   ⚠
# [OK] [71/101] NXPI   -> FULL HOLD + ADD      $237.89 | Quality: EXCELLENT  ✓
# [OK] [74/101] PCAR   -> FULL HOLD + ADD      $118.20 | Quality: EXTENDED   ⚠
# [OK] [75/101] PLTR   -> FULL HOLD + ADD      $176.86 | Quality: EXTENDED   ⚠
# [OK] [81/101] QCOM   -> FULL HOLD + ADD      $181.87 | Quality: OK         ✓
# [OK] [84/101] ROST   -> FULL HOLD + ADD      $189.27 | Quality: EXTENDED   ⚠
# [OK] [85/101] STX    -> FULL HOLD + ADD      $284.47 | Quality: EXTENDED   ⚠
# [OK] [90/101] TTWO   -> FULL HOLD + ADD      $252.38 | Quality: OK         ✓
# [OK] [91/101] TSLA   -> FULL HOLD + ADD      $435.80 | Quality: EXTENDED   ⚠
# [OK] [93/101] SHOP   -> FULL HOLD + ADD      $168.28 | Quality: EXTENDED   ⚠
# [OK] [96/101] WBD    -> FULL HOLD + ADD      $28.32 | Quality: EXTENDED   ⚠
# [OK] [97/101] WDC    -> FULL HOLD + ADD      $187.68 | Quality: EXTENDED   ⚠
#   [100/101] Scanning...
# ================================================================================
#
# [OK] Scan complete: 101 analyzed, 39 FULL HOLD + ADD signals found
#
#
# [STATS] NASDAQ 100 Results:
#    [OK] 10 buy signals (EXCELLENT/GOOD/OK)
#    [WAIT] 29 extended/weak (wait)
#    [SELL] 51 sell signals (bearish)
#
# [OK] TOP BUY OPPORTUNITIES (EXCELLENT/GOOD/OK quality):
# ticker          signal  current_price buy_quality         s1
#   AMGN FULL HOLD + ADD         330.11        GOOD 312.390015
#    CSX FULL HOLD + ADD          35.32          OK  33.506150
#   CTSH FULL HOLD + ADD          85.77        GOOD  74.590429
#     EA FULL HOLD + ADD         204.22        GOOD 199.553284
#    FER FULL HOLD + ADD          67.46        GOOD  61.811347
#   ISRG FULL HOLD + ADD         585.08        GOOD 537.690002
#   MRVL FULL HOLD + ADD          83.45          OK  81.180000
#   NXPI FULL HOLD + ADD         237.89   EXCELLENT 224.885048
#   QCOM FULL HOLD + ADD         181.87          OK 159.243690
#   TTWO FULL HOLD + ADD         252.38          OK 240.279999
#
# [SELL] SELL SIGNALS (Bearish - reduce exposure):
# ticker             signal  current_price r1_quality         r1
#   ABNB             REDUCE         138.66    CAUTION 170.100006
#   ADBE               CASH         339.04    CAUTION 422.950012
#    ADP               CASH         265.67    CAUTION 324.495730
#   ADSK HOLD MOST + REDUCE         276.58    CAUTION 329.089996
#   ALNY HOLD MOST + REDUCE         399.40    CAUTION 495.549988
#    ARM               CASH         113.08    CAUTION 146.429993
#   AXON HOLD MOST + REDUCE         612.98    CAUTION 794.289978
#   CDNS HOLD MOST + REDUCE         318.80    CAUTION 376.450012
#   CHTR FULL CASH / DEFEND         209.71         OK 271.500000
#  CMCSA               CASH          28.21    CAUTION  36.559510
# [OK] Excel file created: c:\workspace\portfolio_analyser\scanner_results\nasdaq100_analysis_20260109_1034.xlsx
#   - Buy Opportunities: 10 stocks
#   - Sell Signals: 51 stocks
# [OK] PDF report created: c:\workspace\portfolio_analyser\scanner_results\scanner_report_nasdaq100_20260109_1034.pdf
#
# [OK] Excel: nasdaq100_analysis_20260109_1034.xlsx
# [OK] PDF: scanner_report_nasdaq100_20260109_1034.pdf

# %% [markdown]
# ## Cleanup Old Scan Files
#
# Archive old scan results to keep the scanner_results folder clean. Keeps the 2 most recent files per category (Portfolio, S&P 500, NASDAQ 100).

# %%
print("\n" + "="*80)
print("CLEANUP - Archiving Old Scan Files")
print("="*80)

# Keep 1 most recent file per category (Excel + PDF = 2 files per category max)
# Archives older files, deletes archives older than 60 days
cleanup_old_scans(results_dir, max_files=1, archive_retention_days=60)

print("\n[OK] Cleanup complete")
# Out:
# ================================================================================
# CLEANUP - Archiving Old Scan Files
# ================================================================================
#   ðŸ“¦ Archived (sp500): sp500_analysis_20260109_0949.xlsx
#   ðŸ“¦ Archived (sp500): scanner_report_sp500_20260109_0949.pdf
#   ðŸ“¦ Archived (nasdaq100): nasdaq100_analysis_20260109_0949.xlsx
#   ðŸ“¦ Archived (nasdaq100): scanner_report_nasdaq100_20260109_0949.pdf
#   ðŸ“¦ Archived (portfolio): portfolio_scanner_20260109_0949.xlsx
#   ðŸ“¦ Archived (portfolio): scanner_report_portfolio_20260109_0949.pdf
#   âœ… Archived 6 file(s), kept 1 most recent
#
# [OK] Cleanup complete
