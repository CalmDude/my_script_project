# %%
from pathlib import Path
from datetime import datetime
import pandas as pd
import sys

# Determine root directory - go up from notebooks folder to portfolio_analyser
if Path.cwd().name == 'notebooks':
    ROOT = Path.cwd().parent
else:
    ROOT = Path.cwd()

src_path = ROOT / 'src'

# Add src to path if not already there
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

from full_scanner import (
    get_sp500_tickers,
    get_nasdaq100_tickers,
    get_portfolio_tickers,
    scan_stocks,
    filter_buy_signals,
    filter_sell_signals,
    create_excel_output,
    create_portfolio_excel,
    create_pdf_report
)

# Setup results directory
results_dir = ROOT / 'scanner_results'
results_dir.mkdir(exist_ok=True)

timestamp = datetime.now().strftime("%Y%m%d_%H%M")

print("✓ Scanner modules loaded")
print(f"✓ Results directory: {results_dir}")
print(f"✓ Timestamp: {timestamp}")
# Out:
# ✓ Scanner modules loaded
# ✓ Results directory: c:\workspace\portfolio_analyser\scanner_results
# ✓ Timestamp: 20260108_2003

# %% [markdown]
# ## Configuration
#
# Set your scan parameters:
# - **daily_bars**: Number of daily bars to analyze (default: 60)
# - **weekly_bars**: Number of weekly bars to analyze (default: 52)
# - **concurrency**: Number of parallel workers (default: 2, max recommended: 5)

# %%
# Scan parameters
DAILY_BARS = 60
WEEKLY_BARS = 52
CONCURRENCY = 2  # Be careful with higher values (rate limits)

print(f"Daily bars: {DAILY_BARS}")
print(f"Weekly bars: {WEEKLY_BARS}")
print(f"Concurrency: {CONCURRENCY}")
# Out:
# Daily bars: 60
# Weekly bars: 52
# Concurrency: 2

# %% [markdown]
# ## Scan S&P 500
#
# Full scan of ~500 stocks. Takes 5-10 minutes depending on cache. Shows both buy opportunities (FULL HOLD + ADD) and sell signals (bearish signals).

# %%
print("Loading portfolio tickers from stocks.txt...")
portfolio_tickers = get_portfolio_tickers()

if portfolio_tickers:
    print(f"Found {len(portfolio_tickers)} portfolio stocks\n")

    # Run scan
    portfolio_results = scan_stocks(
        portfolio_tickers,
        category="Portfolio",
        daily_bars=DAILY_BARS,
        weekly_bars=WEEKLY_BARS,
        concurrency=CONCURRENCY
    )

    if not portfolio_results.empty:
        # Get buy signals (all and quality-filtered)
        portfolio_buy_all = filter_buy_signals(portfolio_results, 'FULL HOLD + ADD', quality_filter=False)
        portfolio_buy = filter_buy_signals(portfolio_results, 'FULL HOLD + ADD', quality_filter=True)
        
        # Get sell signals (all bearish signals)
        portfolio_sell = filter_sell_signals(portfolio_results, quality_filter=False)
        
        # Display summary
        print(f"\n📊 Portfolio Results:")
        print(f"   ✅ {len(portfolio_buy)} buy signals (EXCELLENT/GOOD/OK)")
        if len(portfolio_buy_all) > len(portfolio_buy):
            print(f"   ⏸️  {len(portfolio_buy_all) - len(portfolio_buy)} extended/weak (wait)")
        print(f"   🔴 {len(portfolio_sell)} sell signals (bearish)")
        
        # Display buy opportunities
        if not portfolio_buy.empty:
            print("\n✅ BUY OPPORTUNITIES (EXCELLENT/GOOD/OK quality):")
            display_cols = ['ticker', 'signal', 'current_price', 'buy_quality', 's1']
            if all(col in portfolio_buy.columns for col in display_cols):
                print(portfolio_buy[display_cols].to_string(index=False))
            else:
                print(portfolio_buy[['ticker', 'signal', 'current_price']].to_string(index=False))
        
        # Display sell signals
        if not portfolio_sell.empty:
            print("\n🔴 SELL SIGNALS (Bearish - reduce exposure):")
            display_cols = ['ticker', 'signal', 'current_price', 'r1_quality', 'r1']
            if all(col in portfolio_sell.columns for col in display_cols):
                print(portfolio_sell[display_cols].to_string(index=False))
            else:
                print(portfolio_sell[['ticker', 'signal', 'current_price']].to_string(index=False))
        
        # Save combined results
        if not portfolio_buy.empty or not portfolio_sell.empty:
            xlsx_path = results_dir / f'portfolio_scanner_{timestamp}.xlsx'
            pdf_path = results_dir / f'scanner_report_portfolio_{timestamp}.pdf'
            
            # Create reports with both buy and sell data
            create_excel_output(portfolio_buy, portfolio_sell, xlsx_path, category="Portfolio")
            create_pdf_report(portfolio_buy, portfolio_sell, pdf_path, timestamp, category="Portfolio")
            
            print(f"\n✓ Excel: {xlsx_path.name}")
            print(f"✓ PDF: {pdf_path.name}")
else:
    print("⚠️ No portfolio tickers found in stocks.txt")

# %% [markdown]
# ## Scan Portfolio Stocks
#
# Quick scan of your 9 portfolio stocks from stocks.txt. Shows both buy opportunities and sell signals.

# %%
print("Fetching S&P 500 ticker list...")
sp500_tickers = get_sp500_tickers()
print(f"Found {len(sp500_tickers)} S&P 500 stocks\n")

# Run scan
sp500_results = scan_stocks(
    sp500_tickers,
    category="S&P 500",
    daily_bars=DAILY_BARS,
    weekly_bars=WEEKLY_BARS,
    concurrency=CONCURRENCY
)

if not sp500_results.empty:
    # Get buy signals (all and quality-filtered)
    sp500_buy_all = filter_buy_signals(sp500_results, 'FULL HOLD + ADD', quality_filter=False)
    sp500_buy = filter_buy_signals(sp500_results, 'FULL HOLD + ADD', quality_filter=True)
    
    # Get sell signals (all bearish signals, matching portfolio_analysis logic)
    sp500_sell = filter_sell_signals(sp500_results, quality_filter=False)
    
    # Display summary
    print(f"\n📊 S&P 500 Results:")
    print(f"   ✅ {len(sp500_buy)} buy signals (EXCELLENT/GOOD/OK)")
    if len(sp500_buy_all) > len(sp500_buy):
        print(f"   ⏸️  {len(sp500_buy_all) - len(sp500_buy)} extended/weak (wait)")
    print(f"   🔴 {len(sp500_sell)} sell signals (bearish)")
    
    # Display buy opportunities
    if not sp500_buy.empty:
        print("\n✅ TOP BUY OPPORTUNITIES (EXCELLENT/GOOD/OK quality):")
        display_cols = ['ticker', 'signal', 'current_price', 'buy_quality', 's1']
        if all(col in sp500_buy.columns for col in display_cols):
            print(sp500_buy[display_cols].head(10).to_string(index=False))
        else:
            print(sp500_buy[['ticker', 'signal', 'current_price']].head(10).to_string(index=False))
    
    # Display sell signals (matches portfolio_analysis behavior)
    if not sp500_sell.empty:
        print("\n🔴 SELL SIGNALS (Bearish - reduce exposure):")
        display_cols = ['ticker', 'signal', 'current_price', 'r1_quality', 'r1']
        if all(col in sp500_sell.columns for col in display_cols):
            print(sp500_sell[display_cols].head(10).to_string(index=False))
        else:
            print(sp500_sell[['ticker', 'signal', 'current_price']].head(10).to_string(index=False))
    
    # Save combined results if we have either buy or sell signals
    if not sp500_buy.empty or not sp500_sell.empty:
        xlsx_path = results_dir / f'sp500_analysis_{timestamp}.xlsx'
        pdf_path = results_dir / f'scanner_report_sp500_{timestamp}.pdf'
        
        # Create reports with both buy and sell data
        create_excel_output(sp500_buy, sp500_sell, xlsx_path, category="S&P 500")
        create_pdf_report(sp500_buy, sp500_sell, pdf_path, timestamp, category="S&P 500")
        
        print(f"\n✓ Excel: {xlsx_path.name}")
        print(f"✓ PDF: {pdf_path.name}")
else:
    print("⚠️ No results from S&P 500 scan")
# Out:
# Fetching S&P 500 ticker list...
# [OK] Loaded 503 S&P 500 tickers
#
# Found 503 S&P 500 stocks
#
# [SCAN] Scanning 503 S&P 500 stocks for 'FULL HOLD + ADD' signals...
# Parameters: 60 daily bars, 52 weekly bars, 2 threads
# ================================================================================
# [OK] [4/503] ABBV   -> FULL HOLD + ADD      $224.12 | Quality: EXTENDED   ⚠
# [OK] [9/503] AFL    -> FULL HOLD + ADD      $110.16 | Quality: OK         ✓
# [OK] [14/503] ALB    -> FULL HOLD + ADD      $157.90 | Quality: EXTENDED   ⚠
# [OK] [19/503] GOOGL  -> FULL HOLD + ADD      $326.54 | Quality: EXTENDED   ⚠
# [OK] [20/503] ALL    -> FULL HOLD + ADD      $209.35 | Quality: EXTENDED   ⚠
# [OK] [21/503] GOOG   -> FULL HOLD + ADD      $326.96 | Quality: EXTENDED   ⚠
# [OK] [23/503] AMZN   -> FULL HOLD + ADD      $245.58 | Quality: EXTENDED   ⚠
# [OK] [27/503] AXP    -> FULL HOLD + ADD      $383.70 | Quality: EXTENDED   ⚠
# [OK] [28/503] AIG    -> FULL HOLD + ADD      $78.30 | Quality: CAUTION    ⚠
# [OK] [32/503] AME    -> FULL HOLD + ADD      $211.26 | Quality: EXTENDED   ⚠
# [OK] [33/503] AMGN   -> FULL HOLD + ADD      $331.40 | Quality: GOOD       ✓
# [OK] [34/503] APH    -> FULL HOLD + ADD      $134.37 | Quality: EXTENDED   ⚠
# [OK] [35/503] ADI    -> FULL HOLD + ADD      $297.67 | Quality: EXTENDED   ⚠
# [OK] [38/503] AAPL   -> FULL HOLD + ADD      $256.99 | Quality: EXTENDED   ⚠
# [OK] [39/503] APO    -> FULL HOLD + ADD      $147.81 | Quality: GOOD       ✓
# [OK] [40/503] AMAT   -> FULL HOLD + ADD      $282.45 | Quality: EXTENDED   ⚠
# [OK] [41/503] APP    -> FULL HOLD + ADD      $608.29 | Quality: EXTENDED   ⚠
# [OK] [43/503] ACGL   -> FULL HOLD + ADD      $96.10 | Quality: CAUTION    ⚠
# [OK] [45/503] ARES   -> FULL HOLD + ADD      $176.80 | Quality: EXCELLENT  ✓
# [OK] [48/503] AIZ    -> FULL HOLD + ADD      $238.41 | Quality: OK         ✓
#   [50/503] Scanning...
# [OK] [59/503] BAC    -> FULL HOLD + ADD      $56.42 | Quality: EXTENDED   ⚠
# [OK] [62/503] BRK-B  -> FULL HOLD + ADD      $502.04 | Quality: CAUTION    ⚠
# [OK] [69/503] BK     -> FULL HOLD + ADD      $120.47 | Quality: EXTENDED   ⚠
# [OK] [70/503] BA     -> FULL HOLD + ADD      $228.83 | Quality: EXCELLENT  ✓
# [OK] [71/503] BKNG   -> FULL HOLD + ADD      $5,400.40 | Quality: EXTENDED   ⚠
# [OK] [79/503] BG     -> FULL HOLD + ADD      $98.14 | Quality: EXCELLENT  ✓
# [OK] [81/503] CHRW   -> FULL HOLD + ADD      $166.96 | Quality: EXTENDED   ⚠
# [OK] [85/503] COF    -> FULL HOLD + ADD      $257.15 | Quality: EXTENDED   ⚠
# [OK] [86/503] CCL    -> FULL HOLD + ADD      $32.07 | Quality: EXTENDED   ⚠
# [OK] [87/503] CAH    -> FULL HOLD + ADD      $203.76 | Quality: EXTENDED   ⚠
# [OK] [89/503] CVNA   -> FULL HOLD + ADD      $449.28 | Quality: EXTENDED   ⚠
# [OK] [90/503] CAT    -> FULL HOLD + ADD      $605.77 | Quality: EXTENDED   ⚠
# [OK] [91/503] CBOE   -> FULL HOLD + ADD      $260.87 | Quality: OK         ✓
# [OK] [92/503] CBRE   -> FULL HOLD + ADD      $168.56 | Quality: EXTENDED   ⚠
# [OK] [94/503] COR    -> FULL HOLD + ADD      $337.57 | Quality: GOOD       ✓
# [OK] [99/503] SCHW   -> FULL HOLD + ADD      $101.82 | Quality: EXTENDED   ⚠
#   [100/503] Scanning...
# [OK] [101/503] CVX    -> FULL HOLD + ADD      $158.62 | Quality: CAUTION    ⚠
# [OK] [103/503] CB     -> FULL HOLD + ADD      $312.36 | Quality: GOOD       ✓
# [OK] [106/503] CINF   -> FULL HOLD + ADD      $165.49 | Quality: EXTENDED   ⚠
# [OK] [108/503] CSCO   -> FULL HOLD + ADD      $73.64 | Quality: EXTENDED   ⚠
# [OK] [109/503] C      -> FULL HOLD + ADD      $121.23 | Quality: EXTENDED   ⚠
# [OK] [110/503] CFG    -> FULL HOLD + ADD      $62.05 | Quality: EXTENDED   ⚠
# [OK] [112/503] CME    -> FULL HOLD + ADD      $266.84 | Quality: CAUTION    ⚠
# [OK] [115/503] CTSH   -> FULL HOLD + ADD      $85.64 | Quality: GOOD       ✓
# [OK] [119/503] FIX    -> FULL HOLD + ADD      $974.90 | Quality: EXTENDED   ⚠
# [OK] [127/503] GLW    -> FULL HOLD + ADD      $84.43 | Quality: EXTENDED   ⚠
# [OK] [129/503] CTVA   -> FULL HOLD + ADD      $70.09 | Quality: GOOD       ✓
# [OK] [132/503] CTRA   -> FULL HOLD + ADD      $25.34 | Quality: GOOD       ✓
# [OK] [133/503] CRH    -> FULL HOLD + ADD      $124.33 | Quality: OK         ✓
# [OK] [136/503] CSX    -> FULL HOLD + ADD      $35.31 | Quality: OK         ✓
# [OK] [137/503] CMI    -> FULL HOLD + ADD      $546.03 | Quality: EXTENDED   ⚠
# [OK] [138/503] CVS    -> FULL HOLD + ADD      $80.94 | Quality: OK         ✓
# [OK] [143/503] DAY    -> FULL HOLD + ADD      $69.45 | Quality: OK         ✓
# [OK] [147/503] DAL    -> FULL HOLD + ADD      $71.44 | Quality: EXTENDED   ⚠
#   [150/503] Scanning...
# [OK] [152/503] DG     -> FULL HOLD + ADD      $144.56 | Quality: EXTENDED   ⚠
# [OK] [153/503] DLTR   -> FULL HOLD + ADD      $131.94 | Quality: EXTENDED   ⚠
# [OK] [157/503] DOV    -> FULL HOLD + ADD      $202.38 | Quality: GOOD       ✓
# [OK] [162/503] DD     -> FULL HOLD + ADD      $43.89 | Quality: EXTENDED   ⚠
# [OK] [167/503] EW     -> FULL HOLD + ADD      $85.09 | Quality: GOOD       ✓
# [OK] [168/503] EA     -> FULL HOLD + ADD      $204.38 | Quality: GOOD       ✓
# [OK] [171/503] EMR    -> FULL HOLD + ADD      $143.29 | Quality: EXTENDED   ⚠
# [OK] [187/503] EXPE   -> FULL HOLD + ADD      $299.49 | Quality: EXTENDED   ⚠
# [OK] [189/503] EXPD   -> FULL HOLD + ADD      $157.35 | Quality: EXTENDED   ⚠
# [OK] [191/503] XOM    -> FULL HOLD + ADD      $122.46 | Quality: GOOD       ✓
# [OK] [195/503] FRT    -> FULL HOLD + ADD      $102.87 | Quality: OK         ✓
# [OK] [196/503] FDX    -> FULL HOLD + ADD      $311.69 | Quality: EXTENDED   ⚠
# [OK] [198/503] FITB   -> FULL HOLD + ADD      $50.23 | Quality: EXTENDED   ⚠
# [OK] [199/503] FSLR   -> FULL HOLD + ADD      $245.02 | Quality: EXTENDED   ⚠
#   [200/503] Scanning...
# [OK] [202/503] F      -> FULL HOLD + ADD      $14.43 | Quality: EXTENDED   ⚠
# [OK] [205/503] FOXA   -> FULL HOLD + ADD      $75.84 | Quality: EXTENDED   ⚠
# [OK] [206/503] FOX    -> FULL HOLD + ADD      $67.95 | Quality: EXTENDED   ⚠
# [OK] [207/503] BEN    -> FULL HOLD + ADD      $25.55 | Quality: EXTENDED   ⚠
# [OK] [208/503] FCX    -> FULL HOLD + ADD      $53.56 | Quality: EXTENDED   ⚠
# [OK] [212/503] GE     -> FULL HOLD + ADD      $314.56 | Quality: EXTENDED   ⚠
# [OK] [213/503] GEV    -> FULL HOLD + ADD      $621.94 | Quality: EXTENDED   ⚠
# [OK] [216/503] GD     -> FULL HOLD + ADD      $354.63 | Quality: EXTENDED   ⚠
# [OK] [218/503] GM     -> FULL HOLD + ADD      $84.81 | Quality: EXTENDED   ⚠
# [OK] [220/503] GILD   -> FULL HOLD + ADD      $120.91 | Quality: EXTENDED   ⚠
# [OK] [222/503] GL     -> FULL HOLD + ADD      $142.63 | Quality: OK         ✓
# [OK] [224/503] GS     -> FULL HOLD + ADD      $939.76 | Quality: EXTENDED   ⚠
# [OK] [226/503] HIG    -> FULL HOLD + ADD      $137.75 | Quality: EXTENDED   ⚠
# [OK] [227/503] HAS    -> FULL HOLD + ADD      $88.64 | Quality: EXTENDED   ⚠
# [OK] [228/503] HCA    -> FULL HOLD + ADD      $476.27 | Quality: EXTENDED   ⚠
# [OK] [230/503] HSIC   -> FULL HOLD + ADD      $79.86 | Quality: GOOD       ✓
# [OK] [231/503] HSY    -> FULL HOLD + ADD      $183.99 | Quality: OK         ✓
# [OK] [232/503] HPE    -> FULL HOLD + ADD      $22.09 | Quality: OK         ✓
# [OK] [233/503] HLT    -> FULL HOLD + ADD      $298.00 | Quality: EXTENDED   ⚠
# [OK] [238/503] HST    -> FULL HOLD + ADD      $18.24 | Quality: GOOD       ✓
# [OK] [239/503] HWM    -> FULL HOLD + ADD      $206.54 | Quality: EXTENDED   ⚠
# [OK] [241/503] HUBB   -> FULL HOLD + ADD      $457.50 | Quality: OK         ✓
# [OK] [243/503] HBAN   -> FULL HOLD + ADD      $18.56 | Quality: EXTENDED   ⚠
# [OK] [244/503] HII    -> FULL HOLD + ADD      $379.42 | Quality: EXTENDED   ⚠
# [OK] [245/503] IBM    -> FULL HOLD + ADD      $302.17 | Quality: EXTENDED   ⚠
# [OK] [247/503] IDXX   -> FULL HOLD + ADD      $708.96 | Quality: EXTENDED   ⚠
# [OK] [249/503] INCY   -> FULL HOLD + ADD      $106.51 | Quality: EXTENDED   ⚠
#   [250/503] Scanning...
# [OK] [252/503] INTC   -> FULL HOLD + ADD      $41.24 | Quality: EXTENDED   ⚠
# [OK] [253/503] IBKR   -> FULL HOLD + ADD      $69.68 | Quality: EXTENDED   ⚠
# [OK] [258/503] ISRG   -> FULL HOLD + ADD      $586.25 | Quality: GOOD       ✓
# [OK] [259/503] IVZ    -> FULL HOLD + ADD      $28.30 | Quality: EXTENDED   ⚠
# [OK] [261/503] IQV    -> FULL HOLD + ADD      $243.46 | Quality: EXCELLENT  ✓
# [OK] [263/503] JBHT   -> FULL HOLD + ADD      $206.36 | Quality: EXTENDED   ⚠
# [OK] [264/503] JBL    -> FULL HOLD + ADD      $218.66 | Quality: EXTENDED   ⚠
# [OK] [265/503] JKHY   -> FULL HOLD + ADD      $188.03 | Quality: OK         ✓
# [OK] [266/503] JNJ    -> FULL HOLD + ADD      $205.88 | Quality: EXTENDED   ⚠
# [OK] [268/503] JCI    -> FULL HOLD + ADD      $111.93 | Quality: EXTENDED   ⚠
# [OK] [269/503] JPM    -> FULL HOLD + ADD      $330.82 | Quality: EXTENDED   ⚠
# [OK] [272/503] KEY    -> FULL HOLD + ADD      $21.69 | Quality: EXTENDED   ⚠
# [OK] [273/503] KEYS   -> FULL HOLD + ADD      $206.26 | Quality: EXTENDED   ⚠
# [OK] [276/503] KMI    -> FULL HOLD + ADD      $27.38 | Quality: CAUTION    ⚠
# [OK] [277/503] KKR    -> FULL HOLD + ADD      $133.45 | Quality: GOOD       ✓
# [OK] [278/503] KLAC   -> FULL HOLD + ADD      $1,325.69 | Quality: EXTENDED   ⚠
# [OK] [281/503] LHX    -> FULL HOLD + ADD      $327.90 | Quality: EXTENDED   ⚠
# [OK] [282/503] LRCX   -> FULL HOLD + ADD      $201.26 | Quality: EXTENDED   ⚠
# [OK] [285/503] LDOS   -> FULL HOLD + ADD      $194.19 | Quality: OK         ✓
# [OK] [286/503] LVS    -> FULL HOLD + ADD      $62.09 | Quality: EXTENDED   ⚠
# [OK] [289/503] LLY    -> FULL HOLD + ADD      $1,090.49 | Quality: EXTENDED   ⚠
# [OK] [292/503] LMT    -> FULL HOLD + ADD      $519.98 | Quality: EXTENDED   ⚠
# [OK] [293/503] L      -> FULL HOLD + ADD      $105.73 | Quality: EXTENDED   ⚠
# [OK] [294/503] LOW    -> FULL HOLD + ADD      $256.31 | Quality: GOOD       ✓
# [OK] [297/503] MTB    -> FULL HOLD + ADD      $214.49 | Quality: EXTENDED   ⚠
# [OK] [299/503] MAR    -> FULL HOLD + ADD      $324.30 | Quality: EXTENDED   ⚠
#   [300/503] Scanning...
# [OK] [302/503] MLM    -> FULL HOLD + ADD      $635.20 | Quality: OK         ✓
# [OK] [303/503] MA     -> FULL HOLD + ADD      $583.70 | Quality: CAUTION    ⚠
# [OK] [306/503] MCD    -> FULL HOLD + ADD      $308.51 | Quality: CAUTION    ⚠
# [OK] [307/503] MCK    -> FULL HOLD + ADD      $813.20 | Quality: EXTENDED   ⚠
# [OK] [308/503] MDT    -> FULL HOLD + ADD      $99.95 | Quality: EXTENDED   ⚠
# [OK] [311/503] MET    -> FULL HOLD + ADD      $79.80 | Quality: CAUTION    ⚠
# [OK] [312/503] MTD    -> FULL HOLD + ADD      $1,468.72 | Quality: GOOD       ✓
# [OK] [315/503] MU     -> FULL HOLD + ADD      $327.62 | Quality: EXTENDED   ⚠
# [OK] [322/503] MPWR   -> FULL HOLD + ADD      $958.64 | Quality: EXTENDED   ⚠
# [OK] [323/503] MNST   -> FULL HOLD + ADD      $76.38 | Quality: EXTENDED   ⚠
# [OK] [324/503] MCO    -> FULL HOLD + ADD      $531.65 | Quality: CAUTION    ⚠
# [OK] [325/503] MS     -> FULL HOLD + ADD      $185.52 | Quality: EXTENDED   ⚠
# [OK] [328/503] MSCI   -> FULL HOLD + ADD      $581.74 | Quality: GOOD       ✓
# [OK] [329/503] NDAQ   -> FULL HOLD + ADD      $100.42 | Quality: EXTENDED   ⚠
# [OK] [332/503] NEM    -> FULL HOLD + ADD      $106.07 | Quality: EXTENDED   ⚠
# [OK] [338/503] NDSN   -> FULL HOLD + ADD      $254.69 | Quality: GOOD       ✓
# [OK] [339/503] NSC    -> FULL HOLD + ADD      $289.86 | Quality: EXTENDED   ⚠
# [OK] [340/503] NTRS   -> FULL HOLD + ADD      $144.93 | Quality: EXTENDED   ⚠
# [OK] [341/503] NOC    -> FULL HOLD + ADD      $597.65 | Quality: EXTENDED   ⚠
# [OK] [344/503] NUE    -> FULL HOLD + ADD      $169.24 | Quality: EXCELLENT  ✓
# [OK] [345/503] NVDA   -> FULL HOLD + ADD      $184.73 | Quality: EXTENDED   ⚠
# [OK] [347/503] NXPI   -> FULL HOLD + ADD      $238.85 | Quality: EXCELLENT  ✓
#   [350/503] Scanning...
# [OK] [356/503] PCAR   -> FULL HOLD + ADD      $118.64 | Quality: EXTENDED   ⚠
# [OK] [357/503] PKG    -> FULL HOLD + ADD      $213.53 | Quality: OK         ✓
# [OK] [358/503] PLTR   -> FULL HOLD + ADD      $177.15 | Quality: EXTENDED   ⚠
# [OK] [361/503] PH     -> FULL HOLD + ADD      $902.21 | Quality: EXTENDED   ⚠
# [OK] [370/503] PSX    -> FULL HOLD + ADD      $142.31 | Quality: OK         ✓
# [OK] [372/503] PNC    -> FULL HOLD + ADD      $219.94 | Quality: EXTENDED   ⚠
# [OK] [376/503] PFG    -> FULL HOLD + ADD      $92.02 | Quality: EXTENDED   ⚠
# [OK] [379/503] PLD    -> FULL HOLD + ADD      $128.80 | Quality: GOOD       ✓
# [OK] [380/503] PRU    -> FULL HOLD + ADD      $119.52 | Quality: EXCELLENT  ✓
# [OK] [386/503] QCOM   -> FULL HOLD + ADD      $184.05 | Quality: OK         ✓
# [OK] [388/503] RL     -> FULL HOLD + ADD      $367.23 | Quality: EXTENDED   ⚠
# [OK] [389/503] RJF    -> FULL HOLD + ADD      $167.47 | Quality: EXTENDED   ⚠
# [OK] [390/503] RTX    -> FULL HOLD + ADD      $186.94 | Quality: EXTENDED   ⚠
# [OK] [394/503] RF     -> FULL HOLD + ADD      $29.17 | Quality: EXTENDED   ⚠
# [OK] [399/503] ROK    -> FULL HOLD + ADD      $404.73 | Quality: EXTENDED   ⚠
# [OK] [400/503] ROL    -> FULL HOLD + ADD      $59.89 | Quality: EXTENDED   ⚠
# [OK] [402/503] ROST   -> FULL HOLD + ADD      $190.21 | Quality: EXTENDED   ⚠
# [OK] [404/503] SPGI   -> FULL HOLD + ADD      $543.13 | Quality: EXCELLENT  ✓
# [OK] [406/503] SNDK   -> FULL HOLD + ADD      $328.55 | Quality: EXTENDED   ⚠
# [OK] [409/503] STX    -> FULL HOLD + ADD      $279.95 | Quality: EXTENDED   ⚠
# [OK] [413/503] SPG    -> FULL HOLD + ADD      $186.40 | Quality: OK         ✓
# [OK] [417/503] SNA    -> FULL HOLD + ADD      $360.32 | Quality: EXTENDED   ⚠
# [OK] [418/503] SOLV   -> FULL HOLD + ADD      $86.06 | Quality: EXTENDED   ⚠
# [OK] [420/503] LUV    -> FULL HOLD + ADD      $42.98 | Quality: EXTENDED   ⚠
# [OK] [423/503] STT    -> FULL HOLD + ADD      $133.00 | Quality: EXTENDED   ⚠
# [OK] [424/503] STLD   -> FULL HOLD + ADD      $172.77 | Quality: EXTENDED   ⚠
# [OK] [425/503] STE    -> FULL HOLD + ADD      $260.84 | Quality: OK         ✓
# [OK] [428/503] SYF    -> FULL HOLD + ADD      $88.33 | Quality: EXTENDED   ⚠
# [OK] [432/503] TROW   -> FULL HOLD + ADD      $108.50 | Quality: EXCELLENT  ✓
# [OK] [433/503] TTWO   -> FULL HOLD + ADD      $252.51 | Quality: OK         ✓
# [OK] [434/503] TPR    -> FULL HOLD + ADD      $133.67 | Quality: EXTENDED   ⚠
# [OK] [435/503] TRGP   -> FULL HOLD + ADD      $177.37 | Quality: GOOD       ✓
# [OK] [437/503] TEL    -> FULL HOLD + ADD      $224.93 | Quality: EXTENDED   ⚠
# [OK] [439/503] TER    -> FULL HOLD + ADD      $216.28 | Quality: EXTENDED   ⚠
# [OK] [440/503] TSLA   -> FULL HOLD + ADD      $434.98 | Quality: EXTENDED   ⚠
# [OK] [443/503] TXT    -> FULL HOLD + ADD      $91.95 | Quality: EXCELLENT  ✓
# [OK] [444/503] TMO    -> FULL HOLD + ADD      $613.46 | Quality: GOOD       ✓
# [OK] [445/503] TJX    -> FULL HOLD + ADD      $157.87 | Quality: EXTENDED   ⚠
# [OK] [446/503] TKO    -> FULL HOLD + ADD      $199.87 | Quality: EXTENDED   ⚠
# [OK] [450/503] TDG    -> FULL HOLD + ADD      $1,366.18 | Quality: CAUTION    ⚠
# [OK] [451/503] TRV    -> FULL HOLD + ADD      $284.86 | Quality: EXTENDED   ⚠
# [OK] [452/503] TRMB   -> FULL HOLD + ADD      $79.58 | Quality: EXTENDED   ⚠
# [OK] [453/503] TFC    -> FULL HOLD + ADD      $51.37 | Quality: EXTENDED   ⚠
# [OK] [456/503] USB    -> FULL HOLD + ADD      $55.80 | Quality: EXTENDED   ⚠
# [OK] [459/503] ULTA   -> FULL HOLD + ADD      $657.45 | Quality: EXTENDED   ⚠
# [OK] [460/503] UNP    -> FULL HOLD + ADD      $229.75 | Quality: EXCELLENT  ✓
# [OK] [461/503] UAL    -> FULL HOLD + ADD      $116.59 | Quality: EXTENDED   ⚠
# [OK] [465/503] UHS    -> FULL HOLD + ADD      $211.06 | Quality: OK         ✓
# [OK] [466/503] VLO    -> FULL HOLD + ADD      $188.62 | Quality: EXTENDED   ⚠
# [OK] [467/503] VTR    -> FULL HOLD + ADD      $74.88 | Quality: EXTENDED   ⚠
# [OK] [473/503] VTRS   -> FULL HOLD + ADD      $12.69 | Quality: EXTENDED   ⚠
# [OK] [475/503] V      -> FULL HOLD + ADD      $352.54 | Quality: CAUTION    ⚠
# [OK] [477/503] VMC    -> FULL HOLD + ADD      $298.58 | Quality: OK         ✓
# [OK] [480/503] WAB    -> FULL HOLD + ADD      $222.04 | Quality: CAUTION    ⚠
# [OK] [481/503] WMT    -> FULL HOLD + ADD      $113.22 | Quality: EXTENDED   ⚠
# [OK] [482/503] DIS    -> FULL HOLD + ADD      $114.80 | Quality: OK         ✓
# [OK] [483/503] WBD    -> FULL HOLD + ADD      $28.43 | Quality: EXTENDED   ⚠
# [OK] [485/503] WAT    -> FULL HOLD + ADD      $397.79 | Quality: EXTENDED   ⚠
# [OK] [487/503] WFC    -> FULL HOLD + ADD      $95.71 | Quality: EXTENDED   ⚠
# [OK] [488/503] WELL   -> FULL HOLD + ADD      $184.60 | Quality: EXTENDED   ⚠
# [OK] [490/503] WDC    -> FULL HOLD + ADD      $183.19 | Quality: EXTENDED   ⚠
# [OK] [493/503] WMB    -> FULL HOLD + ADD      $61.31 | Quality: CAUTION    ⚠
# [OK] [494/503] WTW    -> FULL HOLD + ADD      $335.79 | Quality: OK         ✓
# [OK] [499/503] YUM    -> FULL HOLD + ADD      $152.32 | Quality: CAUTION    ⚠
#   [500/503] Scanning...
# ================================================================================
#
# [OK] Scan complete: 502 analyzed, 207 FULL HOLD + ADD signals found
#
#
# 📊 S&P 500 Results:
#    ✅ 58 buy signals (EXCELLENT/GOOD/OK)
#    ⏸️  149 extended/weak (wait)
#    🔴 244 sell signals (bearish)
#
# ✅ TOP BUY OPPORTUNITIES (EXCELLENT/GOOD/OK quality):
# ticker          signal  current_price buy_quality         s1
#    AFL FULL HOLD + ADD       110.1600          OK 107.010002
#    AIZ FULL HOLD + ADD       238.4150          OK 219.529999
#   AMGN FULL HOLD + ADD       331.4000        GOOD 312.390015
#    APO FULL HOLD + ADD       147.8101        GOOD 136.732408
#   ARES FULL HOLD + ADD       176.8016   EXCELLENT 171.505122
#     BA FULL HOLD + ADD       228.8300   EXCELLENT 215.899994
#     BG FULL HOLD + ADD        98.1450   EXCELLENT  96.611922
#     CB FULL HOLD + ADD       312.3600        GOOD 291.029999
#   CBOE FULL HOLD + ADD       260.8650          OK 244.740005
#    COR FULL HOLD + ADD       337.5700        GOOD 333.390015
#
# 🔴 SELL SIGNALS (Bearish - reduce exposure):
# ticker             signal  current_price r1_quality         r1
#   ABNB             REDUCE        137.345    CAUTION 170.100006
#    ABT HOLD MOST + REDUCE        126.620    CAUTION 139.331034
#    ACN             REDUCE        285.310    CAUTION 366.763666
#   ADBE               CASH        341.690    CAUTION 422.950012
#    ADP               CASH        266.010    CAUTION 324.495730
#   ADSK HOLD MOST + REDUCE        276.350    CAUTION 329.089996
#    AEE HOLD MOST + REDUCE        100.245    CAUTION 105.967030
#    AJG FULL CASH / DEFEND        265.125    CAUTION 343.276861
#   AKAM             REDUCE         86.165    CAUTION 109.239998
#   ALGN             REDUCE        170.970    CAUTION 208.309998
# [OK] Excel file created: c:\workspace\portfolio_analyser\scanner_results\sp500_analysis_20260108_2003.xlsx
#   - Buy Opportunities: 58 stocks
#   - Sell Signals: 244 stocks
# [OK] PDF report created: c:\workspace\portfolio_analyser\scanner_results\scanner_report_sp500_20260108_2003.pdf
#
# ✓ Excel: sp500_analysis_20260108_2003.xlsx
# ✓ PDF: scanner_report_sp500_20260108_2003.pdf

# %% [markdown]
# ## Scan NASDAQ 100
#
# Scan ~100 tech-heavy stocks. Takes 2-5 minutes. Shows both buy opportunities (FULL HOLD + ADD) and sell signals (bearish signals).

# %%
print("Fetching NASDAQ 100 ticker list...")
nasdaq100_tickers = get_nasdaq100_tickers()
print(f"Found {len(nasdaq100_tickers)} NASDAQ 100 stocks\n")

# Run scan
nasdaq100_results = scan_stocks(
    nasdaq100_tickers,
    category="NASDAQ 100",
    daily_bars=DAILY_BARS,
    weekly_bars=WEEKLY_BARS,
    concurrency=CONCURRENCY
)

if not nasdaq100_results.empty:
    # Get buy signals (all and quality-filtered)
    nasdaq100_buy_all = filter_buy_signals(nasdaq100_results, 'FULL HOLD + ADD', quality_filter=False)
    nasdaq100_buy = filter_buy_signals(nasdaq100_results, 'FULL HOLD + ADD', quality_filter=True)
    
    # Get sell signals (all bearish signals, matching portfolio_analysis logic)
    nasdaq100_sell = filter_sell_signals(nasdaq100_results, quality_filter=False)
    
    # Display summary
    print(f"\n📊 NASDAQ 100 Results:")
    print(f"   ✅ {len(nasdaq100_buy)} buy signals (EXCELLENT/GOOD/OK)")
    if len(nasdaq100_buy_all) > len(nasdaq100_buy):
        print(f"   ⏸️  {len(nasdaq100_buy_all) - len(nasdaq100_buy)} extended/weak (wait)")
    print(f"   🔴 {len(nasdaq100_sell)} sell signals (bearish)")
    
    # Display buy opportunities
    if not nasdaq100_buy.empty:
        print("\n✅ TOP BUY OPPORTUNITIES (EXCELLENT/GOOD/OK quality):")
        display_cols = ['ticker', 'signal', 'current_price', 'buy_quality', 's1']
        if all(col in nasdaq100_buy.columns for col in display_cols):
            print(nasdaq100_buy[display_cols].head(10).to_string(index=False))
        else:
            print(nasdaq100_buy[['ticker', 'signal', 'current_price']].head(10).to_string(index=False))
    
    # Display sell signals (matches portfolio_analysis behavior)
    if not nasdaq100_sell.empty:
        print("\n🔴 SELL SIGNALS (Bearish - reduce exposure):")
        display_cols = ['ticker', 'signal', 'current_price', 'r1_quality', 'r1']
        if all(col in nasdaq100_sell.columns for col in display_cols):
            print(nasdaq100_sell[display_cols].head(10).to_string(index=False))
        else:
            print(nasdaq100_sell[['ticker', 'signal', 'current_price']].head(10).to_string(index=False))
    
    # Save combined results if we have either buy or sell signals
    if not nasdaq100_buy.empty or not nasdaq100_sell.empty:
        xlsx_path = results_dir / f'nasdaq100_analysis_{timestamp}.xlsx'
        pdf_path = results_dir / f'scanner_report_nasdaq100_{timestamp}.pdf'
        
        # Create reports with both buy and sell data
        create_excel_output(nasdaq100_buy, nasdaq100_sell, xlsx_path, category="NASDAQ 100")
        create_pdf_report(nasdaq100_buy, nasdaq100_sell, pdf_path, timestamp, category="NASDAQ 100")
        
        print(f"\n✓ Excel: {xlsx_path.name}")
        print(f"✓ PDF: {pdf_path.name}")
else:
    print("⚠️ No results from NASDAQ 100 scan")
# Out:
# Fetching NASDAQ 100 ticker list...
# [OK] Loaded 101 NASDAQ 100 tickers
#
# Found 101 NASDAQ 100 stocks
#
# [SCAN] Scanning 101 NASDAQ 100 stocks for 'FULL HOLD + ADD' signals...
# Parameters: 60 daily bars, 52 weekly bars, 2 threads
# ================================================================================
# [OK] [5/101] GOOGL  -> FULL HOLD + ADD      $326.54 | Quality: EXTENDED   ⚠
# [OK] [6/101] GOOG   -> FULL HOLD + ADD      $326.96 | Quality: EXTENDED   ⚠
# [OK] [7/101] AMZN   -> FULL HOLD + ADD      $245.58 | Quality: EXTENDED   ⚠
# [OK] [9/101] AMGN   -> FULL HOLD + ADD      $331.40 | Quality: GOOD       ✓
# [OK] [10/101] ADI    -> FULL HOLD + ADD      $297.67 | Quality: EXTENDED   ⚠
# [OK] [11/101] AAPL   -> FULL HOLD + ADD      $256.99 | Quality: EXTENDED   ⚠
# [OK] [12/101] AMAT   -> FULL HOLD + ADD      $282.45 | Quality: EXTENDED   ⚠
# [OK] [13/101] APP    -> FULL HOLD + ADD      $608.29 | Quality: EXTENDED   ⚠
# [OK] [15/101] ASML   -> FULL HOLD + ADD      $1,189.92 | Quality: EXTENDED   ⚠
# [OK] [16/101] AZN    -> FULL HOLD + ADD      $94.57 | Quality: EXTENDED   ⚠
# [OK] [22/101] BKNG   -> FULL HOLD + ADD      $5,400.40 | Quality: EXTENDED   ⚠
# [OK] [27/101] CSCO   -> FULL HOLD + ADD      $73.64 | Quality: EXTENDED   ⚠
# [OK] [29/101] CTSH   -> FULL HOLD + ADD      $85.64 | Quality: GOOD       ✓
# [OK] [36/101] CSX    -> FULL HOLD + ADD      $35.31 | Quality: OK         ✓
# [OK] [41/101] EA     -> FULL HOLD + ADD      $204.38 | Quality: GOOD       ✓
# [OK] [44/101] FER    -> FULL HOLD + ADD      $67.42 | Quality: GOOD       ✓
# [OK] [47/101] GILD   -> FULL HOLD + ADD      $120.91 | Quality: EXTENDED   ⚠
# [OK] [49/101] IDXX   -> FULL HOLD + ADD      $708.96 | Quality: EXTENDED   ⚠
#   [50/101] Scanning...
# [OK] [51/101] INTC   -> FULL HOLD + ADD      $41.24 | Quality: EXTENDED   ⚠
# [OK] [53/101] ISRG   -> FULL HOLD + ADD      $586.25 | Quality: GOOD       ✓
# [OK] [56/101] KLAC   -> FULL HOLD + ADD      $1,325.69 | Quality: EXTENDED   ⚠
# [OK] [58/101] LRCX   -> FULL HOLD + ADD      $201.26 | Quality: EXTENDED   ⚠
# [OK] [59/101] MAR    -> FULL HOLD + ADD      $324.30 | Quality: EXTENDED   ⚠
# [OK] [60/101] MRVL   -> FULL HOLD + ADD      $83.40 | Quality: OK         ✓
# [OK] [64/101] MU     -> FULL HOLD + ADD      $327.62 | Quality: EXTENDED   ⚠
# [OK] [68/101] MPWR   -> FULL HOLD + ADD      $958.64 | Quality: EXTENDED   ⚠
# [OK] [69/101] MNST   -> FULL HOLD + ADD      $76.38 | Quality: EXTENDED   ⚠
# [OK] [71/101] NVDA   -> FULL HOLD + ADD      $184.73 | Quality: EXTENDED   ⚠
# [OK] [72/101] NXPI   -> FULL HOLD + ADD      $238.85 | Quality: EXCELLENT  ✓
# [OK] [75/101] PCAR   -> FULL HOLD + ADD      $118.64 | Quality: EXTENDED   ⚠
# [OK] [76/101] PLTR   -> FULL HOLD + ADD      $177.15 | Quality: EXTENDED   ⚠
# [OK] [82/101] QCOM   -> FULL HOLD + ADD      $184.05 | Quality: OK         ✓
# [OK] [85/101] ROST   -> FULL HOLD + ADD      $190.21 | Quality: EXTENDED   ⚠
# [OK] [86/101] STX    -> FULL HOLD + ADD      $279.95 | Quality: EXTENDED   ⚠
# [OK] [87/101] SHOP   -> FULL HOLD + ADD      $165.42 | Quality: EXTENDED   ⚠
# [OK] [91/101] TSLA   -> FULL HOLD + ADD      $434.98 | Quality: EXTENDED   ⚠
# [OK] [92/101] TTWO   -> FULL HOLD + ADD      $252.51 | Quality: OK         ✓
# [OK] [97/101] WBD    -> FULL HOLD + ADD      $28.43 | Quality: EXTENDED   ⚠
# [OK] [98/101] WDC    -> FULL HOLD + ADD      $183.19 | Quality: EXTENDED   ⚠
#   [100/101] Scanning...
# ================================================================================
#
# [OK] Scan complete: 101 analyzed, 39 FULL HOLD + ADD signals found
#
#
# 📊 NASDAQ 100 Results:
#    ✅ 10 buy signals (EXCELLENT/GOOD/OK)
#    ⏸️  29 extended/weak (wait)
#    🔴 51 sell signals (bearish)
#
# ✅ TOP BUY OPPORTUNITIES (EXCELLENT/GOOD/OK quality):
# ticker          signal  current_price buy_quality         s1
#   AMGN FULL HOLD + ADD        331.400        GOOD 312.390015
#    CSX FULL HOLD + ADD         35.315          OK  33.506150
#   CTSH FULL HOLD + ADD         85.645        GOOD  74.590429
#     EA FULL HOLD + ADD        204.385        GOOD 199.553284
#    FER FULL HOLD + ADD         67.420        GOOD  61.811347
#   ISRG FULL HOLD + ADD        586.250        GOOD 537.690002
#   MRVL FULL HOLD + ADD         83.400          OK  81.180000
#   NXPI FULL HOLD + ADD        238.850   EXCELLENT 224.885063
#   QCOM FULL HOLD + ADD        184.049          OK 159.243690
#   TTWO FULL HOLD + ADD        252.510          OK 240.279999
#
# 🔴 SELL SIGNALS (Bearish - reduce exposure):
# ticker             signal  current_price r1_quality         r1
#   ABNB             REDUCE       137.3450    CAUTION 170.100006
#   ADBE               CASH       341.6900    CAUTION 422.950012
#    ADP               CASH       266.0100    CAUTION 324.495730
#   ADSK HOLD MOST + REDUCE       276.3500    CAUTION 329.089996
#   ALNY HOLD MOST + REDUCE       402.1500    CAUTION 495.549988
#    ARM               CASH       112.3300    CAUTION 145.000000
#   AXON HOLD MOST + REDUCE       614.3700    CAUTION 794.289978
#   CDNS HOLD MOST + REDUCE       318.4750    CAUTION 376.450012
#   CHTR FULL CASH / DEFEND       210.1150         OK 271.500000
#  CMCSA               CASH        28.1899    CAUTION  36.559514
# [OK] Excel file created: c:\workspace\portfolio_analyser\scanner_results\nasdaq100_analysis_20260108_2003.xlsx
#   - Buy Opportunities: 10 stocks
#   - Sell Signals: 51 stocks
# [OK] PDF report created: c:\workspace\portfolio_analyser\scanner_results\scanner_report_nasdaq100_20260108_2003.pdf
#
# ✓ Excel: nasdaq100_analysis_20260108_2003.xlsx
# ✓ PDF: scanner_report_nasdaq100_20260108_2003.pdf
