# %%
from pathlib import Path
from datetime import datetime
import pandas as pd
import sys

# Determine root directory - go up from notebooks folder to portfolio_analyser
if Path.cwd().name == 'notebooks':
    ROOT = Path.cwd().parent
else:
    ROOT = Path.cwd()

src_path = ROOT / 'src'

# Add src to path if not already there
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

from full_scanner import (
    get_sp500_tickers,
    get_nasdaq100_tickers,
    get_portfolio_tickers,
    scan_stocks,
    filter_buy_signals,
    create_excel_output,
    create_portfolio_excel,
    create_pdf_report
)

# Setup results directory
results_dir = ROOT / 'scanner_results'
results_dir.mkdir(exist_ok=True)

timestamp = datetime.now().strftime("%Y%m%d_%H%M")

print("✓ Scanner modules loaded")
print(f"✓ Results directory: {results_dir}")
print(f"✓ Timestamp: {timestamp}")
# Out:
# ✓ Scanner modules loaded
# ✓ Results directory: c:\workspace\portfolio_analyser\scanner_results
# ✓ Timestamp: 20260107_2330

# %% [markdown]
# ## Configuration
#
# Set your scan parameters:
# - **daily_bars**: Number of daily bars to analyze (default: 60)
# - **weekly_bars**: Number of weekly bars to analyze (default: 52)
# - **concurrency**: Number of parallel workers (default: 2, max recommended: 5)

# %%
# Scan parameters
DAILY_BARS = 60
WEEKLY_BARS = 52
CONCURRENCY = 2  # Be careful with higher values (rate limits)

print(f"Daily bars: {DAILY_BARS}")
print(f"Weekly bars: {WEEKLY_BARS}")
print(f"Concurrency: {CONCURRENCY}")
# Out:
# Daily bars: 60
# Weekly bars: 52
# Concurrency: 2

# %% [markdown]
# ## Option 1: Scan Portfolio Stocks Only
#
# Quick scan of your portfolio stocks from `stocks.txt`. Includes ALL signals (not just FULL HOLD + ADD).

# %%
print("Loading portfolio tickers from stocks.txt...")
portfolio_tickers = get_portfolio_tickers()

if portfolio_tickers:
    print(f"Found {len(portfolio_tickers)} portfolio stocks\n")

    # Run scan
    portfolio_results = scan_stocks(
        portfolio_tickers,
        category="Portfolio",
        daily_bars=DAILY_BARS,
        weekly_bars=WEEKLY_BARS,
        concurrency=CONCURRENCY
    )

    if not portfolio_results.empty:
        print(f"\n✓ Scanned {len(portfolio_results)} stocks")

        # Count by signal
        signal_counts = portfolio_results['signal'].value_counts()
        print("\nSignal breakdown:")
        for signal, count in signal_counts.items():
            print(f"  {signal}: {count}")

        # Save results - use create_portfolio_excel for all signals
        xlsx_path = results_dir / f'portfolio_scanner_{timestamp}.xlsx'
        pdf_path = results_dir / f'scanner_report_portfolio_{timestamp}.pdf'

        create_portfolio_excel(portfolio_results, xlsx_path, category="Portfolio")
        create_pdf_report(portfolio_results, portfolio_results, pdf_path, timestamp, category="Portfolio")

        print(f"\n✓ Excel: {xlsx_path.name}")
        print(f"✓ PDF: {pdf_path.name}")

        # Show FULL HOLD + ADD stocks
        buy_signals = filter_buy_signals(portfolio_results, 'FULL HOLD + ADD')
        if not buy_signals.empty:
            print(f"\n🎯 {len(buy_signals)} FULL HOLD + ADD signals:")
            # Display only columns that exist
            display_cols = ['ticker', 'signal', 'current_price']
            print(buy_signals[display_cols].to_string(index=False))
        else:
            print("\n⚠️ No FULL HOLD + ADD signals in portfolio")
else:
    print("⚠️ No portfolio tickers found in stocks.txt")
# Out:
# Loading portfolio tickers from stocks.txt...
# [OK] Loaded 13 portfolio tickers from stocks.txt
#
# Found 13 portfolio stocks
#
# [SCAN] Scanning 13 Portfolio stocks for 'FULL HOLD + ADD' signals...
# Parameters: 60 daily bars, 52 weekly bars, 2 threads
# ================================================================================
# [OK] [1/13] NVDA   -> FULL HOLD + ADD      $189.11
# [OK] [2/13] TSLA   -> FULL HOLD + ADD      $431.41
# [OK] [5/13] PLTR   -> FULL HOLD + ADD      $181.68
# [OK] [7/13] ASML   -> FULL HOLD + ADD      $1228.47
# [OK] [12/13] MRVL   -> FULL HOLD + ADD      $84.64
# ================================================================================
#
# [OK] Scan complete: 13 analyzed, 5 FULL HOLD + ADD signals found
#
#
# ✓ Scanned 13 stocks
#
# Signal breakdown:
#   FULL HOLD + ADD: 5
#   HOLD MOST + REDUCE: 4
#   CASH: 2
#   HOLD: 2
# âœ“ Excel file created: c:\workspace\portfolio_analyser\scanner_results\portfolio_scanner_20260107_2330.xlsx
#   - All: 13 stocks
#   - FULL HOLD + ADD: 5 stocks
#   - HOLD MOST + REDUCE: 4 stocks
#   - HOLD: 2 stocks
#   - CASH: 2 stocks
# [OK] PDF report created: c:\workspace\portfolio_analyser\scanner_results\scanner_report_portfolio_20260107_2330.pdf
#   - 5 FULL HOLD + ADD (detailed)
#   - 4 HOLD MOST + REDUCE (summary)
#   - 2 HOLD (summary)
#   - 2 CASH (summary)
#
# ✓ Excel: portfolio_scanner_20260107_2330.xlsx
# ✓ PDF: scanner_report_portfolio_20260107_2330.pdf
#
# 🎯 5 FULL HOLD + ADD signals:
# ticker          signal  current_price
#   ASML FULL HOLD + ADD        1228.47
#   MRVL FULL HOLD + ADD          84.64
#   NVDA FULL HOLD + ADD         189.11
#   PLTR FULL HOLD + ADD         181.68
#   TSLA FULL HOLD + ADD         431.41

# %% [markdown]
# ## Option 2: Scan S&P 500
#
# Full scan of ~500 stocks. Takes 5-10 minutes depending on cache. Only outputs FULL HOLD + ADD signals.

# %%
print("Fetching S&P 500 ticker list...")
sp500_tickers = get_sp500_tickers()
print(f"Found {len(sp500_tickers)} S&P 500 stocks\n")

# Run scan
sp500_results = scan_stocks(
    sp500_tickers,
    category="S&P 500",
    daily_bars=DAILY_BARS,
    weekly_bars=WEEKLY_BARS,
    concurrency=CONCURRENCY
)

if not sp500_results.empty:
    # Filter for buy signals only
    sp500_buy = filter_buy_signals(sp500_results, 'FULL HOLD + ADD')
    print(f"\n🎯 S&P 500: {len(sp500_buy)} FULL HOLD + ADD signals found")

    if not sp500_buy.empty:
        # Save results
        xlsx_path = results_dir / f'sp500_analysis_{timestamp}.xlsx'
        pdf_path = results_dir / f'scanner_report_sp500_{timestamp}.pdf'

        create_excel_output(sp500_buy, xlsx_path, category="S&P 500")
        create_pdf_report(sp500_buy, sp500_results, pdf_path, timestamp, category="S&P 500")

        print(f"\n✓ Excel: {xlsx_path.name}")
        print(f"✓ PDF: {pdf_path.name}")

        # Display top results
        print("\nTop results:")
        display_cols = ['ticker', 'signal', 'current_price']
        print(sp500_buy[display_cols].head(10).to_string(index=False))
    else:
        print("\n⚠️ No FULL HOLD + ADD signals found in S&P 500")
# Out:
# Fetching S&P 500 ticker list...
# [OK] Loaded 503 S&P 500 tickers
#
# Found 503 S&P 500 stocks
#
# [SCAN] Scanning 503 S&P 500 stocks for 'FULL HOLD + ADD' signals...
# Parameters: 60 daily bars, 52 weekly bars, 2 threads
# ================================================================================
# [OK] [3/503] ABBV   -> FULL HOLD + ADD      $233.42
# [OK] [9/503] AFL    -> FULL HOLD + ADD      $110.19
# [OK] [14/503] ALB    -> FULL HOLD + ADD      $161.57
# [OK] [19/503] ALL    -> FULL HOLD + ADD      $207.27
# [OK] [20/503] GOOGL  -> FULL HOLD + ADD      $321.98
# [OK] [21/503] GOOG   -> FULL HOLD + ADD      $322.43
# [OK] [23/503] AMZN   -> FULL HOLD + ADD      $241.56
# [OK] [27/503] AXP    -> FULL HOLD + ADD      $378.22
# [OK] [28/503] AIG    -> FULL HOLD + ADD      $77.07
# [OK] [32/503] AME    -> FULL HOLD + ADD      $211.18
# [OK] [33/503] APH    -> FULL HOLD + ADD      $138.91
# [OK] [34/503] AMGN   -> FULL HOLD + ADD      $341.64
# [OK] [35/503] ADI    -> FULL HOLD + ADD      $292.89
# [OK] [38/503] APO    -> FULL HOLD + ADD      $144.28
# [OK] [39/503] AAPL   -> FULL HOLD + ADD      $260.33
# [OK] [40/503] AMAT   -> FULL HOLD + ADD      $292.20
# [OK] [41/503] APP    -> FULL HOLD + ADD      $632.92
# [OK] [43/503] ACGL   -> FULL HOLD + ADD      $95.16
# [OK] [46/503] ARES   -> FULL HOLD + ADD      $170.80
# [OK] [48/503] AIZ    -> FULL HOLD + ADD      $236.50
#   [50/503] Scanning...
# [OK] [59/503] BAC    -> FULL HOLD + ADD      $55.64
# [OK] [62/503] BRK-B  -> FULL HOLD + ADD      $496.12
# [OK] [69/503] BA     -> FULL HOLD + ADD      $228.12
# [OK] [70/503] BK     -> FULL HOLD + ADD      $120.45
# [OK] [71/503] BKNG   -> FULL HOLD + ADD      $5445.72
# [OK] [79/503] BG     -> FULL HOLD + ADD      $92.59
# [OK] [81/503] CHRW   -> FULL HOLD + ADD      $166.73
# [OK] [85/503] COF    -> FULL HOLD + ADD      $253.25
# [OK] [86/503] CAH    -> FULL HOLD + ADD      $207.19
# [OK] [87/503] CCL    -> FULL HOLD + ADD      $32.11
# [OK] [89/503] CAT    -> FULL HOLD + ADD      $596.52
# [OK] [90/503] CVNA   -> FULL HOLD + ADD      $450.78
# [OK] [91/503] CBOE   -> FULL HOLD + ADD      $255.16
# [OK] [92/503] CBRE   -> FULL HOLD + ADD      $166.33
# [OK] [94/503] COR    -> FULL HOLD + ADD      $340.41
# [OK] [98/503] SCHW   -> FULL HOLD + ADD      $101.93
#   [100/503] Scanning...
# [OK] [101/503] CVX    -> FULL HOLD + ADD      $155.20
# [OK] [103/503] CB     -> FULL HOLD + ADD      $306.63
# [OK] [106/503] CINF   -> FULL HOLD + ADD      $163.04
# [OK] [108/503] CSCO   -> FULL HOLD + ADD      $74.72
# [OK] [109/503] C      -> FULL HOLD + ADD      $121.37
# [OK] [110/503] CFG    -> FULL HOLD + ADD      $60.99
# [OK] [112/503] CME    -> FULL HOLD + ADD      $266.85
# [OK] [114/503] KO     -> FULL HOLD + ADD      $67.54
# [OK] [115/503] CTSH   -> FULL HOLD + ADD      $84.11
# [OK] [119/503] FIX    -> FULL HOLD + ADD      $1035.12
# [OK] [124/503] CEG    -> FULL HOLD + ADD      $338.63
# [OK] [127/503] GLW    -> FULL HOLD + ADD      $87.99
# [OK] [132/503] CTRA   -> FULL HOLD + ADD      $25.29
# [OK] [133/503] CRH    -> FULL HOLD + ADD      $122.88
# [OK] [136/503] CSX    -> FULL HOLD + ADD      $35.05
# [OK] [137/503] CMI    -> FULL HOLD + ADD      $539.03
# [OK] [138/503] CVS    -> FULL HOLD + ADD      $79.79
# [OK] [143/503] DAY    -> FULL HOLD + ADD      $69.40
# [OK] [147/503] DAL    -> FULL HOLD + ADD      $71.65
#   [150/503] Scanning...
# [OK] [152/503] DG     -> FULL HOLD + ADD      $143.51
# [OK] [153/503] DLTR   -> FULL HOLD + ADD      $131.56
# [OK] [157/503] DOV    -> FULL HOLD + ADD      $199.38
# [OK] [162/503] DD     -> FULL HOLD + ADD      $43.23
# [OK] [167/503] EW     -> FULL HOLD + ADD      $84.83
# [OK] [168/503] EA     -> FULL HOLD + ADD      $204.50
# [OK] [171/503] EMR    -> FULL HOLD + ADD      $142.15
# [OK] [187/503] EXPE   -> FULL HOLD + ADD      $297.18
# [OK] [188/503] EXPD   -> FULL HOLD + ADD      $156.90
# [OK] [190/503] XOM    -> FULL HOLD + ADD      $118.49
# [OK] [195/503] FRT    -> FULL HOLD + ADD      $101.67
# [OK] [196/503] FDX    -> FULL HOLD + ADD      $307.33
# [OK] [198/503] FITB   -> FULL HOLD + ADD      $49.17
# [OK] [199/503] FSLR   -> FULL HOLD + ADD      $241.11
#   [200/503] Scanning...
# [OK] [202/503] F      -> FULL HOLD + ADD      $13.74
# [OK] [205/503] FOXA   -> FULL HOLD + ADD      $75.03
# [OK] [206/503] FOX    -> FULL HOLD + ADD      $67.07
# [OK] [207/503] BEN    -> FULL HOLD + ADD      $25.15
# [OK] [208/503] FCX    -> FULL HOLD + ADD      $55.50
# [OK] [211/503] GE     -> FULL HOLD + ADD      $323.64
# [OK] [213/503] GEV    -> FULL HOLD + ADD      $662.32
# [OK] [216/503] GD     -> FULL HOLD + ADD      $345.64
# [OK] [218/503] GM     -> FULL HOLD + ADD      $81.91
# [OK] [220/503] GILD   -> FULL HOLD + ADD      $124.35
# [OK] [222/503] GL     -> FULL HOLD + ADD      $139.76
# [OK] [224/503] GS     -> FULL HOLD + ADD      $941.02
# [OK] [226/503] HIG    -> FULL HOLD + ADD      $135.90
# [OK] [227/503] HAS    -> FULL HOLD + ADD      $87.02
# [OK] [228/503] HCA    -> FULL HOLD + ADD      $470.65
# [OK] [230/503] HSIC   -> FULL HOLD + ADD      $78.14
# [OK] [231/503] HSY    -> FULL HOLD + ADD      $180.07
# [OK] [232/503] HPE    -> FULL HOLD + ADD      $22.43
# [OK] [234/503] HLT    -> FULL HOLD + ADD      $293.50
# [OK] [238/503] HST    -> FULL HOLD + ADD      $17.79
# [OK] [239/503] HWM    -> FULL HOLD + ADD      $210.90
# [OK] [241/503] HUBB   -> FULL HOLD + ADD      $468.20
# [OK] [243/503] HBAN   -> FULL HOLD + ADD      $18.14
# [OK] [244/503] HII    -> FULL HOLD + ADD      $356.45
# [OK] [245/503] IBM    -> FULL HOLD + ADD      $296.73
# [OK] [247/503] IDXX   -> FULL HOLD + ADD      $714.55
# [OK] [249/503] INCY   -> FULL HOLD + ADD      $110.57
#   [250/503] Scanning...
# [OK] [252/503] INTC   -> FULL HOLD + ADD      $42.63
# [OK] [253/503] IBKR   -> FULL HOLD + ADD      $71.34
# [OK] [258/503] ISRG   -> FULL HOLD + ADD      $592.27
# [OK] [259/503] IVZ    -> FULL HOLD + ADD      $27.69
# [OK] [261/503] IQV    -> FULL HOLD + ADD      $244.29
# [OK] [262/503] JBHT   -> FULL HOLD + ADD      $203.82
# [OK] [264/503] JBL    -> FULL HOLD + ADD      $224.45
# [OK] [265/503] JKHY   -> FULL HOLD + ADD      $185.97
# [OK] [267/503] JNJ    -> FULL HOLD + ADD      $207.49
# [OK] [268/503] JCI    -> FULL HOLD + ADD      $112.41
# [OK] [269/503] JPM    -> FULL HOLD + ADD      $326.99
# [OK] [272/503] KEY    -> FULL HOLD + ADD      $21.30
# [OK] [273/503] KEYS   -> FULL HOLD + ADD      $212.32
# [OK] [276/503] KMI    -> FULL HOLD + ADD      $27.00
# [OK] [277/503] KKR    -> FULL HOLD + ADD      $130.83
# [OK] [278/503] KLAC   -> FULL HOLD + ADD      $1359.69
# [OK] [281/503] LHX    -> FULL HOLD + ADD      $309.76
# [OK] [283/503] LRCX   -> FULL HOLD + ADD      $203.08
# [OK] [285/503] LVS    -> FULL HOLD + ADD      $61.43
# [OK] [286/503] LDOS   -> FULL HOLD + ADD      $196.61
# [OK] [289/503] LLY    -> FULL HOLD + ADD      $1108.09
# [OK] [292/503] LMT    -> FULL HOLD + ADD      $496.87
# [OK] [293/503] L      -> FULL HOLD + ADD      $105.45
# [OK] [294/503] LOW    -> FULL HOLD + ADD      $247.12
# [OK] [297/503] MTB    -> FULL HOLD + ADD      $209.55
# [OK] [299/503] MAR    -> FULL HOLD + ADD      $319.26
#   [300/503] Scanning...
# [OK] [301/503] MLM    -> FULL HOLD + ADD      $625.04
# [OK] [303/503] MA     -> FULL HOLD + ADD      $579.92
# [OK] [306/503] MCD    -> FULL HOLD + ADD      $304.16
# [OK] [307/503] MCK    -> FULL HOLD + ADD      $823.95
# [OK] [308/503] MDT    -> FULL HOLD + ADD      $99.77
# [OK] [311/503] MET    -> FULL HOLD + ADD      $78.27
# [OK] [312/503] MTD    -> FULL HOLD + ADD      $1470.87
# [OK] [315/503] MU     -> FULL HOLD + ADD      $339.55
# [OK] [322/503] MPWR   -> FULL HOLD + ADD      $959.08
# [OK] [323/503] MNST   -> FULL HOLD + ADD      $76.15
# [OK] [324/503] MCO    -> FULL HOLD + ADD      $531.44
# [OK] [325/503] MS     -> FULL HOLD + ADD      $184.79
# [OK] [328/503] MSCI   -> FULL HOLD + ADD      $578.69
# [OK] [329/503] NDAQ   -> FULL HOLD + ADD      $100.40
# [OK] [332/503] NEM    -> FULL HOLD + ADD      $108.01
# [OK] [338/503] NDSN   -> FULL HOLD + ADD      $252.86
# [OK] [339/503] NSC    -> FULL HOLD + ADD      $284.09
# [OK] [340/503] NTRS   -> FULL HOLD + ADD      $142.62
# [OK] [341/503] NOC    -> FULL HOLD + ADD      $577.01
# [OK] [344/503] NUE    -> FULL HOLD + ADD      $164.81
# [OK] [345/503] NVDA   -> FULL HOLD + ADD      $189.11
# [OK] [347/503] NXPI   -> FULL HOLD + ADD      $239.34
#   [350/503] Scanning...
# [OK] [356/503] PCAR   -> FULL HOLD + ADD      $115.30
# [OK] [357/503] PKG    -> FULL HOLD + ADD      $206.81
# [OK] [358/503] PLTR   -> FULL HOLD + ADD      $181.68
# [OK] [361/503] PH     -> FULL HOLD + ADD      $908.39
# [OK] [372/503] PNC    -> FULL HOLD + ADD      $216.27
# [OK] [376/503] PFG    -> FULL HOLD + ADD      $90.88
# [OK] [379/503] PLD    -> FULL HOLD + ADD      $126.90
# [OK] [380/503] PRU    -> FULL HOLD + ADD      $116.85
# [OK] [385/503] PWR    -> FULL HOLD + ADD      $436.89
# [OK] [386/503] QCOM   -> FULL HOLD + ADD      $180.19
# [OK] [388/503] RL     -> FULL HOLD + ADD      $360.94
# [OK] [389/503] RJF    -> FULL HOLD + ADD      $165.15
# [OK] [390/503] RTX    -> FULL HOLD + ADD      $185.73
# [OK] [394/503] RF     -> FULL HOLD + ADD      $28.46
# [OK] [399/503] ROK    -> FULL HOLD + ADD      $409.34
# [OK] [400/503] ROL    -> FULL HOLD + ADD      $59.45
# [OK] [402/503] ROST   -> FULL HOLD + ADD      $186.99
# [OK] [404/503] SPGI   -> FULL HOLD + ADD      $537.50
# [OK] [406/503] SNDK   -> FULL HOLD + ADD      $353.56
# [OK] [409/503] STX    -> FULL HOLD + ADD      $308.26
# [OK] [413/503] SPG    -> FULL HOLD + ADD      $183.95
# [OK] [417/503] SNA    -> FULL HOLD + ADD      $352.58
# [OK] [418/503] SOLV   -> FULL HOLD + ADD      $84.24
# [OK] [420/503] LUV    -> FULL HOLD + ADD      $42.64
# [OK] [423/503] STT    -> FULL HOLD + ADD      $132.45
# [OK] [424/503] STLD   -> FULL HOLD + ADD      $167.83
# [OK] [425/503] STE    -> FULL HOLD + ADD      $259.20
# [OK] [428/503] SYF    -> FULL HOLD + ADD      $87.43
# [OK] [432/503] TROW   -> FULL HOLD + ADD      $106.00
# [OK] [433/503] TTWO   -> FULL HOLD + ADD      $256.67
# [OK] [434/503] TPR    -> FULL HOLD + ADD      $130.97
# [OK] [435/503] TRGP   -> FULL HOLD + ADD      $174.55
# [OK] [437/503] TEL    -> FULL HOLD + ADD      $229.59
# [OK] [439/503] TER    -> FULL HOLD + ADD      $222.48
# [OK] [440/503] TSLA   -> FULL HOLD + ADD      $431.41
# [OK] [443/503] TXT    -> FULL HOLD + ADD      $88.58
# [OK] [444/503] TMO    -> FULL HOLD + ADD      $617.15
# [OK] [445/503] TJX    -> FULL HOLD + ADD      $154.04
# [OK] [446/503] TKO    -> FULL HOLD + ADD      $202.91
# [OK] [450/503] TDG    -> FULL HOLD + ADD      $1385.25
# [OK] [451/503] TRV    -> FULL HOLD + ADD      $283.19
# [OK] [452/503] TRMB   -> FULL HOLD + ADD      $80.18
# [OK] [453/503] TFC    -> FULL HOLD + ADD      $50.58
# [OK] [456/503] USB    -> FULL HOLD + ADD      $54.87
# [OK] [459/503] ULTA   -> FULL HOLD + ADD      $655.36
# [OK] [460/503] UNP    -> FULL HOLD + ADD      $224.48
# [OK] [461/503] UAL    -> FULL HOLD + ADD      $116.60
# [OK] [465/503] UHS    -> FULL HOLD + ADD      $208.39
# [OK] [466/503] VLO    -> FULL HOLD + ADD      $183.86
# [OK] [467/503] VTR    -> FULL HOLD + ADD      $75.69
# [OK] [473/503] VTRS   -> FULL HOLD + ADD      $12.46
# [OK] [475/503] V      -> FULL HOLD + ADD      $355.88
# [OK] [477/503] VMC    -> FULL HOLD + ADD      $292.12
# [OK] [480/503] WAB    -> FULL HOLD + ADD      $216.62
# [OK] [481/503] WMT    -> FULL HOLD + ADD      $112.72
# [OK] [482/503] DIS    -> FULL HOLD + ADD      $112.91
# [OK] [483/503] WBD    -> FULL HOLD + ADD      $28.59
# [OK] [485/503] WAT    -> FULL HOLD + ADD      $399.41
# [OK] [487/503] WFC    -> FULL HOLD + ADD      $94.29
# [OK] [488/503] WELL   -> FULL HOLD + ADD      $185.65
# [OK] [490/503] WDC    -> FULL HOLD + ADD      $199.88
# [OK] [493/503] WMB    -> FULL HOLD + ADD      $60.39
# [OK] [494/503] WTW    -> FULL HOLD + ADD      $331.38
# [OK] [499/503] YUM    -> FULL HOLD + ADD      $150.49
#   [500/503] Scanning...
# ================================================================================
#
# [OK] Scan complete: 502 analyzed, 208 FULL HOLD + ADD signals found
#
#
# 🎯 S&P 500: 208 FULL HOLD + ADD signals found
# [OK] Excel file created: c:\workspace\portfolio_analyser\scanner_results\sp500_analysis_20260107_2330.xlsx
#   - FULL HOLD + ADD: 208 stocks
# [OK] PDF report created: c:\workspace\portfolio_analyser\scanner_results\scanner_report_sp500_20260107_2330.pdf
#   - 208 FULL HOLD + ADD (detailed)
#
# ✓ Excel: sp500_analysis_20260107_2330.xlsx
# ✓ PDF: scanner_report_sp500_20260107_2330.pdf
#
# Top results:
# ticker          signal  current_price
#   AAPL FULL HOLD + ADD         260.33
#   ABBV FULL HOLD + ADD         233.42
#   ACGL FULL HOLD + ADD          95.16
#    ADI FULL HOLD + ADD         292.89
#    AFL FULL HOLD + ADD         110.19
#    AIG FULL HOLD + ADD          77.07
#    AIZ FULL HOLD + ADD         236.50
#    ALB FULL HOLD + ADD         161.57
#    ALL FULL HOLD + ADD         207.27
#   AMAT FULL HOLD + ADD         292.20

# %% [markdown]
# ## Option 3: Scan NASDAQ 100
#
# Scan ~100 tech-heavy stocks. Takes 2-5 minutes. Only outputs FULL HOLD + ADD signals.

# %%
print("Fetching NASDAQ 100 ticker list...")
nasdaq100_tickers = get_nasdaq100_tickers()
print(f"Found {len(nasdaq100_tickers)} NASDAQ 100 stocks\n")

# Run scan
nasdaq100_results = scan_stocks(
    nasdaq100_tickers,
    category="NASDAQ 100",
    daily_bars=DAILY_BARS,
    weekly_bars=WEEKLY_BARS,
    concurrency=CONCURRENCY
)

if not nasdaq100_results.empty:
    # Filter for buy signals only
    nasdaq100_buy = filter_buy_signals(nasdaq100_results, 'FULL HOLD + ADD')
    print(f"\n🎯 NASDAQ 100: {len(nasdaq100_buy)} FULL HOLD + ADD signals found")

    if not nasdaq100_buy.empty:
        # Save results
        xlsx_path = results_dir / f'nasdaq100_analysis_{timestamp}.xlsx'
        pdf_path = results_dir / f'scanner_report_nasdaq100_{timestamp}.pdf'

        create_excel_output(nasdaq100_buy, xlsx_path, category="NASDAQ 100")
        create_pdf_report(nasdaq100_buy, nasdaq100_results, pdf_path, timestamp, category="NASDAQ 100")

        print(f"\n✓ Excel: {xlsx_path.name}")
        print(f"✓ PDF: {pdf_path.name}")

        # Display top results
        print("\nTop results:")
        display_cols = ['ticker', 'signal', 'current_price']
        print(nasdaq100_buy[display_cols].head(10).to_string(index=False))
    else:
        print("\n⚠️ No FULL HOLD + ADD signals found in NASDAQ 100")
# Out:
# Fetching NASDAQ 100 ticker list...
# [OK] Loaded 101 NASDAQ 100 tickers
#
# Found 101 NASDAQ 100 stocks
#
# [SCAN] Scanning 101 NASDAQ 100 stocks for 'FULL HOLD + ADD' signals...
# Parameters: 60 daily bars, 52 weekly bars, 2 threads
# ================================================================================
# [OK] [5/101] GOOG   -> FULL HOLD + ADD      $322.43
# [OK] [6/101] GOOGL  -> FULL HOLD + ADD      $321.98
# [OK] [7/101] AMZN   -> FULL HOLD + ADD      $241.56
# [OK] [9/101] AMGN   -> FULL HOLD + ADD      $341.64
# [OK] [10/101] ADI    -> FULL HOLD + ADD      $292.89
# [OK] [11/101] AAPL   -> FULL HOLD + ADD      $260.33
# [OK] [12/101] AMAT   -> FULL HOLD + ADD      $292.20
# [OK] [14/101] APP    -> FULL HOLD + ADD      $632.92
# [OK] [15/101] ASML   -> FULL HOLD + ADD      $1228.47
# [OK] [16/101] AZN    -> FULL HOLD + ADD      $95.16
# [OK] [22/101] BKNG   -> FULL HOLD + ADD      $5445.72
# [OK] [27/101] CSCO   -> FULL HOLD + ADD      $74.72
# [OK] [29/101] CTSH   -> FULL HOLD + ADD      $84.11
# [OK] [31/101] CEG    -> FULL HOLD + ADD      $338.63
# [OK] [36/101] CSX    -> FULL HOLD + ADD      $35.05
# [OK] [41/101] EA     -> FULL HOLD + ADD      $204.50
# [OK] [44/101] FER    -> FULL HOLD + ADD      $67.36
# [OK] [47/101] GILD   -> FULL HOLD + ADD      $124.35
# [OK] [49/101] IDXX   -> FULL HOLD + ADD      $714.55
# [OK] [50/101] INTC   -> FULL HOLD + ADD      $42.63
# [OK] [53/101] ISRG   -> FULL HOLD + ADD      $592.27
# [OK] [55/101] KLAC   -> FULL HOLD + ADD      $1359.69
# [OK] [57/101] LRCX   -> FULL HOLD + ADD      $203.08
# [OK] [59/101] MAR    -> FULL HOLD + ADD      $319.26
# [OK] [60/101] MRVL   -> FULL HOLD + ADD      $84.64
# [OK] [64/101] MU     -> FULL HOLD + ADD      $339.55
# [OK] [68/101] MPWR   -> FULL HOLD + ADD      $959.08
# [OK] [69/101] MNST   -> FULL HOLD + ADD      $76.15
# [OK] [71/101] NVDA   -> FULL HOLD + ADD      $189.11
# [OK] [72/101] NXPI   -> FULL HOLD + ADD      $239.34
# [OK] [75/101] PCAR   -> FULL HOLD + ADD      $115.30
# [OK] [76/101] PLTR   -> FULL HOLD + ADD      $181.68
# [OK] [82/101] QCOM   -> FULL HOLD + ADD      $180.19
# [OK] [85/101] ROST   -> FULL HOLD + ADD      $186.99
# [OK] [86/101] STX    -> FULL HOLD + ADD      $308.26
# [OK] [87/101] SHOP   -> FULL HOLD + ADD      $166.74
# [OK] [91/101] TTWO   -> FULL HOLD + ADD      $256.67
# [OK] [92/101] TSLA   -> FULL HOLD + ADD      $431.41
# [OK] [97/101] WBD    -> FULL HOLD + ADD      $28.59
# [OK] [98/101] WDC    -> FULL HOLD + ADD      $199.88
#   [100/101] Scanning...
# ================================================================================
#
# [OK] Scan complete: 101 analyzed, 40 FULL HOLD + ADD signals found
#
#
# 🎯 NASDAQ 100: 40 FULL HOLD + ADD signals found
# [OK] Excel file created: c:\workspace\portfolio_analyser\scanner_results\nasdaq100_analysis_20260107_2330.xlsx
#   - FULL HOLD + ADD: 40 stocks
# [OK] PDF report created: c:\workspace\portfolio_analyser\scanner_results\scanner_report_nasdaq100_20260107_2330.pdf
#   - 40 FULL HOLD + ADD (detailed)
#
# ✓ Excel: nasdaq100_analysis_20260107_2330.xlsx
# ✓ PDF: scanner_report_nasdaq100_20260107_2330.pdf
#
# Top results:
# ticker          signal  current_price
#   AAPL FULL HOLD + ADD         260.33
#    ADI FULL HOLD + ADD         292.89
#   AMAT FULL HOLD + ADD         292.20
#   AMGN FULL HOLD + ADD         341.64
#   AMZN FULL HOLD + ADD         241.56
#    APP FULL HOLD + ADD         632.92
#   ASML FULL HOLD + ADD        1228.47
#    AZN FULL HOLD + ADD          95.16
#   BKNG FULL HOLD + ADD        5445.72
#    CEG FULL HOLD + ADD         338.63
